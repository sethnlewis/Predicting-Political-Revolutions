# %%
import pandas as pd
pd.options.display.max_columns = 100

# %%
df_rows = pd.read_csv('contribDB_2014.csv', nrows=5)

# %%
df_rows
# Out:
#    cycle             transaction.id  transaction.type   amount        date  \
# 0   2014  CA:1424021_INC634_2014_1_                15  1789.15  2013-11-19
# 1   2014  CA:1436949_INC342_2014_0_                15   408.26  2009-01-07
# 2   2014  CA:1436949_INC343_2014_0_                15   842.06  2009-01-12
# 3   2014  CA:1436949_INC352_2014_0_                15   230.53  2009-01-21
# 4   2014  CA:1436949_INC356_2014_0_                15   409.44  2009-02-07
#
#     bonica.cid            contributor.name  contributor.lname  \
# 0   3836518376         state of california                NaN
# 1  32780584235  golden state business bank                NaN
# 2  32780584235  golden state business bank                NaN
# 3   3839554438      arrowhead credit union                NaN
# 4  32780584235  golden state business bank                NaN
#
#    contributor.fname  contributor.mname  contributor.suffix  \
# 0                NaN                NaN                 NaN
# ...

# %%
df_rows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 46 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   cycle                     5 non-null      int64
#  1   transaction.id            5 non-null      object
#  2   transaction.type          5 non-null      int64
#  3   amount                    5 non-null      float64
#  4   date                      5 non-null      object
#  5   bonica.cid                5 non-null      int64
#  6   contributor.name          5 non-null      object
#  7   contributor.lname         0 non-null      float64
#  8   contributor.fname         0 non-null      float64
#  9   contributor.mname         0 non-null      float64
#  10  contributor.suffix        0 non-null      float64
#  11  contributor.title         0 non-null      float64
#  12  contributor.ffname        0 non-null      float64
# ...

# %%
df_cols = pd.read_csv('contribDB_2014.csv')
# Out:
# C:\Users\seths\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (2,7,8,9,10,11,12,14,15,20,21,23,24,25,27,28,36,37,38,39,40,41,42) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     467     with parser:
# --> 468         return parser.read(nrows)
#     469
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1068
# -> 1069         df = DataFrame(col_dict, columns=columns, index=index)
#    1070
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     528         elif isinstance(data, dict):
# ...

# %%
df_cols.info()

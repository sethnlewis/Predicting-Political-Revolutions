# %% [markdown]
# # Cleaning "Mass Mobilizations" Protest Dataset
#
# This notebook receives as input the raw edition of the Mass Mobilization protest dataset from the Mass Molilization Project and funded by the Political Instability Task Force (PITF). The notebook serves the purpose of addressing missing and inconsistent values, removing outliers, and creating consistent naming schemes to allow for cross-use with other datasets.
#
#
# ### About the Data
# It is described in the source documentation as "an effort to understand citizen movements against governments, what citizens want when they demonstrate against governments, and how governments respond to citizens. The MM data cover 162 countries between 1990 and 2018. These data contain events where 50 or more protesters publicly demonstrate against government, resulting in more than 10,000 protest events. Each event records location, protest size, protester demands, and government responses." [(1)](https://massmobilization.github.io/about.html) The project is sponsored by the Political Instability Task Force (PITF). The PITF is funded by the Central Intelligence Agency (CIA). [(1)](https://massmobilization.github.io/about.html) Throughout the rest of this analysis, this dataset will be referred to as the "Protests" dataset.
#
# Although the data source does specify that the dataset is not entirely comprehensive of all country across this entire time period. That said, it does contain over 17,000 recorded protests, each composed of 31 features. The data span 167 countries from 1990 to 2020.
#
#
# #### Data source citation:
# Clark, David; Regan, Patrick, 2016, "Mass Mobilization Protest Data", https://doi.org/10.7910/DVN/HTTWYL, Harvard Dataverse, V5, UNF:6:F/k8KUqKpCa5UssBbL/gzg== [fileUNF]

# %% [markdown]
# ## Data Understanding

# %%
# Import necessary packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
import datetime
import sys

# Encoding & analyzing
from sklearn.preprocessing import OneHotEncoder
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Exporting processed dataset
from sqlalchemy import create_engine

# Options
# pd.options.display.max_rows = 100
pd.options.display.max_columns = 200
# %matplotlib inline

# Convenience for working with external src code files
# %load_ext autoreload
# %autoreload 2
sys.path.insert(1, "../src")

# Custom functions
from identify_collinearity import *

# %%
# Import raw dataset in CSV format
path = "../data/raw/Mass-Mobilization-Protests/mmALL_073120_csv.csv"
df = pd.read_csv(path)

# %%
# Provide general descriptors of dataset
display(df.info())
display(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17145 entries, 0 to 17144
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     17145 non-null  int64
#  1   country                17145 non-null  object
#  2   ccode                  17145 non-null  int64
#  3   year                   17145 non-null  int64
#  4   region                 17145 non-null  object
#  5   protest                17145 non-null  int64
#  6   protestnumber          17145 non-null  int64
#  7   startday               15239 non-null  float64
#  8   startmonth             15239 non-null  float64
#  9   startyear              15239 non-null  float64
#  10  endday                 15239 non-null  float64
#  11  endmonth               15239 non-null  float64
#  12  endyear                15239 non-null  float64
#  13  protesterviolence      15758 non-null  float64
#  14  location               15218 non-null  object
#  15  participants_category  9887 non-null   object
#  16  participants           15746 non-null  object
#  17  protesteridentity      14684 non-null  object
#  18  protesterdemand1       15238 non-null  object
#  19  protesterdemand2       2977 non-null   object
#  20  protesterdemand3       383 non-null    object
#  21  protesterdemand4       831 non-null    object
#  22  stateresponse1         15208 non-null  object
#  23  stateresponse2         2888 non-null   object
#  24  stateresponse3         930 non-null    object
#  25  stateresponse4         244 non-null    object
#  26  stateresponse5         849 non-null    object
#  27  stateresponse6         16 non-null     object
#  28  stateresponse7         920 non-null    object
#  29  sources                15235 non-null  object
#  30  notes                  15193 non-null  object
# dtypes: float64(7), int64(5), object(19)
# memory usage: 4.1+ MB
# None
#                  id         ccode          year       protest  protestnumber  \
# count  1.714500e+04  17145.000000  17145.000000  17145.000000   17145.000000
# mean   4.380888e+09    437.888189   2006.171654      0.888831       7.406299
# std    2.320550e+09    232.054953      8.987378      0.314351      11.854041
# min    2.019900e+08     20.000000   1990.000000      0.000000       0.000000
# 25%    2.202010e+09    220.000000   1998.000000      1.000000       1.000000
# 50%    4.342008e+09    434.000000   2007.000000      1.000000       3.000000
# 75%    6.512005e+09    651.000000   2014.000000      1.000000       8.000000
# max    9.102020e+09    910.000000   2020.000000      1.000000     143.000000
#
#            startday    startmonth     startyear        endday      endmonth  \
# count  15239.000000  15239.000000  15239.000000  15239.000000  15239.000000
# mean      15.455935      6.227836   2006.326465     15.580616      6.243520
# std        8.817037      3.461912      8.958007      8.803944      3.461745
# min        1.000000      1.000000   1990.000000      1.000000      1.000000
# 25%        8.000000      3.000000   1999.000000      8.000000      3.000000
# 50%       15.000000      6.000000   2007.000000     16.000000      6.000000
# 75%       23.000000      9.000000   2014.000000     23.000000      9.000000
# max       31.000000     12.000000   2020.000000     31.000000     12.000000
#
#             endyear  protesterviolence
# count  15239.000000       15758.000000
# mean    2006.329221           0.256060
# std        8.959254           0.436469
# min     1990.000000           0.000000
# 25%     1999.000000           0.000000
# 50%     2007.000000           0.000000
# 75%     2014.000000           1.000000
# max     2020.000000           1.000000

# %% [markdown]
# ##### Check for duplicated protest IDs

# %%
df.id.value_counts()
# Out:
# 512000000     1
# 4502005006    1
# 2202017017    1
# 2001995002    1
# 1352011003    1
#              ..
# 2202002009    1
# 2001998017    1
# 4901991003    1
# 6402014010    1
# 701995005     1
# Name: id, Length: 17145, dtype: int64

# %% [markdown]
# ##### Understand protest year

# %%
# Understand "Protest Year" feature
year = df.year.unique()
year.sort()
print(year)

plt.hist(df.year, bins=(2020 - 1990));
# Out:
# [1990 1991 1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003
#  2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017
#  2018 2019 2020]

# %%
# Understand "Region" feature
regions = df.region.value_counts()
plt.figure(figsize=(10, 4))
plt.bar(regions.index, regions.values);

# %% [markdown]
# ##### "Protest" feature is used to indicate whether or not a protest occurred. Drop all rows with df.protest == 0. This means no protest took place, which can be verified by investigating a sample of those entries. Since this analysis studies only protests, non-protest entries are not of interest.

# %%
print(df.protest.value_counts())

print("\nDropping {} rows".format(df.protest.value_counts().iloc[1]))

df = df.loc[df.protest == 1].copy()
df.reset_index(inplace=True, drop=True)
# Out:
# 1    15239
# 0     1906
# Name: protest, dtype: int64
#
# Dropping 1906 rows

# %%
# Understand "ProtestNumber" feature
protestnumber = df.protestnumber.value_counts()
print(protestnumber[:20])

plt.figure(figsize=(10, 4))
df.protestnumber.hist(bins=50);
# Out:
# 1     2970
# 2     2141
# 3     1620
# 4     1269
# 5     1024
# 6      792
# 7      627
# 8      533
# 9      439
# 10     384
# 11     331
# 12     288
# 13     250
# 14     216
# 15     191
# 16     174
# 17     157
# 18     143
# 19     129
# 20     120
# Name: protestnumber, dtype: int64

# %% [markdown]
# ### Is "year" column the same as "startyear" column?
#
# Reviewing the below empty dataframe shows the answer is "yes".

# %%
df.loc[df.year != df.startyear]
# Out:
# Empty DataFrame
# Columns: [id, country, ccode, year, region, protest, protestnumber, startday, startmonth, startyear, endday, endmonth, endyear, protesterviolence, location, participants_category, participants, protesteridentity, protesterdemand1, protesterdemand2, protesterdemand3, protesterdemand4, stateresponse1, stateresponse2, stateresponse3, stateresponse4, stateresponse5, stateresponse6, stateresponse7, sources, notes]
# Index: []

# %%
df.protesterviolence.value_counts()
# Out:
# 0.0    11204
# 1.0     4035
# Name: protesterviolence, dtype: int64

# %% [markdown]
# ##### "Location" feature has too many unique values to provide value to analysis (confirmed by further investigation into data) and isn't at all standardized. Drop feature.

# %%
print(f"{df.location.unique().shape[0]} unique locations")
df.drop("location", axis=1, inplace=True)
# Out:
# 4401 unique locations

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# #### Convert 'Start' and 'End' dates to their own datetime columns

# %%
# For start date
startdate = df[["startyear", "startmonth", "startday"]]
startdate.columns = ["year", "month", "day"]
df["startdate"] = pd.to_datetime(startdate)

# For end date
enddate = df[["endyear", "endmonth", "endday"]]
enddate.columns = ["year", "month", "day"]
df["enddate"] = pd.to_datetime(enddate)


# Duration
# Add 1 to enddate because no protest is "zero" days, as would be indicated by a 1-day protest in the otherwise-defined below formula
df["duration_days"] = (
    (df.enddate + datetime.timedelta(days=1)) - df.startdate
).dt.days

# %% [markdown]
# #### Country name codes
#
# Make consistent with other data sources to enable merging. Minor differences in spelling, abbreviations, casing, etc. make this necessary. Process completed in simple Excel file for simplicity. Import that lookup table to convert to new naming schemes.

# %%
# Import Excel file containing lookup mapping/dictionary
code_lookup = pd.read_excel("../src/country_codes_protests.xlsx")
name_dict = dict(zip(code_lookup.combo_original, code_lookup.country_final))
scode_dict = dict(zip(code_lookup.combo_original, code_lookup.scode_final))

# Create ID to be used across all datasets
df["combo"] = df.country + "_" + df.ccode.astype("str")
df["countryname_final"] = df.combo.map(name_dict)
df["scode_final"] = df.combo.map(scode_dict)

# Show results
display(
    df[
        ["country", "ccode", "combo", "countryname_final", "scode_final"]
    ].drop_duplicates()
)

# Drop unused/helper features
df.drop(["ccode", "country", "combo"], axis=1, inplace=True)
# Out:
#                   country  ccode                  combo   countryname_final  \
# 0                  Canada     20              Canada_20              Canada
# 53                   Cuba     40                Cuba_40                Cuba
# 152                 Haiti     41               Haiti_41               Haiti
# 275    Dominican Republic     42  Dominican Republic_42  Dominican Republic
# 346               Jamaica     51             Jamaica_51             Jamaica
# ...                   ...    ...                    ...                 ...
# 14957           Singapore    830          Singapore_830           Singapore
# 14972         Philippines    840        Philippines_840         Philippines
# 15036           Indonesia    850          Indonesia_850           Indonesia
# 15189         Timor Leste    860        Timor Leste_860         Timor Leste
# 15201    Papua New Guinea    910   Papua New Guinea_910    Papua New Guinea
#
#       scode_final
# 0             CAN
# 53            CUB
# 152           HAI
# 275           DOM
# 346           JAM
# ...           ...
# 14957         SIN
# 14972         PHI
# 15036         INS
# 15189         ETM
# 15201         PNG
#
# [169 rows x 5 columns]

# %% [markdown]
# ### Fill in missing "Participants Category" value using the "Participants" column.
# This takes some manual  changes. Everything that can be changed from string to int is done automatically. Everything that can't be done automatically is added to a dictionary to be done manually. This *drastically* reduces any need for manual work

# %%
print(df.participants_category.value_counts())
print(f"\n{df.loc[df.participants.isna()].shape[0]} null values")
# Out:
# 100-999       3204
# 50-99         2508
# 2000-4999     1580
# >10000        1470
# 5000-10000     642
# 1000-1999      483
# Name: participants_category, dtype: int64
#
# 12 null values

# %%
# Convert range in format "a-b" to average(a, b)
def convert_range_to_average(range_string):

    if range_string is np.nan:
        return np.nan

    # Split "x-y" format
    range_list = str.split(range_string, "-")

    if len(range_list) == 1:
        avg = range_list[0].replace("<", "").replace(">", "")

    elif len(range_list) == 2:
        # Convert both "x" and "y" to ints before averaging
        avg = np.mean([int(range_list[0]), int(range_list[1])])

    else:
        raise error

    # Return average
    return int(avg)

# %%
# ----- CREATE 'CONVERTER' DICTIONARY -----
# also create dictionary of 'participant' values that couldn't be converted

# Gather array of unique 'participants' values
participants_unique = df.participants.dropna().unique()

# Create empty dictionaries to hold lookups
converter = {}

# Create dictionary to convert messy strings to ints
# print("COULDN'T CONVERT THE FOLLOWING VALUES:\n")
for participant in participants_unique:

    # Else remove commonly unnecessary characters
    participant_clean = (
        str.lower(participant)
        .replace(",", "")
        .replace("about", "")
        .replace("around", "")
        .replace("over", "")
        .replace("people", "")
        .replace("some", "")
        .replace("estimated", "")
        .replace("protester", "")
        .replace("construction worker", "")
        .replace("member", "")
        .replace("citizen", "")
        .replace("parent", "")
        .replace("local", "")
        .replace("demonstrator", "")
        .replace("teacher", "")
        .replace("activist", "")
        .replace("supporter", "")
        .replace("villager", "")
        .replace("campaign", "")
        .replace("campaigner", "")
        .replace("driver", "")
        .replace("resident", "")
        .replace("participant", "")
        .replace(" of ", "")
        .replace("_", "")
        .replace(" to ", "-")
        .replace(">", "")
        .replace("<", "")
        .replace("+", "")
        .replace("almost", "")
        .replace("more than", "")
        .replace("less than", "")
        .replace("nearly", "")
        .replace("up to", "")
        .replace("at least", "")
        .replace("s", "")
    )
    # Try converting clean value
    try:

        # Append to converter dictionary if successful
        converter[participant] = int(participant_clean)

    # Else convert values of format "x-y"
    except:
        try:

            converter[participant] = convert_range_to_average(
                participant_clean
            )

        # Else create dict to manually clean
        except:
            # print("Couldn't convert: {}  /  {}".format(participant, participant_clean))
            pass

# %%
# Identify the rows that weren't able to be converted using the dict above.
# Estimate whether or not it is practical top use "participants_category"
# to average values within a range and use that value within participants_clean

temp = df[["id", "participants", "participants_category"]].copy()
temp["participants_clean"] = df["participants"].map(
    converter
)  # .astype('Int64')

nas = temp.loc[temp["participants_clean"].isna()]
print("Remaining rows:", nas.shape[0])
print("Examples include:")


nas.sort_values(by="participants").head(100)
# Out:
# Remaining rows: 1291
# Examples include:
#                id                 participants participants_category  \
# 1410   1012017014         "Rocked by protests"               100-999
# 11615  6601992002                            .                   NaN
# 1633   1302005002                            .                   NaN
# 11631  6602002005                            .                   NaN
# 15100  8501999009                            .                   NaN
# ...           ...                          ...                   ...
# 1407   1012017011             Several thousand             2000-4999
# 5487   3432016002             Several thousand            5000-10000
# 14713  8002017001             Several thousand             2000-4999
# 1398   1012017002  Several thousand protesters             2000-4999
# 6737   3651998001            Tens of thousands                >10000
#
#        participants_clean
# 1410                  NaN
# 11615                 NaN
# 1633                  NaN
# 11631                 NaN
# 15100                 NaN
# ...                   ...
# 1407                  NaN
# 5487                  NaN
# 14713                 NaN
# 1398                  NaN
# 6737                  NaN
#
# [100 rows x 4 columns]

# %%
# Apply dictionary to convert original participant counts
counts_converted = df["participants"].map(converter)  # .astype('Int64')

# Create a series to hold the averages converted from the range column
range_as_average = df["participants_category"].apply(convert_range_to_average)

# Choose the count value unless it is NaN, in which case use avg value
chose_non_nan = lambda avg, count: avg if math.isnan(float(count)) else count

# Apply dict
df["participants_clean"] = list(
    map(chose_non_nan, range_as_average, counts_converted)
)
print("Total remaining NaN values:", df["participants_clean"].isna().sum())
# Out:
# Total remaining NaN values: 14

# %%
df.describe()
# Out:
#                  id          year  protest  protestnumber      startday  \
# count  1.523900e+04  15239.000000  15239.0   15239.000000  15239.000000
# mean   4.315571e+09   2006.326465      1.0       8.332633     15.455935
# std    2.343174e+09      8.958007      0.0      12.262761      8.817037
# min    2.019900e+08   1990.000000      1.0       1.000000      1.000000
# 25%    2.201993e+09   1999.000000      1.0       2.000000      8.000000
# 50%    3.852015e+09   2007.000000      1.0       4.000000     15.000000
# 75%    6.452015e+09   2014.000000      1.0      10.000000     23.000000
# max    9.102017e+09   2020.000000      1.0     143.000000     31.000000
#
#          startmonth     startyear        endday      endmonth       endyear  \
# count  15239.000000  15239.000000  15239.000000  15239.000000  15239.000000
# mean       6.227836   2006.326465     15.580616      6.243520   2006.329221
# std        3.461912      8.958007      8.803944      3.461745      8.959254
# min        1.000000   1990.000000      1.000000      1.000000   1990.000000
# 25%        3.000000   1999.000000      8.000000      3.000000   1999.000000
# 50%        6.000000   2007.000000     16.000000      6.000000   2007.000000
# 75%        9.000000   2014.000000     23.000000      9.000000   2014.000000
# max       12.000000   2020.000000     31.000000     12.000000   2020.000000
#
#        protesterviolence  duration_days  participants_clean
# count       15239.000000   15239.000000        1.522500e+04
# mean            0.264781       2.607651        1.546013e+04
# std             0.441231      15.839195        1.138397e+05
# min             0.000000       1.000000        1.000000e+01
# 25%             0.000000       1.000000        1.000000e+02
# 50%             0.000000       1.000000        5.000000e+02
# 75%             1.000000       1.000000        3.000000e+03
# max             1.000000     939.000000        7.000000e+06

# %% [markdown]
# ##### Fill in missing "Participant Categories" values from "Participants" feature

# %%
# Provide conversion from string formats to list formats
dict_str_to_list = {
    "50-99": [50, 99],
    "100-999": [100, 999],
    "2000-4999": [2000, 4999],
    "1000-1999": [1000, 1999],
    "5000-9999": [5000, 9999],
    "10000+": [10000, int(10e12)],
}

dict_str_to_list
# Out:
# {'50-99': [50, 99],
#  '100-999': [100, 999],
#  '2000-4999': [2000, 4999],
#  '1000-1999': [1000, 1999],
#  '5000-9999': [5000, 9999],
#  '10000+': [10000, 10000000000000]}

# %%
# Place each item in a given category
def pick_bucket(x):
    for key in dict_str_to_list:
        lim_low = dict_str_to_list[key][0]
        lim_hi = dict_str_to_list[key][1]

        if (x >= lim_low) and (x <= lim_hi):
            return key
    return np.nan


df["participants_category_manufactured"] = list(
    map(pick_bucket, df["participants_clean"])
)
df["participants_category_manufactured"].value_counts()
# Out:
# 100-999      4754
# 50-99        3475
# 10000+       2564
# 1000-1999    2489
# 2000-4999    1131
# 5000-9999     795
# Name: participants_category_manufactured, dtype: int64

# %% [markdown]
# ##### Now, check if the above categories match the Categories column in df as a QC

# %%
df_participants = df[
    [
        "participants_category",
        "participants",
        "participants_clean",
        "participants_category_manufactured",
    ]
]
df_participants
# Out:
#       participants_category participants  participants_clean  \
# 0                       NaN        1000s              1000.0
# 1                       NaN         1000              1000.0
# 2                       NaN          500               500.0
# 3                       NaN         100s               100.0
# 4                       NaN          950               950.0
# ...                     ...          ...                 ...
# 15234               100-999         100+               100.0
# 15235             1000-1999   About 1000              1000.0
# 15236                 50-99          50+                50.0
# 15237                 50-99          50+                50.0
# 15238               100-999    About 100               100.0
#
#       participants_category_manufactured
# 0                              1000-1999
# 1                              1000-1999
# 2                                100-999
# 3                                100-999
# 4                                100-999
# ...                                  ...
# 15234                            100-999
# 15235                          1000-1999
# 15236                              50-99
# 15237                              50-99
# 15238                            100-999
#
# [15239 rows x 4 columns]

# %% [markdown]
# ##### Find values where the "manufactured" value (created from "Participants" column) is different from the "original" (provided) column

# %%
df_participants.loc[
    (
        df_participants.participants_category
        != df_participants.participants_category_manufactured
    )
    & (~df_participants.participants_category.isna())
    & (df_participants.participants_category != ">10000")
].sort_values(by="participants", ascending=True).value_counts()
# Out:
# participants_category  participants  participants_clean  participants_category_manufactured
# 2000-4999              1000s         1000.0              1000-1999                             879
# 5000-10000             thousands     7500.0              5000-9999                             137
#                        5000          5000.0              5000-9999                             120
#                        10000         10000.0             10000+                                 91
# 100-999                >50           50.0                50-99                                  69
#                                                                                               ...
# 5000-10000             6000-8000     7000.0              5000-9999                               1
#                        6500          6500.0              5000-9999                               1
# 1000-1999              100s-1000s    550.0               100-999                                 1
# 5000-10000             7000-15000    11000.0             10000+                                  1
#                        6000-7000     6500.0              5000-9999                               1
# Length: 84, dtype: int64

# %%
print(df.participants_clean.value_counts())
print("\nNA values:", df.participants_clean.isna().sum())
# Out:
# 50.0       3172
# 100.0      2608
# 1000.0     2316
# 10000.0    1106
# 200.0       452
#            ...
# 950.0         1
# 87.0          1
# 12500.0       1
# 175.0         1
# 525.0         1
# Name: participants_clean, Length: 318, dtype: int64
#
# NA values: 14

# %%
# THIS SHOWS ALL PROTEXTS THAT HAVE EITHER COUNT OR CATEGORY AS MISSING
na_counts = df.loc[
    (df.participants_clean.isna())
    | (df.participants_category_manufactured.isna())
]

print("Shape:", na_counts.participants_category.shape)
display(na_counts)
# Out:
# Shape: (31,)
#                id  year           region  protest  protestnumber  startday  \
# 21      202000004  2000    North America        1              4      16.0
# 585     902005006  2005  Central America        1              6      16.0
# 770     921997001  1997  Central America        1              1      15.0
# 781     922001001  2001  Central America        1              1       1.0
# 783     922003001  2003  Central America        1              1      20.0
# 794     922006004  2006  Central America        1              4       5.0
# 816     931994004  1994  Central America        1              4      23.0
# 1633   1302005002  2005    South America        1              2      13.0
# 11383  6452008002  2008             MENA        1              2      27.0
# 11419  6452013004  2013             MENA        1              4      26.0
# 11470  6511990002  1990             MENA        1              2      29.0
# 11615  6601992002  1992             MENA        1              2      22.0
# 11631  6602002005  2002             MENA        1              5      16.0
# 11793  6702012001  2012             MENA        1              1       9.0
# 12145  7022012004  2012             Asia        1              4       6.0
# 12204  7032011001  2011             Asia        1              1      11.0
# 12216  7032011013  2011             Asia        1             13      21.0
# 12222  7032011019  2011             Asia        1             19      21.0
# 12238  7032012001  2012             Asia        1              1      12.0
# 12252  7032012015  2012             Asia        1             15      23.0
# 12258  7032012021  2012             Asia        1             21      28.0
# 12269  7032012032  2012             Asia        1             32      17.0
# 12275  7032013005  2013             Asia        1              5       6.0
# 12303  7032013033  2013             Asia        1             33       6.0
# 12570  7102011006  2011             Asia        1              6      18.0
# 12975  7321990014  1990             Asia        1             14       8.0
# 13346  7402012002  2012             Asia        1              2      29.0
# 13954  7712011012  2011             Asia        1             12       5.0
# 13993  7712011051  2011             Asia        1             51      13.0
# 15087  8501998019  1998             Asia        1             19       1.0
# 15100  8501999009  1999             Asia        1              9      26.0
#
#        startmonth  startyear  endday  endmonth  endyear  protesterviolence  \
# 21            6.0     2000.0    16.0       6.0   2000.0                1.0
# 585           3.0     2005.0    16.0       3.0   2005.0                1.0
# 770           8.0     1997.0    15.0       8.0   1997.0                0.0
# 781           5.0     2001.0     1.0       5.0   2001.0                0.0
# 783           2.0     2003.0    20.0       2.0   2003.0                1.0
# 794           7.0     2006.0     5.0       7.0   2006.0                1.0
# 816           8.0     1994.0    30.0       8.0   1994.0                1.0
# 1633          4.0     2005.0    13.0       4.0   2005.0                0.0
# 11383         4.0     2008.0    27.0       4.0   2008.0                0.0
# 11419         1.0     2013.0    26.0       1.0   2013.0                1.0
# 11470        11.0     1990.0    29.0      11.0   1990.0                1.0
# 11615         8.0     1992.0    25.0       8.0   1992.0                0.0
# 11631         4.0     2002.0    16.0       4.0   2002.0                0.0
# 11793         3.0     2012.0     9.0       3.0   2012.0                0.0
# 12145         9.0     2012.0     6.0       9.0   2012.0                0.0
# 12204         1.0     2011.0    11.0       1.0   2011.0                0.0
# 12216         4.0     2011.0    21.0       4.0   2011.0                0.0
# 12222         6.0     2011.0    28.0       6.0   2011.0                0.0
# 12238         1.0     2012.0    12.0       1.0   2012.0                0.0
# 12252         3.0     2012.0    23.0       3.0   2012.0                0.0
# 12258         8.0     2012.0    28.0       8.0   2012.0                0.0
# 12269        10.0     2012.0    17.0      10.0   2012.0                0.0
# 12275         2.0     2013.0     6.0       2.0   2013.0                1.0
# 12303        12.0     2013.0     6.0      12.0   2013.0                0.0
# 12570         7.0     2011.0    18.0       7.0   2011.0                1.0
# 12975         6.0     1990.0     8.0       6.0   1990.0                1.0
# 13346         6.0     2012.0    29.0       6.0   2012.0                0.0
# 13954         3.0     2011.0     5.0       3.0   2011.0                0.0
# 13993        11.0     2011.0    13.0      11.0   2011.0                0.0
# 15087         9.0     1998.0     1.0       9.0   1998.0                1.0
# 15100         8.0     1999.0    26.0       8.0   1999.0                1.0
#
#       participants_category             participants  \
# 21                      NaN                      10s
# 585                     NaN                      NaN
# 770                     NaN                      NaN
# 781                     NaN                      NaN
# 783                     NaN                      NaN
# 794                     NaN                      NaN
# 816                     NaN                      NaN
# 1633                    NaN                        .
# 11383                   NaN                       40
# 11419                   NaN                      NaN
# 11470                   NaN                       29
# 11615                   NaN                        .
# 11631                   NaN                        .
# 11793                   NaN                      10s
# 12145                   NaN                      10s
# 12204                   NaN                      10s
# 12216                   NaN                      10s
# 12222                   NaN                      10s
# 12238                   NaN                      10s
# 12252                   NaN                      10s
# 12258                   NaN                      10s
# 12269                   NaN                      10s
# 12275                   NaN                      10s
# 12303                   NaN                      10s
# 12570                   NaN                      10s
# 12975                   NaN                        .
# 13346                   NaN  Between 11000 and 45000
# 13954                   NaN                      10s
# 13993                   NaN                      10s
# 15087                   NaN                        .
# 15100                   NaN                        .
#
#                                        protesteridentity  \
# 21                               anti poverty protesters
# 585                                                  NaN
# 770                                      bank depositors
# 781                            unions, former guerrillas
# 783                         striking health care workers
# 794                                             students
# 816                               transportation workers
# 1633                                             indians
# 11383                              members of parliament
# 11419                                             sunnis
# 11470                                 disgruntled voters
# 11615                                         christians
# 11631                                          hizbullah
# 11793                                    female students
# 12145                     shopkeepers from korvon market
# 12204                     members of patriotic movements
# 12216     united national movement government opposition
# 12222                         supporters of myrza asatov
# 12238            kyrgyz patriotic forces public movement
# 12252                                    the trade union
# 12258  the opposition movement for kyrgyzstan s salva...
# 12269           relatives and supporters of arrested mps
# 12275                     victims of june ethnic clashes
# 12303                                    local residents
# 12570                               uighurs ethnic group
# 12975                                           students
# 13346                                 protestors network
# 13954                             grameen bank employees
# 13993                                     chittagong bnp
# 15087                                             public
# 15100                       anti independence supporters
#
#                   protesterdemand1             protesterdemand2  \
# 21     political behavior, process                          NaN
# 585    political behavior, process                          NaN
# 770    political behavior, process                          NaN
# 781    political behavior, process                          NaN
# 783             labor wage dispute                          NaN
# 794    price increases, tax policy                          NaN
# 816    price increases, tax policy                          NaN
# 1633   political behavior, process                          NaN
# 11383  political behavior, process                          NaN
# 11419        removal of politician                          NaN
# 11470  political behavior, process                          NaN
# 11615  political behavior, process                          NaN
# 11631  political behavior, process                          NaN
# 11793          social restrictions                          NaN
# 12145  political behavior, process                          NaN
# 12204  political behavior, process                          NaN
# 12216  political behavior, process                          NaN
# 12222  political behavior, process                          NaN
# 12238  political behavior, process                          NaN
# 12252           labor wage dispute                          NaN
# 12258              land farm issue  political behavior, process
# 12269  political behavior, process                          NaN
# 12275  political behavior, process                          NaN
# 12303             police brutality                          NaN
# 12570  political behavior, process                          NaN
# 12975           labor wage dispute                          NaN
# 13346  political behavior, process                          NaN
# 13954  political behavior, process             police brutality
# 13993  price increases, tax policy                          NaN
# 15087          social restrictions                          NaN
# 15100  political behavior, process                          NaN
#
#       protesterdemand3 protesterdemand4   stateresponse1 stateresponse2  \
# 21                 NaN              NaN  crowd dispersal        arrests
# 585                NaN              NaN  crowd dispersal            NaN
# 770                NaN              NaN           ignore            NaN
# 781                NaN              NaN           ignore            NaN
# 783                NaN              NaN  crowd dispersal            NaN
# 794                NaN              NaN  crowd dispersal      shootings
# 816                NaN              NaN  crowd dispersal            NaN
# 1633               NaN              NaN  crowd dispersal            NaN
# 11383              NaN              NaN           ignore            NaN
# 11419              NaN              NaN        shootings       killings
# 11470              NaN              NaN        shootings            NaN
# 11615              NaN              NaN           ignore            NaN
# 11631              NaN              NaN           ignore            NaN
# 11793              NaN              NaN  crowd dispersal       beatings
# 12145              NaN              NaN     accomodation            NaN
# 12204              NaN              NaN           ignore            NaN
# 12216              NaN              NaN           ignore            NaN
# 12222              NaN              NaN          arrests            NaN
# 12238              NaN              NaN           ignore            NaN
# 12252              NaN              NaN           ignore            NaN
# 12258              NaN              NaN           ignore            NaN
# 12269              NaN              NaN           ignore            NaN
# 12275              NaN              NaN           ignore            NaN
# 12303              NaN              NaN           ignore            NaN
# 12570              NaN              NaN          arrests      shootings
# 12975              NaN              NaN              NaN            NaN
# 13346              NaN              NaN           ignore            NaN
# 13954              NaN              NaN  crowd dispersal            NaN
# 13993              NaN              NaN           ignore            NaN
# 15087              NaN              NaN         killings            NaN
# 15100              NaN              NaN           ignore            NaN
#
#       stateresponse3 stateresponse4 stateresponse5 stateresponse6  \
# 21               NaN            NaN            NaN            NaN
# 585              NaN            NaN            NaN            NaN
# 770              NaN            NaN            NaN            NaN
# 781              NaN            NaN            NaN            NaN
# 783              NaN            NaN            NaN            NaN
# 794         killings        arrests            NaN            NaN
# 816              NaN            NaN            NaN            NaN
# 1633             NaN            NaN            NaN            NaN
# 11383            NaN            NaN            NaN            NaN
# 11419            NaN            NaN            NaN            NaN
# 11470            NaN            NaN            NaN            NaN
# 11615            NaN            NaN            NaN            NaN
# 11631            NaN            NaN            NaN            NaN
# 11793            NaN            NaN            NaN            NaN
# 12145            NaN            NaN            NaN            NaN
# 12204            NaN            NaN            NaN            NaN
# 12216            NaN            NaN            NaN            NaN
# 12222            NaN            NaN            NaN            NaN
# 12238            NaN            NaN            NaN            NaN
# 12252            NaN            NaN            NaN            NaN
# 12258            NaN            NaN            NaN            NaN
# 12269            NaN            NaN            NaN            NaN
# 12275            NaN            NaN            NaN            NaN
# 12303            NaN            NaN            NaN            NaN
# 12570       killings            NaN            NaN            NaN
# 12975            NaN            NaN            NaN            NaN
# 13346            NaN            NaN            NaN            NaN
# 13954            NaN            NaN            NaN            NaN
# 13993            NaN            NaN            NaN            NaN
# 15087            NaN            NaN            NaN            NaN
# 15100            NaN            NaN            NaN            NaN
#
#       stateresponse7                                            sources  \
# 21               NaN  1. world briefing the new york times, june 16,...
# 585              NaN  world briefing americas: guatemala: protesters...
# 770              NaN  swindled salvadorans demonstrate the philadelp...
# 781              NaN  ap photos associated press international, may ...
# 783              NaN  protesters storm social security building in e...
# 794              NaN  in el salvador, confrontation between police, ...
# 816              NaN  nicaragua: transportation workers call nationa...
# 1633             NaN  bbc monitoring latin america, april 13, 2005, ...
# 11383            NaN  iraq struggle unfolds in peaceful protest and ...
# 11419            NaN  deadly turn in protests against iraqi leadersh...
# 11470            NaN  ny times, nov. 29, 1990 section a; page 12; co...
# 11615            NaN  ny times, august 22, 1992, section 1; page 2; ...
# 11631            NaN  jerusalem post, april 16, 2002, p2. powell war...
# 11793            NaN  woman dies after campus demonstration; religio...
# 12145            NaN  1. shopkeepers protesting after market fire ne...
# 12204            NaN  1. kyrgyz patriots call for national tv channe...
# 12216            NaN  1. kyrgyz opposition demands reform from gover...
# 12222            NaN  1. kyrgyz protesters block road to tajikistan ...
# 12238            NaN  1. kyrgyz protesters against plans to allow fo...
# 12252            NaN  1. kyrgyz trade union members rally against ne...
# 12258            NaN  1. protesters disrupt kyrgyzstan s first minin...
# 12269            NaN  1. supporters of arrested kyrgyz mps hold rall...
# 12275            NaN  1. kyrgyz protesters demand punishment of judg...
# 12303            NaN  1. protesters in kyrgyzstan s north blockade r...
# 12570            NaN  1. china says 18 died in police station attack...
# 12975            NaN  st. petersburg times, june 8, 1990, national; ...
# 13346            NaN  protest rally against noda, oi restarts intens...
# 13954            NaN  the new nation bangladesh ;gb employees protes...
# 13993            NaN  the new nation bangladesh ;bnp s programme the...
# 15087            NaN  sydney morning herald, september 2, 1998, news...
# 15100            NaN  ny times, august 27, 1999, section a; page 12;...
#
#                                                    notes  startdate  \
# 21     anti poverty protesters fought with the police... 2000-06-16
# 585    eighth day of protests over trade agreement wi... 2005-03-16
# 770    protesters demand government refund losses fro... 1997-08-15
# 781    unions and former guerrillas marched in protes... 2001-05-01
# 783    striking health workers stormed el salvador s ... 2003-02-20
# 794    students protested increased prices in public ... 2006-07-05
# 816    transportation workers strike, protesting fuel... 1994-08-23
# 1633                    occupying the education ministry 2005-04-13
# 11383  the latest episode in the struggle between the... 2008-04-27
# 11419  at least seven protesters and two soldiers wer... 2013-01-26
# 11470  the police reported that 29 people were injure... 1990-11-29
# 11615  christian areas of lebanon were paralyzed toda... 1992-08-22
# 11631  hizbullah has stepped up raids on israel since... 2002-04-16
# 11793  one woman died as a result of the attack on pr... 2012-03-09
# 12145  the shopkeepers protested to demand government... 2012-09-06
# 12204  1. protest centered on the demand for the publ... 2011-01-11
# 12216  a united national movement which claims to hav... 2011-04-21
# 12222  the organizers of a road protest in lyaylyak d... 2011-06-21
# 12238  protestors were against allowing foreign compa... 2012-01-12
# 12252  representatives of the trade union are holding... 2012-03-23
# 12258  a group of protestors stormed the sale of lice... 2012-08-28
# 12269  relatives and supporters of the three mps accu... 2012-10-17
# 12275  those who suffered in the june events staged a... 2013-02-06
# 12303  supporters of arrested kyrgyz opposition mp ah... 2013-12-06
# 12570  the chinese government disputes that this was ... 2011-07-18
# 12975  anti government students threw gasoline bombs ... 1990-06-08
# 13346  the protest outside the prime ministercos offi... 2012-06-29
# 13954  grameen bank gb employees on saturday staged d... 2011-03-05
# 13993  the main opposition bnp hasdecided to hold a t... 2011-11-13
# 15087  indonesian security forces opened fire on riot... 1998-09-01
# 15100  opponents of independence for east timor ran w... 1999-08-26
#
#          enddate  duration_days countryname_final scode_final  \
# 21    2000-06-16              1            Canada         CAN
# 585   2005-03-16              1         Guatemala         GUA
# 770   1997-08-15              1       El Salvador         SLV
# 781   2001-05-01              1       El Salvador         SLV
# 783   2003-02-20              1       El Salvador         SLV
# 794   2006-07-05              1       El Salvador         SLV
# 816   1994-08-30              8         Nicaragua         NIC
# 1633  2005-04-13              1           Ecuador         ECU
# 11383 2008-04-27              1              Iraq         IRQ
# 11419 2013-01-26              1              Iraq         IRQ
# 11470 1990-11-29              1             Egypt         EGY
# 11615 1992-08-25              4           Lebanon         LEB
# 11631 2002-04-16              1           Lebanon         LEB
# 11793 2012-03-09              1      Saudi Arabia         SAU
# 12145 2012-09-06              1        Tajikistan         TAJ
# 12204 2011-01-11              1        Kyrgyzstan         KYR
# 12216 2011-04-21              1        Kyrgyzstan         KYR
# 12222 2011-06-28              8        Kyrgyzstan         KYR
# 12238 2012-01-12              1        Kyrgyzstan         KYR
# 12252 2012-03-23              1        Kyrgyzstan         KYR
# 12258 2012-08-28              1        Kyrgyzstan         KYR
# 12269 2012-10-17              1        Kyrgyzstan         KYR
# 12275 2013-02-06              1        Kyrgyzstan         KYR
# 12303 2013-12-06              1        Kyrgyzstan         KYR
# 12570 2011-07-18              1             China         CHN
# 12975 1990-06-08              1             Korea         KOR
# 13346 2012-06-29              1             Japan         JPN
# 13954 2011-03-05              1        Bangladesh         BNG
# 13993 2011-11-13              1        Bangladesh         BNG
# 15087 1998-09-01              1         Indonesia         INS
# 15100 1999-08-26              1         Indonesia         INS
#
#        participants_clean participants_category_manufactured
# 21                   10.0                                NaN
# 585                   NaN                                NaN
# 770                   NaN                                NaN
# 781                   NaN                                NaN
# 783                   NaN                                NaN
# 794                   NaN                                NaN
# 816                   NaN                                NaN
# 1633                  NaN                                NaN
# 11383                40.0                                NaN
# 11419                 NaN                                NaN
# 11470                29.0                                NaN
# 11615                 NaN                                NaN
# 11631                 NaN                                NaN
# 11793                10.0                                NaN
# 12145                10.0                                NaN
# 12204                10.0                                NaN
# 12216                10.0                                NaN
# 12222                10.0                                NaN
# 12238                10.0                                NaN
# 12252                10.0                                NaN
# 12258                10.0                                NaN
# 12269                10.0                                NaN
# 12275                10.0                                NaN
# 12303                10.0                                NaN
# 12570                10.0                                NaN
# 12975                 NaN                                NaN
# 13346                 NaN                                NaN
# 13954                10.0                                NaN
# 13993                10.0                                NaN
# 15087                 NaN                                NaN
# 15100                 NaN                                NaN

# %% [markdown]
# ##### The data manual says that only protests with 50+ people should be included. Below is the set of protests that do not meet that criterion. Drop those rows as outliers since they are inconsistent with the data definitions.

# %%
print("Before setting to NaN:")
display(df.loc[df.participants_clean < 50])

df.loc[df.participants_clean < 50, "participants_clean"] = np.nan
# Out:
# Before setting to NaN:
#                id  year         region  protest  protestnumber  startday  \
# 21      202000004  2000  North America        1              4      16.0
# 11383  6452008002  2008           MENA        1              2      27.0
# 11470  6511990002  1990           MENA        1              2      29.0
# 11793  6702012001  2012           MENA        1              1       9.0
# 12145  7022012004  2012           Asia        1              4       6.0
# 12204  7032011001  2011           Asia        1              1      11.0
# 12216  7032011013  2011           Asia        1             13      21.0
# 12222  7032011019  2011           Asia        1             19      21.0
# 12238  7032012001  2012           Asia        1              1      12.0
# 12252  7032012015  2012           Asia        1             15      23.0
# 12258  7032012021  2012           Asia        1             21      28.0
# 12269  7032012032  2012           Asia        1             32      17.0
# 12275  7032013005  2013           Asia        1              5       6.0
# 12303  7032013033  2013           Asia        1             33       6.0
# 12570  7102011006  2011           Asia        1              6      18.0
# 13954  7712011012  2011           Asia        1             12       5.0
# 13993  7712011051  2011           Asia        1             51      13.0
#
#        startmonth  startyear  endday  endmonth  endyear  protesterviolence  \
# 21            6.0     2000.0    16.0       6.0   2000.0                1.0
# 11383         4.0     2008.0    27.0       4.0   2008.0                0.0
# 11470        11.0     1990.0    29.0      11.0   1990.0                1.0
# 11793         3.0     2012.0     9.0       3.0   2012.0                0.0
# 12145         9.0     2012.0     6.0       9.0   2012.0                0.0
# 12204         1.0     2011.0    11.0       1.0   2011.0                0.0
# 12216         4.0     2011.0    21.0       4.0   2011.0                0.0
# 12222         6.0     2011.0    28.0       6.0   2011.0                0.0
# 12238         1.0     2012.0    12.0       1.0   2012.0                0.0
# 12252         3.0     2012.0    23.0       3.0   2012.0                0.0
# 12258         8.0     2012.0    28.0       8.0   2012.0                0.0
# 12269        10.0     2012.0    17.0      10.0   2012.0                0.0
# 12275         2.0     2013.0     6.0       2.0   2013.0                1.0
# 12303        12.0     2013.0     6.0      12.0   2013.0                0.0
# 12570         7.0     2011.0    18.0       7.0   2011.0                1.0
# 13954         3.0     2011.0     5.0       3.0   2011.0                0.0
# 13993        11.0     2011.0    13.0      11.0   2011.0                0.0
#
#       participants_category participants  \
# 21                      NaN          10s
# 11383                   NaN           40
# 11470                   NaN           29
# 11793                   NaN          10s
# 12145                   NaN          10s
# 12204                   NaN          10s
# 12216                   NaN          10s
# 12222                   NaN          10s
# 12238                   NaN          10s
# 12252                   NaN          10s
# 12258                   NaN          10s
# 12269                   NaN          10s
# 12275                   NaN          10s
# 12303                   NaN          10s
# 12570                   NaN          10s
# 13954                   NaN          10s
# 13993                   NaN          10s
#
#                                        protesteridentity  \
# 21                               anti poverty protesters
# 11383                              members of parliament
# 11470                                 disgruntled voters
# 11793                                    female students
# 12145                     shopkeepers from korvon market
# 12204                     members of patriotic movements
# 12216     united national movement government opposition
# 12222                         supporters of myrza asatov
# 12238            kyrgyz patriotic forces public movement
# 12252                                    the trade union
# 12258  the opposition movement for kyrgyzstan s salva...
# 12269           relatives and supporters of arrested mps
# 12275                     victims of june ethnic clashes
# 12303                                    local residents
# 12570                               uighurs ethnic group
# 13954                             grameen bank employees
# 13993                                     chittagong bnp
#
#                   protesterdemand1             protesterdemand2  \
# 21     political behavior, process                          NaN
# 11383  political behavior, process                          NaN
# 11470  political behavior, process                          NaN
# 11793          social restrictions                          NaN
# 12145  political behavior, process                          NaN
# 12204  political behavior, process                          NaN
# 12216  political behavior, process                          NaN
# 12222  political behavior, process                          NaN
# 12238  political behavior, process                          NaN
# 12252           labor wage dispute                          NaN
# 12258              land farm issue  political behavior, process
# 12269  political behavior, process                          NaN
# 12275  political behavior, process                          NaN
# 12303             police brutality                          NaN
# 12570  political behavior, process                          NaN
# 13954  political behavior, process             police brutality
# 13993  price increases, tax policy                          NaN
#
#       protesterdemand3 protesterdemand4   stateresponse1 stateresponse2  \
# 21                 NaN              NaN  crowd dispersal        arrests
# 11383              NaN              NaN           ignore            NaN
# 11470              NaN              NaN        shootings            NaN
# 11793              NaN              NaN  crowd dispersal       beatings
# 12145              NaN              NaN     accomodation            NaN
# 12204              NaN              NaN           ignore            NaN
# 12216              NaN              NaN           ignore            NaN
# 12222              NaN              NaN          arrests            NaN
# 12238              NaN              NaN           ignore            NaN
# 12252              NaN              NaN           ignore            NaN
# 12258              NaN              NaN           ignore            NaN
# 12269              NaN              NaN           ignore            NaN
# 12275              NaN              NaN           ignore            NaN
# 12303              NaN              NaN           ignore            NaN
# 12570              NaN              NaN          arrests      shootings
# 13954              NaN              NaN  crowd dispersal            NaN
# 13993              NaN              NaN           ignore            NaN
#
#       stateresponse3 stateresponse4 stateresponse5 stateresponse6  \
# 21               NaN            NaN            NaN            NaN
# 11383            NaN            NaN            NaN            NaN
# 11470            NaN            NaN            NaN            NaN
# 11793            NaN            NaN            NaN            NaN
# 12145            NaN            NaN            NaN            NaN
# 12204            NaN            NaN            NaN            NaN
# 12216            NaN            NaN            NaN            NaN
# 12222            NaN            NaN            NaN            NaN
# 12238            NaN            NaN            NaN            NaN
# 12252            NaN            NaN            NaN            NaN
# 12258            NaN            NaN            NaN            NaN
# 12269            NaN            NaN            NaN            NaN
# 12275            NaN            NaN            NaN            NaN
# 12303            NaN            NaN            NaN            NaN
# 12570       killings            NaN            NaN            NaN
# 13954            NaN            NaN            NaN            NaN
# 13993            NaN            NaN            NaN            NaN
#
#       stateresponse7                                            sources  \
# 21               NaN  1. world briefing the new york times, june 16,...
# 11383            NaN  iraq struggle unfolds in peaceful protest and ...
# 11470            NaN  ny times, nov. 29, 1990 section a; page 12; co...
# 11793            NaN  woman dies after campus demonstration; religio...
# 12145            NaN  1. shopkeepers protesting after market fire ne...
# 12204            NaN  1. kyrgyz patriots call for national tv channe...
# 12216            NaN  1. kyrgyz opposition demands reform from gover...
# 12222            NaN  1. kyrgyz protesters block road to tajikistan ...
# 12238            NaN  1. kyrgyz protesters against plans to allow fo...
# 12252            NaN  1. kyrgyz trade union members rally against ne...
# 12258            NaN  1. protesters disrupt kyrgyzstan s first minin...
# 12269            NaN  1. supporters of arrested kyrgyz mps hold rall...
# 12275            NaN  1. kyrgyz protesters demand punishment of judg...
# 12303            NaN  1. protesters in kyrgyzstan s north blockade r...
# 12570            NaN  1. china says 18 died in police station attack...
# 13954            NaN  the new nation bangladesh ;gb employees protes...
# 13993            NaN  the new nation bangladesh ;bnp s programme the...
#
#                                                    notes  startdate  \
# 21     anti poverty protesters fought with the police... 2000-06-16
# 11383  the latest episode in the struggle between the... 2008-04-27
# 11470  the police reported that 29 people were injure... 1990-11-29
# 11793  one woman died as a result of the attack on pr... 2012-03-09
# 12145  the shopkeepers protested to demand government... 2012-09-06
# 12204  1. protest centered on the demand for the publ... 2011-01-11
# 12216  a united national movement which claims to hav... 2011-04-21
# 12222  the organizers of a road protest in lyaylyak d... 2011-06-21
# 12238  protestors were against allowing foreign compa... 2012-01-12
# 12252  representatives of the trade union are holding... 2012-03-23
# 12258  a group of protestors stormed the sale of lice... 2012-08-28
# 12269  relatives and supporters of the three mps accu... 2012-10-17
# 12275  those who suffered in the june events staged a... 2013-02-06
# 12303  supporters of arrested kyrgyz opposition mp ah... 2013-12-06
# 12570  the chinese government disputes that this was ... 2011-07-18
# 13954  grameen bank gb employees on saturday staged d... 2011-03-05
# 13993  the main opposition bnp hasdecided to hold a t... 2011-11-13
#
#          enddate  duration_days countryname_final scode_final  \
# 21    2000-06-16              1            Canada         CAN
# 11383 2008-04-27              1              Iraq         IRQ
# 11470 1990-11-29              1             Egypt         EGY
# 11793 2012-03-09              1      Saudi Arabia         SAU
# 12145 2012-09-06              1        Tajikistan         TAJ
# 12204 2011-01-11              1        Kyrgyzstan         KYR
# 12216 2011-04-21              1        Kyrgyzstan         KYR
# 12222 2011-06-28              8        Kyrgyzstan         KYR
# 12238 2012-01-12              1        Kyrgyzstan         KYR
# 12252 2012-03-23              1        Kyrgyzstan         KYR
# 12258 2012-08-28              1        Kyrgyzstan         KYR
# 12269 2012-10-17              1        Kyrgyzstan         KYR
# 12275 2013-02-06              1        Kyrgyzstan         KYR
# 12303 2013-12-06              1        Kyrgyzstan         KYR
# 12570 2011-07-18              1             China         CHN
# 13954 2011-03-05              1        Bangladesh         BNG
# 13993 2011-11-13              1        Bangladesh         BNG
#
#        participants_clean participants_category_manufactured
# 21                   10.0                                NaN
# 11383                40.0                                NaN
# 11470                29.0                                NaN
# 11793                10.0                                NaN
# 12145                10.0                                NaN
# 12204                10.0                                NaN
# 12216                10.0                                NaN
# 12222                10.0                                NaN
# 12238                10.0                                NaN
# 12252                10.0                                NaN
# 12258                10.0                                NaN
# 12269                10.0                                NaN
# 12275                10.0                                NaN
# 12303                10.0                                NaN
# 12570                10.0                                NaN
# 13954                10.0                                NaN
# 13993                10.0                                NaN

# %% [markdown]
# ##### Show the Participants distribution after cleaning is now complete

# %%
plt.figure()
df["participants_clean"].dropna().sort_values().hist(bins=25)
plt.title("Participant Turnout Hist")

plt.figure()
df["participants_clean"].dropna().sort_values().hist(bins=4000)
plt.xlim([0, 20000])
plt.title("Participant Turnout Hist (Zoomed In)");

# %% [markdown]
# ### Protester Identity
#
# Drop this feature given the extreme number of unique values and lack of standardization

# %%
print(df.protesteridentity.value_counts().head(20))
print("\nUnique values:", df.protesteridentity.unique().shape[0])
df.drop("protesteridentity", axis=1, inplace=True)
# Out:
# protesters                                                         1541
# students                                                            646
# workers                                                             273
# unspecified                                                         224
# farmers                                                             219
# residents                                                           171
# opposition supporters                                               165
# university students                                                 144
# demonstrators                                                       137
# opposition                                                          133
# women                                                               115
# teachers                                                             99
# ladies in white                                                      90
# people                                                               83
# activists                                                            67
# youths                                                               58
# taxi drivers                                                         57
# journalists                                                          54
# pegida patriotic europeans against the islamization of the west      51
# soldiers                                                             51
# Name: protesteridentity, dtype: int64
#
# Unique values: 5785

# %% [markdown]
# ### Protester Demands
#
# There are 7 possible demand categories, as stated by the data dictionary. These features are provided in a difficult to use format and need to instead be one-hot encoded. Currently, there are four column for demands for each protest. There can be 1, 2, 3, or 4 demands, but there is not a dedicated column for each demand. The below process one-hot encodes the data to make it usable in models.

# %%
# Columns to be used for this section
demand_cols = [
    "protesterdemand1",
    "protesterdemand2",
    "protesterdemand3",
    "protesterdemand4",
]

# Print list of demands in each relevant column
for col in demand_cols:
    print(df[col].value_counts())
    print("-----")
# Out:
# political behavior, process    9680
# labor wage dispute             1710
# price increases, tax policy    1087
# removal of politician          1011
# police brutality                825
# land farm issue                 467
# social restrictions             458
# Name: protesterdemand1, dtype: int64
# -----
# political behavior, process    1004
# removal of politician           768
# labor wage dispute              438
# police brutality                241
# price increases, tax policy     214
# social restrictions             212
# land farm issue                 100
# Name: protesterdemand2, dtype: int64
# -----
# price increases, tax policy    111
# removal of politician           94
# political behavior, process     63
# labor wage dispute              61
# police brutality                28
# social restrictions             14
# land farm issue                 12
# Name: protesterdemand3, dtype: int64
# -----
# .                              744
# removal of politician           18
# police brutality                 7
# land farm issue                  3
# political behavior, process      3
# price increases, tax policy      2
# labor wage dispute               2
# Name: protesterdemand4, dtype: int64
# -----

# %%
# Create list of unique demands
demands = np.concatenate(
    [
        df.protesterdemand1.dropna().unique(),
        df.protesterdemand2.dropna().unique(),
        df.protesterdemand3.dropna().unique(),
        df.protesterdemand4.dropna().unique(),
    ]
)
# Verify there are only 7 demands as indicated by data manual
set(demands)
# Out:
# {'.',
#  'labor wage dispute',
#  'land farm issue',
#  'police brutality',
#  'political behavior, process',
#  'price increases, tax policy',
#  'removal of politician',
#  'social restrictions'}

# %%
# Replace '.' with np.nan
for demand_col in demand_cols:
    df[demand_col].replace(".", np.nan, inplace=True)

# %% [markdown]
# ##### Create one-hot encoded columns for each of these demands

# %%
# Instantiate encoder
ohe = OneHotEncoder(sparse=False)

# Loop over all demands
for demand_col in demand_cols:

    # First iteration
    if demand_col == demand_cols[0]:
        fit = ohe.fit_transform(df[demand_col].values.reshape(-1, 1))
        demand_array = np.array(fit)

    # Subsequent iterations
    else:
        fit = ohe.transform(df[demand_col].values.reshape(-1, 1))
        demand_array = np.logical_or(demand_array, fit)


# Clean column names
remove_commas = lambda x: str.replace(x, ", ", "/")
remove_spaces = lambda x: str.replace(x, " ", "-")
col_names = ohe.get_feature_names(["demand"])
col_names = list(map(remove_spaces, map(remove_commas, col_names)))

# Store as dataframe
demand_df = pd.DataFrame(demand_array, dtype="int", columns=col_names)
demand_df.drop("demand_nan", axis=1, inplace=True)

print("\nFinal shape:", demand_df.shape)
print("\nColumn names:", demand_df.columns)
print(
    "\nRequests by type:\n{}".format(
        (demand_df.sum().sort_values(ascending=False))
    )
)
# Out:
# Final shape: (15239, 7)
#
# Column names: Index(['demand_labor-wage-dispute', 'demand_land-farm-issue',
#        'demand_police-brutality', 'demand_political-behavior/process',
#        'demand_price-increases/tax-policy', 'demand_removal-of-politician',
#        'demand_social-restrictions'],
#       dtype='object')
#
# Requests by type:
# demand_political-behavior/process    10750
# demand_labor-wage-dispute             2211
# demand_removal-of-politician          1889
# demand_price-increases/tax-policy     1414
# demand_police-brutality               1101
# demand_social-restrictions             684
# demand_land-farm-issue                 582
# dtype: int64

# %% [markdown]
# ### State responses
#
# These features are stored in the same format as the *protester demands* columns discussed above. The below cells use a similar one-hot encoding loop process to turn the demands into 7 one-hot encoded columns

# %%
# column names containing state response data
response_cols = [
    "stateresponse1",
    "stateresponse2",
    "stateresponse3",
    "stateresponse4",
    "stateresponse5",
    "stateresponse6",
    "stateresponse7",
]

# Replace '.' with np.nan
for col in response_cols:
    df[col].replace(".", np.nan, inplace=True)

# %%
# Verify there are only 7 responses as indicated by data manual
# Create list of unique demands

demands = np.array([])
for col in response_cols:
    demands = np.concatenate([demands, df[col]])
print(set(demands))
# We see that there are 7 demands, plus placeholder '.' and 'nan' values to drop later
# Out:
# {nan, 'arrests', 'beatings', 'shootings', 'accomodation', 'ignore', 'crowd dispersal', 'killings'}

# %%
# Encode each response

# Instantiate enocder
ohe = OneHotEncoder(sparse=False)

# Loop over each response column in the DataFrame
for col in response_cols:

    # First iteration
    if col == response_cols[0]:
        fit = ohe.fit_transform(df[col].values.reshape(-1, 1))
        response_array = np.array(fit)
    else:
        fit = ohe.transform(df[col].values.reshape(-1, 1))
        response_array = np.logical_or(response_array, fit)


print("\nPre-cleaning column names:", ohe.get_feature_names(["response"]))


# # Clean column names
remove_spaces = lambda x: str.replace(x, " ", "-")
col_names = ohe.get_feature_names(["response"])
col_names = list(map(remove_spaces, col_names))
print("\nPost-cleaning column names:", col_names)

# Store as dataframe
response_df = pd.DataFrame(response_array, dtype="int", columns=col_names)
response_df.drop("response_nan", axis=1, inplace=True)

print("\nFinal shape:", response_df.shape)
print("\nColumn names:", response_df.columns)
# Out:
# Pre-cleaning column names: ['response_accomodation' 'response_arrests' 'response_beatings'
#  'response_crowd dispersal' 'response_ignore' 'response_killings'
#  'response_shootings' 'response_nan']
#
# Post-cleaning column names: ['response_accomodation', 'response_arrests', 'response_beatings', 'response_crowd-dispersal', 'response_ignore', 'response_killings', 'response_shootings', 'response_nan']
#
# Final shape: (15239, 7)
#
# Column names: Index(['response_accomodation', 'response_arrests', 'response_beatings',
#        'response_crowd-dispersal', 'response_ignore', 'response_killings',
#        'response_shootings'],
#       dtype='object')

# %% [markdown]
# ### Investigate "sources" and "notes" columns
#
# After close investigation, they are both filled with too many unique, unstandardized values to retain in analysis. Drop each of them.

# %%
print(f"{df.sources.unique().shape[0]} unique values, including:\n")
print(df.sources.value_counts())
df.drop("sources", axis=1, inplace=True)
# Out:
# 14123 unique values, including:
#
# germany s car capital reels as court allows ban on cars the new york times, february 28, 2018 wednesday, section a; column 0; foreign desk; pg. 1, 1583 words, by katrin bennhold ;                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    48
# discontent over migrants takes a toll on east german city the new york times, december 2, 2015 wednesday, section ; column 0; foreign desk; letter from europe; pg. , 680 words, by alison smale angela merkel faces protests on anniversary of german reunification; german chancellor angela merkel s visit to dresden to mark the 26th anniversary of reunification drew protests from far right nationalists who oppose her policy of welcoming refugees. germany cracks down on far right groups with arrests and a trial the new york times, april 20, 2016 wednesday, section a; column 0; foreign desk; pg. 10, 841 words, by alison smale and melissa eddy. follow alison smale on twitter asmalenyt, and melissa eddy meddynyt. the christian science monitor, october 3, 2016 monday, world, 427 words, eva botkin kowacki staff writer;    45
# mr. trump s cuban opportunity. the washington post, january 11, 2017 wednesday regional edition, editorial copy; pg. a18, 551 words ;                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  37
# discontent over migrants takes a toll on east german city the new york times, december 2, 2015 wednesday, section ; column 0; foreign desk; letter from europe; pg. , 680 words, by alison smale;                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      37
# why these catholics plan to protest at pope s cuba visit; a group of catholic protesters were arrested in havana less than a week before a visit from pope francis to cuba. the protesters say the catholic church should do more for their political cause. the christian science monitor, september 14, 2015 monday, world, 537 words, lucy schouten staff;                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          37
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ..
# macron s first day marred by union protests over jobs; france analysis the times london , may 9, 2017 tuesday, news; pg. 30,31, 1166 words, charles bremner ;                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           1
# tunisian civil servants strike, protest for pay raises associated press international november 22, 2018 thursday 2:42 pm gmt, length: 138 words                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         1
# mugabe police beat protesters who had given them flowers the times london , august 18, 2016 thursday, news; pg. 32, 489 words, stuart graham;                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           1
# one killed in madagascar power cut protests agence france presse english, december 23, 2014 tuesday 8:20 am gmt, 185 words ;                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            1
# clashes escalate in yemen; at least 12 protesters are killed the new york times, april 5, 2011 tuesday, section a; column 0; foreign desk; pg. 9, 762 words, by laura kasinof and j. david goodman; laura kasinof reported from sana, and j. david goodman from new york. protesters shot the times london , april 4, 2011 monday, news; pg. 27, 43 words;                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# Name: sources, Length: 14122, dtype: int64

# %%
print(f"{df.notes.unique().shape[0]} unique values, including:\n")
print(df.notes.value_counts())
df.drop("notes", axis=1, inplace=True)
# Out:
# 13922 unique values, including:
#
# general strike                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  116
# just the number of arrest and or injuries                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        53
# but stuttgart, nestled in a basin framed by vineyards and forested hills, also has a long tradition of hiking clubs and solar panels on its rooftops. the city has a green mayor, who drives an electric car, and has been governed by a coalition led by the greens since 2011. it also has a vibrant local environmental movement, which has been protesting a multiyear, multibillion euro project in the heart of the city to move the main train station underground. outraged at the sprawling and polluting building site, known as stuttgart 21, residents have been demonstrating every monday for seven years. this week, on the eve of the diesel ruling, as air pollution measurements reached twice the level permitted under european standards, the 406th protest took place. braving subzero temperatures, mr. resch, the man who filed the driving ban lawsuit, addressed a small but noisy crowd. coded as weekly protests on mondays for entire period.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       48
# coded as weekly protests going back to october of 2014. enough information to code one protest a week with 1,000s of individuals. 2 12 2015 more than one year later, they are still here, the thousands of people who rally every monday under the banner of the pegida movement to vent their rage against muslims, migrants and especially the government of chancellor angela merkel. no further mentions of pegida demonstrations during the year. though there is also no sign that the monday protests stopped. 26 4 2016 dresden, where weekly demonstrations against immigrants have been held since late 2014. 3 10 2016 celebrations marking 26 years since germany s reunification filled the streets of dresden monday, but the mood wasn t all jovial. when german chancellor angela merkel arrived and greeted the people who had gathered, some right wing protestors jeered and shouted traitor and merkel must go, while holding placards bearing the same slogan. at the center of the criticism levied against her and other politicians is merkel s open door refugee policy. dresden, where the celebrations of german unity day took place, is a hotbed of anti migrant sentiment. the anti islam group patriotic europeans against the islamization of the west, known by its german acronym as pegida, is based there. the grassroots movement has held weekly rallies in the city, attracting about 20,000 supporters at their peak in early 2015.     45
# more than one year later, they are still here, the thousands of people who rally every monday under the banner of the pegida movement to vent their rage against muslims, migrants and especially the government of chancellor angela merkel.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    41
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# about three thousand solidarity unionists held three parallel demonstrations in front of the sejm and the cabinet office yesterday dec. 18 . jars with red paint and firecrackers were thrown at the cabinet office, breaking several windows. solidarity s power industry section was the first to begin its demonstration. the unionists picketed the sejm protesting against the new energy law which they believed to be disastrous for poland. marian krzaklewski, solidarity chairman, announced more protests to be held next year unless the situation in the power industry changed. the loudest demonstration was the one held by solidarity unionists from the stocznia gdanska shipyard. in the early afternoon several hundred shipyard workers, accompanied by representatives of coal miners and workers from warsaw s tractor factory ursus, arrived in front of the sejm. marian krzaklewski led them towards the cabinet office. the demonstrators were joined by a group of activists from the movement for the reconstruction of poland rop .                                                                                                                                                                                                                                                                                                                                                                                                                 1
# in a full display of force, panama s indigenous groups have this week seized private and public offices and blocked roads to dramatize protests against the government s indifference to their demand for self rule. dressed for battle and with faces painted, thousands of ngobe, bugle, kuna and embera indians, who make up more than eight percent of panama s 2.4 million people, also demanded lands where they could live and practice their customs and traditions. the situation became even more tense all over the country after the government sent hundreds of anti riot policemen to quell the protests yesterday.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 1
# last wednesday, workers across the country, otherwise known as organized labour, embarked on a nationwide demonstration to drum home their dissatisfaction over the energy sector levies act 2015, as well as hikes in electricity and water tariffs. across the country, from tamale, wa, kumasi, takoradi, ho, sunyani, aflao, cape coast to accra and tema, ghanaian workers, clad in red t shirts and red bands poured onto the streets to demonstrate. the demonstration, according to kofi asamoah, secretary general of the trades union congress tuc was to impress upon the government to come out with practical solution to the problems the two parties government and organized labour had tabled for discussion.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1
# riot police drove off hundreds of demonstrators who gathered at the harare magistrates court monday in support of 13 students arrested during a march through the city last week. the students, from the harare polytechnic, were later freed on bail on charges of public violence allegedly committed after weeks of unrest at both the polytech and the university of zimbabwe.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                1
# about 3,000 taiwanese farmers from across the island yesterday demonstrated in front of the council of agriculture to protest against what they say is the government s failure to take care of their interests. no more sacrifice to farmers, high handed government, shouted the farmers, who were upset by a recent government decision to remove special rural insurance programmes.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          1
# Name: notes, Length: 13921, dtype: int64

# %% [markdown]
# ## Put it all together

# %%
# Take a look at everything that is an option
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15239 entries, 0 to 15238
# Data columns (total 32 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  15239 non-null  int64
#  1   year                                15239 non-null  int64
#  2   region                              15239 non-null  object
#  3   protest                             15239 non-null  int64
#  4   protestnumber                       15239 non-null  int64
#  5   startday                            15239 non-null  float64
#  6   startmonth                          15239 non-null  float64
#  7   startyear                           15239 non-null  float64
#  8   endday                              15239 non-null  float64
#  9   endmonth                            15239 non-null  float64
#  10  endyear                             15239 non-null  float64
#  11  protesterviolence                   15239 non-null  float64
#  12  participants_category               9887 non-null   object
#  13  participants                        15227 non-null  object
#  14  protesterdemand1                    15238 non-null  object
#  15  protesterdemand2                    2977 non-null   object
#  16  protesterdemand3                    383 non-null    object
#  17  protesterdemand4                    35 non-null     object
#  18  stateresponse1                      15208 non-null  object
#  19  stateresponse2                      2888 non-null   object
#  20  stateresponse3                      930 non-null    object
#  21  stateresponse4                      244 non-null    object
#  22  stateresponse5                      53 non-null     object
#  23  stateresponse6                      16 non-null     object
#  24  stateresponse7                      7 non-null      object
#  25  startdate                           15239 non-null  datetime64[ns]
#  26  enddate                             15239 non-null  datetime64[ns]
#  27  duration_days                       15239 non-null  int64
#  28  countryname_final                   15239 non-null  object
#  29  scode_final                         15239 non-null  object
#  30  participants_clean                  15208 non-null  float64
#  31  participants_category_manufactured  15208 non-null  object
# dtypes: datetime64[ns](2), float64(8), int64(5), object(17)
# memory usage: 3.7+ MB

# %%
# Manually select only the features deemed worth keeping based on above analysis
include_cols = [
    "countryname_final",
    "scode_final",
    "region",
    "protestnumber",
    "protesterviolence",
    "startdate",
    "duration_days",
    "participants_clean",
    "participants_category_manufactured",
]

df[include_cols]
# Out:
#       countryname_final scode_final         region  protestnumber  \
# 0                Canada         CAN  North America              1
# 1                Canada         CAN  North America              2
# 2                Canada         CAN  North America              3
# 3                Canada         CAN  North America              4
# 4                Canada         CAN  North America              5
# ...                 ...         ...            ...            ...
# 15234  Papua New Guinea         PNG        Oceania              1
# 15235  Papua New Guinea         PNG        Oceania              1
# 15236  Papua New Guinea         PNG        Oceania              1
# 15237  Papua New Guinea         PNG        Oceania              2
# 15238  Papua New Guinea         PNG        Oceania              3
#
#        protesterviolence  startdate  duration_days  participants_clean  \
# 0                    0.0 1990-01-15              1              1000.0
# 1                    0.0 1990-06-25              1              1000.0
# 2                    0.0 1990-07-01              1               500.0
# 3                    1.0 1990-07-12             57               100.0
# 4                    1.0 1990-08-14              2               950.0
# ...                  ...        ...            ...                 ...
# 15234                1.0 2014-02-16              3               100.0
# 15235                1.0 2016-05-15             26              1000.0
# 15236                0.0 2017-06-15              1                50.0
# 15237                1.0 2017-07-15              1                50.0
# 15238                0.0 2017-10-31              1               100.0
#
#       participants_category_manufactured
# 0                              1000-1999
# 1                              1000-1999
# 2                                100-999
# 3                                100-999
# 4                                100-999
# ...                                  ...
# 15234                            100-999
# 15235                          1000-1999
# 15236                              50-99
# 15237                              50-99
# 15238                            100-999
#
# [15239 rows x 9 columns]

# %% [markdown]
# ### Combine clean dataframe with protester demands and government responses

# %%
df_joined = pd.concat([df[include_cols], demand_df, response_df], axis=1)

# %%
df_joined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15239 entries, 0 to 15238
# Data columns (total 23 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   countryname_final                   15239 non-null  object
#  1   scode_final                         15239 non-null  object
#  2   region                              15239 non-null  object
#  3   protestnumber                       15239 non-null  int64
#  4   protesterviolence                   15239 non-null  float64
#  5   startdate                           15239 non-null  datetime64[ns]
#  6   duration_days                       15239 non-null  int64
#  7   participants_clean                  15208 non-null  float64
#  8   participants_category_manufactured  15208 non-null  object
#  9   demand_labor-wage-dispute           15239 non-null  int32
#  10  demand_land-farm-issue              15239 non-null  int32
#  11  demand_police-brutality             15239 non-null  int32
#  12  demand_political-behavior/process   15239 non-null  int32
#  13  demand_price-increases/tax-policy   15239 non-null  int32
#  14  demand_removal-of-politician        15239 non-null  int32
#  15  demand_social-restrictions          15239 non-null  int32
#  16  response_accomodation               15239 non-null  int32
#  17  response_arrests                    15239 non-null  int32
#  18  response_beatings                   15239 non-null  int32
#  19  response_crowd-dispersal            15239 non-null  int32
#  20  response_ignore                     15239 non-null  int32
#  21  response_killings                   15239 non-null  int32
#  22  response_shootings                  15239 non-null  int32
# dtypes: datetime64[ns](1), float64(2), int32(14), int64(2), object(4)
# memory usage: 1.9+ MB

# %% [markdown]
# ### Fill na values where valuable, drop rows with remaining nas
#
# Below, we see that there are 31 rows with null values. In all cases, it is in the 'participants' category. It is worth dropping these rows entirely since the participant count at a protest is an invaluable field in this analysis.

# %%
display(df_joined.loc[df_joined.isna().any(axis=1)].info())

df_joined.dropna(inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31 entries, 21 to 15100
# Data columns (total 23 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   countryname_final                   31 non-null     object
#  1   scode_final                         31 non-null     object
#  2   region                              31 non-null     object
#  3   protestnumber                       31 non-null     int64
#  4   protesterviolence                   31 non-null     float64
#  5   startdate                           31 non-null     datetime64[ns]
#  6   duration_days                       31 non-null     int64
#  7   participants_clean                  0 non-null      float64
#  8   participants_category_manufactured  0 non-null      object
#  9   demand_labor-wage-dispute           31 non-null     int32
#  10  demand_land-farm-issue              31 non-null     int32
#  11  demand_police-brutality             31 non-null     int32
#  12  demand_political-behavior/process   31 non-null     int32
#  13  demand_price-increases/tax-policy   31 non-null     int32
#  14  demand_removal-of-politician        31 non-null     int32
#  15  demand_social-restrictions          31 non-null     int32
#  16  response_accomodation               31 non-null     int32
#  17  response_arrests                    31 non-null     int32
#  18  response_beatings                   31 non-null     int32
#  19  response_crowd-dispersal            31 non-null     int32
#  20  response_ignore                     31 non-null     int32
#  21  response_killings                   31 non-null     int32
#  22  response_shootings                  31 non-null     int32
# dtypes: datetime64[ns](1), float64(2), int32(14), int64(2), object(4)
# memory usage: 4.1+ KB
# None

# %% [markdown]
# ##### Loop over list of columns to make sure the intended columns have been retained vs. deleted

# %%
keeper_cols = list(df_joined.columns)

for x_val in list(df.columns):
    incl = "include:" if x_val in keeper_cols else "*EXCLUDE*:"
    print(incl, x_val)
# Out:
# *EXCLUDE*: id
# *EXCLUDE*: year
# include: region
# *EXCLUDE*: protest
# include: protestnumber
# *EXCLUDE*: startday
# *EXCLUDE*: startmonth
# *EXCLUDE*: startyear
# *EXCLUDE*: endday
# *EXCLUDE*: endmonth
# *EXCLUDE*: endyear
# include: protesterviolence
# *EXCLUDE*: participants_category
# *EXCLUDE*: participants
# *EXCLUDE*: protesterdemand1
# *EXCLUDE*: protesterdemand2
# *EXCLUDE*: protesterdemand3
# *EXCLUDE*: protesterdemand4
# *EXCLUDE*: stateresponse1
# *EXCLUDE*: stateresponse2
# *EXCLUDE*: stateresponse3
# *EXCLUDE*: stateresponse4
# *EXCLUDE*: stateresponse5
# *EXCLUDE*: stateresponse6
# *EXCLUDE*: stateresponse7
# include: startdate
# *EXCLUDE*: enddate
# include: duration_days
# include: countryname_final
# include: scode_final
# include: participants_clean
# include: participants_category_manufactured

# %% [markdown]
# ## Minor cleanups
#
# ##### Type casting

# %%
df_joined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15208 entries, 0 to 15238
# Data columns (total 23 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   countryname_final                   15208 non-null  object
#  1   scode_final                         15208 non-null  object
#  2   region                              15208 non-null  object
#  3   protestnumber                       15208 non-null  int64
#  4   protesterviolence                   15208 non-null  float64
#  5   startdate                           15208 non-null  datetime64[ns]
#  6   duration_days                       15208 non-null  int64
#  7   participants_clean                  15208 non-null  float64
#  8   participants_category_manufactured  15208 non-null  object
#  9   demand_labor-wage-dispute           15208 non-null  int32
#  10  demand_land-farm-issue              15208 non-null  int32
#  11  demand_police-brutality             15208 non-null  int32
#  12  demand_political-behavior/process   15208 non-null  int32
#  13  demand_price-increases/tax-policy   15208 non-null  int32
#  14  demand_removal-of-politician        15208 non-null  int32
#  15  demand_social-restrictions          15208 non-null  int32
#  16  response_accomodation               15208 non-null  int32
#  17  response_arrests                    15208 non-null  int32
#  18  response_beatings                   15208 non-null  int32
#  19  response_crowd-dispersal            15208 non-null  int32
#  20  response_ignore                     15208 non-null  int32
#  21  response_killings                   15208 non-null  int32
#  22  response_shootings                  15208 non-null  int32
# dtypes: datetime64[ns](1), float64(2), int32(14), int64(2), object(4)
# memory usage: 2.0+ MB

# %%
# Convert relevant columns from float to int
convert_to_int = ["protesterviolence", "participants_clean"]

df.dropna(inplace=True)
for col in convert_to_int:
    df_joined[col] = df_joined[col].astype("int")

df_joined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15208 entries, 0 to 15238
# Data columns (total 23 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   countryname_final                   15208 non-null  object
#  1   scode_final                         15208 non-null  object
#  2   region                              15208 non-null  object
#  3   protestnumber                       15208 non-null  int64
#  4   protesterviolence                   15208 non-null  int32
#  5   startdate                           15208 non-null  datetime64[ns]
#  6   duration_days                       15208 non-null  int64
#  7   participants_clean                  15208 non-null  int32
#  8   participants_category_manufactured  15208 non-null  object
#  9   demand_labor-wage-dispute           15208 non-null  int32
#  10  demand_land-farm-issue              15208 non-null  int32
#  11  demand_police-brutality             15208 non-null  int32
#  12  demand_political-behavior/process   15208 non-null  int32
#  13  demand_price-increases/tax-policy   15208 non-null  int32
#  14  demand_removal-of-politician        15208 non-null  int32
#  15  demand_social-restrictions          15208 non-null  int32
#  16  response_accomodation               15208 non-null  int32
#  17  response_arrests                    15208 non-null  int32
#  18  response_beatings                   15208 non-null  int32
#  19  response_crowd-dispersal            15208 non-null  int32
#  20  response_ignore                     15208 non-null  int32
#  21  response_killings                   15208 non-null  int32
#  22  response_shootings                  15208 non-null  int32
# dtypes: datetime64[ns](1), int32(16), int64(2), object(4)
# memory usage: 1.9+ MB

# %% [markdown]
# ##### Add identifier to cross-reference with other datasets

# %%
# Add identifier
df_joined["year_scode"] = (
    df_joined.startdate.dt.year.astype("str") + "_" + df_joined.scode_final
)

# %% [markdown]
# ##### Rename columns for intuitive names when used externally (outside of this context)

# %%
df_joined.rename(
    columns={
        "participants_clean": "participants",
        "participants_category_manufactured": "participants_category",
        "scode_final": "scode",
        "countryname_final": "country",
    },
    inplace=True,
)
df_joined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15208 entries, 0 to 15238
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   country                            15208 non-null  object
#  1   scode                              15208 non-null  object
#  2   region                             15208 non-null  object
#  3   protestnumber                      15208 non-null  int64
#  4   protesterviolence                  15208 non-null  int32
#  5   startdate                          15208 non-null  datetime64[ns]
#  6   duration_days                      15208 non-null  int64
#  7   participants                       15208 non-null  int32
#  8   participants_category              15208 non-null  object
#  9   demand_labor-wage-dispute          15208 non-null  int32
#  10  demand_land-farm-issue             15208 non-null  int32
#  11  demand_police-brutality            15208 non-null  int32
#  12  demand_political-behavior/process  15208 non-null  int32
#  13  demand_price-increases/tax-policy  15208 non-null  int32
#  14  demand_removal-of-politician       15208 non-null  int32
#  15  demand_social-restrictions         15208 non-null  int32
#  16  response_accomodation              15208 non-null  int32
#  17  response_arrests                   15208 non-null  int32
#  18  response_beatings                  15208 non-null  int32
#  19  response_crowd-dispersal           15208 non-null  int32
#  20  response_ignore                    15208 non-null  int32
#  21  response_killings                  15208 non-null  int32
#  22  response_shootings                 15208 non-null  int32
#  23  year_scode                         15208 non-null  object
# dtypes: datetime64[ns](1), int32(16), int64(2), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# ## Log transformations
#
# For features with extreme outliers that were determined to still be reasonable, log transformations are performed below to create a more "normal" distribution and decrease the impact of outliers.

# %% [markdown]
# #### Participants
# Based on the histogram / distplot, there are clearly substantial outliers. None of these rows should be dropped simply because there is a large number of protesters, even if the values are extreme. Methodology: Log transformation.

# %%
# Calculate the 3 std dev range for reference
max_value = int(
    df_joined.participants.mean() + 3 * df_joined.participants.std()
)
print(
    "Number of values outside 3 std deviations:",
    df_joined.loc[df_joined.participants > max_value].shape[0],
)

# Before log transformation
plt.figure(figsize=(10, 4))
sns.distplot(df_joined.participants)
plt.title("Protest participants (no transformation)")
plt.show()

# After Log transform
df_joined["participants_log"] = np.log(df_joined.participants)
plt.figure(figsize=(10, 4))
sns.distplot(x=df_joined.participants_log)
plt.title("Protest participants (Log transformed)");
# Out:
# Number of values outside 3 std deviations: 142
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %% [markdown]
# #### Protest durations
# As can be seen below, only ~13% of protests last longer than one day. As a result, if we're looking for outliers, the analysis will look at 3 times the standard deviation *after* removing the 1-day protests given how they skew the dataset.
#
# Log transformations are completed here as well.

# %%
print("Protests lasting one day:", (df_joined.duration_days == 1).sum())
print("Protests lasting longer:", (df_joined.duration_days != 1).sum())
print(
    "Percentage lasting longer:",
    (df_joined.duration_days != 1).sum()
    / (df_joined.duration_days != 0).sum(),
)
# Out:
# Protests lasting one day: 13175
# Protests lasting longer: 2033
# Percentage lasting longer: 0.13367964229352972

# %%
# Calculate the 3 std dev range for reference
remove_1_day_protests = df_joined.loc[
    df_joined.duration_days > 1, "duration_days"
]
max_value = int(remove_1_day_protests.mean() + 3 * remove_1_day_protests.std())
print("Number of values outside 3 std deviations:", max_value)

# Plot before transformation
plt.figure(figsize=(8, 4))
sns.distplot(x=df_joined.duration_days)
plt.title("Protest duration (days)")
plt.show()

# Plot after log transformation
df_joined["duration_days_log"] = np.log(df_joined.duration_days)

plt.figure(figsize=(8, 4))
sns.distplot(x=df_joined.duration_days_log)
plt.title("Protest duration (days), Log transformed");
# Out:
# Number of values outside 3 std deviations: 138
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %% [markdown]
# ### Protest number
# Even the largest number of protests in a given year, 143, is very realistic even if it is an extreme outlier. Perform a log transformation to reduce the impact of the outlier.

# %%
# Calculate the 3 std dev range for reference
max_value = int(
    df_joined.protestnumber.mean() + 3 * df_joined.protestnumber.std()
)
print("Max protests per year:", df_joined["protestnumber"].max())
print(
    "Number of values outside 3 std deviations:",
    df_joined.loc[df_joined.protestnumber > max_value].shape[0],
)
sns.distplot(df_joined.protestnumber)


df_joined["protestnumber_log"] = np.log(df_joined.protestnumber)

plt.figure()
sns.distplot(df_joined.protestnumber_log);
# Out:
# Max protests per year: 143
# Number of values outside 3 std deviations: 312
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %% [markdown]
# ### Check for multi-collinearity
# There are no features with a troublesome level of collinearity, as shown by the heatmap, the table showing no co-correlations above 0.75, and the VIFs all below 5.

# %%
calculate_collinearity(df_joined, min_threshold=0.25)
# Out:
# Features with correlation higher than 0.25:
#                                                           cc
# pairs
# (protestnumber, protestnumber)                      1.000000
# (protestnumber_log, protestnumber)                  0.786487
# (response_ignore, response_crowd-dispersal)         0.704829
# (duration_days, duration_days_log)                  0.559469
# (response_shootings, response_killings)             0.543153
# (response_crowd-dispersal, protesterviolence)       0.492648
# (response_ignore, protesterviolence)                0.481695
# (response_ignore, response_arrests)                 0.421115
# (participants_log, participants)                    0.358865
# (demand_labor-wage-dispute, demand_political-be...  0.340976
# (response_accomodation, response_ignore)            0.281526
# (response_ignore, response_shootings)               0.267363
# (response_crowd-dispersal, response_arrests)        0.259886
# (response_arrests, protesterviolence)               0.257654
# (protesterviolence, response_shootings)             0.250764
# (response_ignore, response_killings)                0.250197

# %% [markdown]
# ##### Calculate Variance Inflation Factors (VIFs)
#
# From the correlations above, it is clear that *protestnumber_log* is very strongly correlated with *protestnumber*. This will be taken into account in the modeling notebook, at which point the most valuable feature will be selected and the other dropped.

# %%
# Source: Flatiron School course material
# https://github.com/learn-co-curriculum/dsc-modeling-your-data
numeric = df_joined.drop(
    [
        "country",
        "scode",
        "region",
        "startdate",
        "participants_category",
        "year_scode",
    ],
    axis=1,
)
vif = [
    variance_inflation_factor(numeric.values, i)
    for i in range(numeric.shape[1])
]
list(zip(numeric.columns, vif))
# Out:
# [('protestnumber', 3.8271264022818707),
#  ('protesterviolence', 1.9655329079131332),
#  ('duration_days', 1.5038497398509745),
#  ('participants', 1.1340636519676837),
#  ('demand_labor-wage-dispute', 1.4716432632878538),
#  ('demand_land-farm-issue', 1.123398672126511),
#  ('demand_police-brutality', 1.2273669200511454),
#  ('demand_political-behavior/process', 4.723613297453955),
#  ('demand_price-increases/tax-policy', 1.2428582030739181),
#  ('demand_removal-of-politician', 1.3192428494046233),
#  ('demand_social-restrictions', 1.1171712387133945),
#  ('response_accomodation', 1.4415093859903751),
#  ('response_arrests', 1.4417710537554116),
#  ('response_beatings', 1.150802528170475),
#  ('response_crowd-dispersal', 3.0891288212015198),
#  ('response_ignore', 5.155336159032765),
#  ('response_killings', 1.5612187577998273),
#  ('response_shootings', 1.561201114842301),
#  ('participants_log', 8.043059198343128),
#  ('duration_days_log', 1.765254706809465),
#  ('protestnumber_log', 7.259207892059265)]

# %% [markdown]
# # Export as SQL

# %%
# Response columns are not used in later portions of the analysis because they could lead to data leakage
response_cols = [
    "response_accomodation",
    "response_arrests",
    "response_beatings",
    "response_crowd-dispersal",
    "response_ignore",
    "response_killings",
    "response_shootings",
]

# Drop them
df_joined.drop(response_cols, axis=1, inplace=True)

# %%
# Export
engine = create_engine("sqlite:///../data/processed/protests.db")

with engine.begin() as connection:
    df_joined.to_sql(
        name="protests", con=engine, if_exists="replace", index=False
    )

# %% [markdown]
# #### Final dataset

# %%
display(df_joined.info())
df_joined.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15208 entries, 0 to 15238
# Data columns (total 20 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   country                            15208 non-null  object
#  1   scode                              15208 non-null  object
#  2   region                             15208 non-null  object
#  3   protestnumber                      15208 non-null  int64
#  4   protesterviolence                  15208 non-null  int32
#  5   startdate                          15208 non-null  datetime64[ns]
#  6   duration_days                      15208 non-null  int64
#  7   participants                       15208 non-null  int32
#  8   participants_category              15208 non-null  object
#  9   demand_labor-wage-dispute          15208 non-null  int32
#  10  demand_land-farm-issue             15208 non-null  int32
#  11  demand_police-brutality            15208 non-null  int32
#  12  demand_political-behavior/process  15208 non-null  int32
#  13  demand_price-increases/tax-policy  15208 non-null  int32
#  14  demand_removal-of-politician       15208 non-null  int32
#  15  demand_social-restrictions         15208 non-null  int32
#  16  year_scode                         15208 non-null  object
#  17  participants_log                   15208 non-null  float64
#  18  duration_days_log                  15208 non-null  float64
#  19  protestnumber_log                  15208 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int32(9), int64(2), object(5)
# memory usage: 1.9+ MB
# None
#        protestnumber  protesterviolence  duration_days  participants  \
# count   15208.000000       15208.000000   15208.000000  1.520800e+04
# mean        8.330155           0.264532       2.609811  1.547740e+04
# std        12.264161           0.441098      15.855057  1.139022e+05
# min         1.000000           0.000000       1.000000  5.000000e+01
# 25%         2.000000           0.000000       1.000000  1.000000e+02
# 50%         4.000000           0.000000       1.000000  5.000000e+02
# 75%        10.000000           1.000000       1.000000  3.000000e+03
# max       143.000000           1.000000     939.000000  7.000000e+06
#
#        demand_labor-wage-dispute  demand_land-farm-issue  \
# count               15208.000000            15208.000000
# mean                    0.145187                0.038204
# std                     0.352301                0.191694
# min                     0.000000                0.000000
# 25%                     0.000000                0.000000
# 50%                     0.000000                0.000000
# 75%                     0.000000                0.000000
# max                     1.000000                1.000000
#
#        demand_police-brutality  demand_political-behavior/process  \
# count             15208.000000                       15208.000000
# mean                  0.072265                           0.705484
# std                   0.258934                           0.455840
# min                   0.000000                           0.000000
# 25%                   0.000000                           0.000000
# 50%                   0.000000                           1.000000
# 75%                   0.000000                           1.000000
# max                   1.000000                           1.000000
#
#        demand_price-increases/tax-policy  demand_removal-of-politician  \
# count                       15208.000000                  15208.000000
# mean                            0.092780                      0.124145
# std                             0.290134                      0.329758
# min                             0.000000                      0.000000
# 25%                             0.000000                      0.000000
# 50%                             0.000000                      0.000000
# 75%                             0.000000                      0.000000
# max                             1.000000                      1.000000
#
#        demand_social-restrictions  participants_log  duration_days_log  \
# count                15208.000000      15208.000000       15208.000000
# mean                     0.044845          6.414935           0.217949
# std                      0.206970          2.291926           0.684430
# min                      0.000000          3.912023           0.000000
# 25%                      0.000000          4.605170           0.000000
# 50%                      0.000000          6.214608           0.000000
# 75%                      0.000000          8.006368           0.000000
# max                      1.000000         15.761421           6.844815
#
#        protestnumber_log
# count       15208.000000
# mean            1.487411
# std             1.090895
# min             0.000000
# 25%             0.693147
# 50%             1.386294
# 75%             2.302585
# max             4.962845

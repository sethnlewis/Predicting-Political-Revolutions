# %% [markdown]
# ### Exploratory Analysis - Mass Mobilization Protests

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as sk
import os, sys
import math

from sklearn.preprocessing import OneHotEncoder

from sqlalchemy import create_engine


pd.options.display.max_columns = 100
pd.options.display.max_rows = 300

path_data = os.path.join('..', 'data', 'raw')

UNKNOWN = 'unknown'

# %%
path_csv = os.path.join(path_data, 'Mass-Mobilization-Protests', 'mmALL_073120_csv.csv')
df = pd.read_csv(path_csv)

# %%
df.loc[23]
# Out:
# id                                                               202000004
# country                                                             Canada
# ccode                                                                   20
# year                                                                  2000
# region                                                       North America
# protest                                                                  1
# protestnumber                                                            4
# startday                                                              16.0
# startmonth                                                             6.0
# startyear                                                           2000.0
# endday                                                                16.0
# endmonth                                                               6.0
# endyear                                                             2000.0
# protesterviolence                                                      1.0
# location                                                  Toronto, Ontario
# participants_category                                                  NaN
# participants                                                           10s
# protesteridentity                                  anti poverty protesters
# protesterdemand1                               political behavior, process
# protesterdemand2                                                       NaN
# protesterdemand3                                                       NaN
# protesterdemand4                                                       NaN
# stateresponse1                                             crowd dispersal
# stateresponse2                                                     arrests
# stateresponse3                                                         NaN
# stateresponse4                                                         NaN
# stateresponse5                                                         NaN
# stateresponse6                                                         NaN
# stateresponse7                                                         NaN
# sources                  1. world briefing the new york times, june 16,...
# notes                    anti poverty protesters fought with the police...
# Name: 23, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17145 entries, 0 to 17144
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     17145 non-null  int64
#  1   country                17145 non-null  object
#  2   ccode                  17145 non-null  int64
#  3   year                   17145 non-null  int64
#  4   region                 17145 non-null  object
#  5   protest                17145 non-null  int64
#  6   protestnumber          17145 non-null  int64
#  7   startday               15239 non-null  float64
#  8   startmonth             15239 non-null  float64
#  9   startyear              15239 non-null  float64
#  10  endday                 15239 non-null  float64
#  11  endmonth               15239 non-null  float64
#  12  endyear                15239 non-null  float64
#  13  protesterviolence      15758 non-null  float64
#  14  location               15218 non-null  object
#  15  participants_category  9887 non-null   object
#  16  participants           15746 non-null  object
#  17  protesteridentity      14684 non-null  object
#  18  protesterdemand1       15238 non-null  object
#  19  protesterdemand2       2977 non-null   object
#  20  protesterdemand3       383 non-null    object
#  21  protesterdemand4       831 non-null    object
#  22  stateresponse1         15208 non-null  object
#  23  stateresponse2         2888 non-null   object
#  24  stateresponse3         930 non-null    object
#  25  stateresponse4         244 non-null    object
#  26  stateresponse5         849 non-null    object
#  27  stateresponse6         16 non-null     object
#  28  stateresponse7         920 non-null    object
#  29  sources                15235 non-null  object
#  30  notes                  15193 non-null  object
# dtypes: float64(7), int64(5), object(19)
# memory usage: 4.1+ MB

# %%
def print_counts(series):
    unique = series.value_counts()
    return unique

# %%
print_counts(df.id)
# Out:
# 512000000     1
# 4502005006    1
# 2202017017    1
# 2001995002    1
# 1352011003    1
#              ..
# 2202002009    1
# 2001998017    1
# 4901991003    1
# 6402014010    1
# 701995005     1
# Name: id, Length: 17145, dtype: int64

# %% [markdown]
# ### Country names codes
#
# Make consistent with other data sources to enable merging. Minor differences in spelling, abbreviations, casing, etc. make this necessary. Process completed in simple Excel file for simplicity. Import that lookup table to convert to new naming schemes.

# %%
df_naming_lookup = pd.read_excel('../src/country_codes_protests.xlsx')
renaming_dict = dict(zip(df_naming_lookup.ccode.values, df_naming_lookup.country_final))
scode_dict = dict(zip(df_naming_lookup.ccode.values, df_naming_lookup.scode_final))

df['scode_final'] = df.ccode.map(scode_dict)
df['countryname_final'] = df.ccode.map(renaming_dict)
display(df[['ccode', 'country', 'countryname_final', 'scode_final']].drop_duplicates())
df.drop(['ccode', 'country'], axis=1, inplace=True)
# Out:
#        ccode                   country         countryname_final scode_final
# 0         20                    Canada                    Canada         CAN
# 60        40                      Cuba                      Cuba         CUB
# 182       41                     Haiti                     Haiti         HAI
# 306       42        Dominican Republic        Dominican Republic         DOM
# 389       51                   Jamaica                   Jamaica         JAM
# 434       70                    Mexico                    Mexico         MEX
# 587       90                 Guatemala                 Guatemala         GUA
# 704       91                  Honduras                  Honduras         HON
# 820       92               El Salvador               El Salvador         SAL
# 886       93                 Nicaragua                 Nicaragua         NIC
# 979       94                Costa Rica                Costa Rica         COS
# 1032      95                    Panama                    Panama         PAN
# 1090     100                  Colombia                  Colombia         COL
# 1231     101                 Venezuela                 Venezuela         VEN
# 1550     110                    Guyana                    Guyana         GUY
# 1599     115                  Suriname                  Suriname         SUR
# 1664     130                   Ecuador                   Ecuador         ECU
# 1829     135                      Peru                      Peru         PER
# 1996     140                    Brazil                    Brazil         BRA
# 2220     145                   Bolivia                   Bolivia         BOL
# 2364     150                  Paraguay                  Paraguay         PAR
# 2436     155                     Chile                     Chile         CHL
# 2608     160                 Argentina                 Argentina         ARG
# 2726     165                   Uruguay                   Uruguay         URU
# 2803     200            United Kingdom            United Kingdom         UKG
# 3381     205                   Ireland                   Ireland         IRE
# 3819     210               Netherlands               Netherlands         NTH
# 3854     211                   Belgium                   Belgium         BEL
# 3911     212                Luxembourg                Luxembourg         LUX
# 3943     220                    France                    France         FRN
# 4490     225               Switzerland               Switzerland         SWZ
# 4524     230                     Spain                     Spain         SPN
# 4694     235                  Portugal                  Portugal         POR
# 4742     255                   Germany                   Germany         GMY
# 5106     260              Germany West              Germany West         GFR
# 5108     265              Germany East              Germany East         GDR
# 5119     290                    Poland                    Poland         POL
# 5246     305                   Austria                   Austria         AUS
# 5277     310                   Hungary                   Hungary         HUN
# 5356     315            Czechoslovakia            Czechoslovakia         CZE
# 5362     316            Czech Republic            Czech Republic         CZR
# 5409     317           Slovak Republic           Slovak Republic         SLO
# 5465     325                     Italy                     Italy         ITA
# 5633     339                   Albania                   Albania         ALB
# 5726     341                    Kosovo                    Kosovo         KOS
# 5749     342                    Serbia                    Serbia         SER
# 5787     343                 Macedonia                 Macedonia         MAC
# 5877     344                   Croatia                   Croatia         CRO
# 5920     345                Yugoslavia                Yugoslavia         YGS
# 5956     346                    Bosnia                    Bosnia         BOS
# 6012     347                Yugoslavia                Yugoslavia         YGS
# 6114     347     Serbia and Montenegro                Yugoslavia         YGS
# 6119     348                Montenegro                Montenegro         MNT
# 6139     349                  Slovenia                  Slovenia         SLV
# 6179     350                    Greece                    Greece         GRC
# 6494     352                    Cyprus                    Cyprus         CYP
# 6636     355                  Bulgaria                  Bulgaria         BUL
# 6768     359                   Moldova                   Moldova         MLD
# 6882     360                   Romania                   Romania         RUM
# 7108     364                      USSR                      USSR         USR
# 7168     365                    Russia                    Russia         RUS
# 7373     366                   Estonia                   Estonia         EST
# 7437     367                    Latvia                    Latvia         LAT
# 7535     368                 Lithuania                 Lithuania         LIT
# 7588     369                   Ukraine                   Ukraine         UKR
# 7746     370                   Belarus                   Belarus         BLR
# 7826     371                   Armenia                   Armenia         ARM
# 7934     372                   Georgia                   Georgia         GRG
# 8001     373                Azerbaijan                Azerbaijan         AZE
# 8133     375                   Finland                   Finland         FIN
# 8169     380                    Sweden                    Sweden         SWD
# 8206     385                    Norway                    Norway         NOR
# 8238     390                   Denmark                   Denmark         DEN
# 8272     402                Cape Verde                Cape Verde         CAP
# 8304     404             Guinea-Bissau             Guinea-Bissau         GNB
# 8353     411         Equatorial Guinea         Equatorial Guinea         EQG
# 8384     420                    Gambia                    Gambia         GAM
# 8427     432                      Mali                      Mali         MLI
# 8491     433                   Senegal                   Senegal         SEN
# 8550     434                     Benin                     Benin         BEN
# 8621     435                Mauritania                Mauritania         MAA
# 8712     436                     Niger                     Niger         NIR
# 8826     437               Ivory Coast             Cote D'Ivoire         IVO
# 8946     438                    Guinea                    Guinea         GUI
# 9065     439              Burkina Faso              Burkina Faso         BFO
# 9145     450                   Liberia                   Liberia         LBR
# 9223     451              Sierra Leone              Sierra Leone         SIE
# 9274     452                     Ghana                     Ghana         GHA
# 9351     461                      Togo                      Togo         TOG
# 9453     471                  Cameroon                  Cameroon         CAO
# 9523     475                   Nigeria                   Nigeria         NIG
# 9697     481                     Gabon                     Gabon         GAB
# 9745     482  Central African Republic  Central African Republic         CEN
# 9814     483                      Chad                      Chad         CHA
# 9853     484         Congo Brazzaville         Congo-Brazzaville         CON
# 9905     490            Congo Kinshasa            Congo Kinshasa         ZAI
# 9990     500                    Uganda                    Uganda         UGA
# 10064    501                     Kenya                     Kenya         KEN
# 10417    510                  Tanzania                  Tanzania         TAZ
# 10471    516                   Burundi                   Burundi         BUI
# 10581    517                    Rwanda                    Rwanda         RWA
# 10617    520                   Somalia                   Somalia         SOM
# 10659    522                  Djibouti                  Djibouti         DJI
# 10691    525               South Sudan               South Sudan         SSU
# 10701    529                  Ethiopia                  Ethiopia         ETI
# 10714    530                  Ethiopia                  Ethiopia         ETI
# 10752    531                   Eritrea                   Eritrea         ERI
# 10783    540                    Angola                    Angola         ANG
# 10821    541                Mozambique                Mozambique         MZM
# 10903    551                    Zambia                    Zambia         ZAM
# 11002    552                  Zimbabwe                  Zimbabwe         ZIM
# 11121    553                    Malawi                    Malawi         MAW
# 11193    560              South Africa              South Africa         SAF
# 11370    565                   Namibia                   Namibia         NAM
# 11604    570                   Lesotho                   Lesotho         LES
# 11654    571                  Botswana                  Botswana         BOT
# 11705    572                 Swaziland                 Swaziland         SWA
# 11813    580                Madagascar                Madagascar         MAG
# 11935    581                   Comoros                   Comoros         COM
# 12027    590                 Mauritius                 Mauritius         MAS
# 12062    600                   Morocco                   Morocco         MOR
# 12119    615                   Algeria                   Algeria         ALG
# 12241    616                   Tunisia                   Tunisia         TUN
# 12304    620                     Libya                     Libya         LIB
# 12350    625                     Sudan                     Sudan         SUD
# 12434    630                      Iran                      Iran         IRN
# 12562    640                    Turkey                    Turkey         TUR
# 12696    645                      Iraq                      Iraq         IRQ
# 12831    651                     Egypt                     Egypt         EGY
# 12968    652                     Syria                     Syria         SYR
# 13007    660                   Lebanon                   Lebanon         LEB
# 13138    663                    Jordan                    Jordan         JOR
# 13202    670              Saudi Arabia              Saudi Arabia         SAU
# 13245    678                     Yemen               Yemen North         YAR
# 13250    679                     Yemen                     Yemen         YEM
# 13411    690                    Kuwait                    Kuwait         KUW
# 13468    692                   Bahrain                   Bahrain         BAH
# 13532    694                     Qatar                     Qatar         QAT
# 13563    696       United Arab Emirate      United Arab Emirates         UAE
# 13594    698                      Oman                      Oman         OMA
# 13647    700               Afghanistan               Afghanistan         AFG
# 13703    701              Turkmenistan              Turkmenistan         TKM
# 13734    702                Tajikistan                Tajikistan         TAJ
# 13785    703                Kyrgyzstan                Kyrgyzstan         KYR
# 13958    704                Uzbekistan                Uzbekistan         UZB
# 14013    705                Kazakhstan                Kazakhstan         KZK
# 14106    710                     China                     China         CHN
# 14427    712                  Mongolia                  Mongolia         MON
# 14490    713                    Taiwan                    Taiwan         TAW
# 14640    731               North Korea               Korea North         PRK
# 14672    732               South Korea               Korea South         ROK
# 15020    740                     Japan                     Japan         JPN
# 15091    750                     India                     India         IND
# 15319    760                    Bhutan                    Bhutan         BHU
# 15350    770                  Pakistan                  Pakistan         PAK
# 15528    771                Bangladesh                Bangladesh         BNG
# 15871    775                   Myanmar           Myanmar (Burma)         MYA
# 15969    780                 Sri Lanka                 Sri Lanka         SRI
# 16053    790                     Nepal                     Nepal         NEP
# 16268    800                  Thailand                  Thailand         THI
# 16525    811                  Cambodia                  Cambodia         CAM
# 16590    812                      Laos                      Laos         LAO
# 16621    816                   Vietnam             Vietnam North         DRV
# 16657    820                  Malaysia                  Malaysia         MAL
# 16809    830                 Singapore                 Singapore         SIN
# 16848    840               Philippines               Philippines         PHI
# 16920    850                 Indonesia                 Indonesia         INS
# 17073    860               Timor Leste               Timor Leste         ETM
# 17095    910          Papua New Guinea          Papua New Guinea         PNG

# %%
# year = df.year.unique()
# year.sort()
# print(year)

# print_counts(df.year)

# %%
# print_counts(df.region)

# %%
# print_counts(df.protest)

# %%
# print_counts(df.protestnumber)

# %%
# print(df.loc[df.protestnumber == 0].protesterdemand1.value_counts())
# print(df.loc[df.protestnumber == 0].stateresponse1.value_counts())
# print(df.loc[df.protestnumber == 0].notes.value_counts())

# %%
df = df.loc[df.protest == 1].copy()
df.reset_index(inplace=True, drop=True)

# %% [markdown]
# ##### Notes: drop all rows with df.protest == 0. This means no protest took place, which can be verified by investigating a sample of those entries. Since this analysis studies only protests, non-protest entries are not of interest.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15239 entries, 0 to 15238
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     15239 non-null  int64
#  1   year                   15239 non-null  int64
#  2   region                 15239 non-null  object
#  3   protest                15239 non-null  int64
#  4   protestnumber          15239 non-null  int64
#  5   startday               15239 non-null  float64
#  6   startmonth             15239 non-null  float64
#  7   startyear              15239 non-null  float64
#  8   endday                 15239 non-null  float64
#  9   endmonth               15239 non-null  float64
#  10  endyear                15239 non-null  float64
#  11  protesterviolence      15239 non-null  float64
#  12  location               15218 non-null  object
#  13  participants_category  9887 non-null   object
#  14  participants           15227 non-null  object
#  15  protesteridentity      14684 non-null  object
#  16  protesterdemand1       15238 non-null  object
#  17  protesterdemand2       2977 non-null   object
#  18  protesterdemand3       383 non-null    object
#  19  protesterdemand4       779 non-null    object
#  20  stateresponse1         15208 non-null  object
#  21  stateresponse2         2888 non-null   object
#  22  stateresponse3         930 non-null    object
#  23  stateresponse4         244 non-null    object
#  24  stateresponse5         797 non-null    object
#  25  stateresponse6         16 non-null     object
#  26  stateresponse7         857 non-null    object
#  27  sources                15235 non-null  object
#  28  notes                  15193 non-null  object
#  29  scode_final            15239 non-null  object
#  30  countryname_final      15239 non-null  object
# dtypes: float64(7), int64(4), object(20)
# memory usage: 3.6+ MB

# %% [markdown]
# # Convert 'Start' and 'End' data to their own datetime columns

# %%
# For start date
start_date = df[['startyear', 'startmonth', 'startday']]
start_date.columns = ['year', 'month', 'day']
df['start_datetime'] = pd.to_datetime(start_date)

# For end date
end_date = df[['endyear', 'endmonth', 'endday']]
end_date.columns = ['year', 'month', 'day']
df['end_datetime'] = pd.to_datetime(end_date)


# Duration
df['duration_days'] = (df.end_datetime - df.start_datetime).dt.days


# Display resulting dataframe info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15239 entries, 0 to 15238
# Data columns (total 34 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     15239 non-null  int64
#  1   year                   15239 non-null  int64
#  2   region                 15239 non-null  object
#  3   protest                15239 non-null  int64
#  4   protestnumber          15239 non-null  int64
#  5   startday               15239 non-null  float64
#  6   startmonth             15239 non-null  float64
#  7   startyear              15239 non-null  float64
#  8   endday                 15239 non-null  float64
#  9   endmonth               15239 non-null  float64
#  10  endyear                15239 non-null  float64
#  11  protesterviolence      15239 non-null  float64
#  12  location               15218 non-null  object
#  13  participants_category  9887 non-null   object
#  14  participants           15227 non-null  object
#  15  protesteridentity      14684 non-null  object
#  16  protesterdemand1       15238 non-null  object
#  17  protesterdemand2       2977 non-null   object
#  18  protesterdemand3       383 non-null    object
#  19  protesterdemand4       779 non-null    object
#  20  stateresponse1         15208 non-null  object
#  21  stateresponse2         2888 non-null   object
#  22  stateresponse3         930 non-null    object
#  23  stateresponse4         244 non-null    object
#  24  stateresponse5         797 non-null    object
#  25  stateresponse6         16 non-null     object
#  26  stateresponse7         857 non-null    object
#  27  sources                15235 non-null  object
#  28  notes                  15193 non-null  object
#  29  scode_final            15239 non-null  object
#  30  countryname_final      15239 non-null  object
#  31  start_datetime         15239 non-null  datetime64[ns]
#  32  end_datetime           15239 non-null  datetime64[ns]
#  33  duration_days          15239 non-null  int64
# dtypes: datetime64[ns](2), float64(7), int64(5), object(20)
# memory usage: 4.0+ MB

# %% [markdown]
# ### Is "year" column the same as "startyear" column?

# %%
df.loc[df.year != df.startyear]
# Out:
# Empty DataFrame
# Columns: [id, year, region, protest, protestnumber, startday, startmonth, startyear, endday, endmonth, endyear, protesterviolence, location, participants_category, participants, protesteridentity, protesterdemand1, protesterdemand2, protesterdemand3, protesterdemand4, stateresponse1, stateresponse2, stateresponse3, stateresponse4, stateresponse5, stateresponse6, stateresponse7, sources, notes, scode_final, countryname_final, start_datetime, end_datetime, duration_days]
# Index: []

# %% [markdown]
# ##### Yes, it is. Exclude it from final clean dataframe

# %% [markdown]
# # Create column for Duration

# %%
# print_counts(df.startday)

# %%
# print_counts(df.startmonth)

# %%
# print_counts(df.startyear)

# %%
# print_counts(df.endday)

# %%
# print_counts(df.endmonth)

# %%
# print_counts(df.endyear)

# %%
# print_counts(df.protesterviolence)

# %%
# df.location.value_counts().shape

# %% [markdown]
# ##### 'Locations' column isn't at all standardized. Avoid using unless absolutely necessary. The 'Country' column should provide the necessary information for an MVP.
#
# Fill na's with UNKNOWN

# %%
df['location'] = df.location.fillna(UNKNOWN)

# %%
# df.info()

# %%
# df.participants.isna()

# %%
# #print(df.participants_category.value_counts())
# df.loc[df.participants.isna()]

# %% [markdown]
# ### Fill in missing "Participants Category" value using the "Participants" column.
# This takes some manual  changes. Everything that can be changed from string to int is done automatically. Everything that can't be done automatically is added to a dictionary to be done manually. This *drastically* reduces any need for manual work

# %%
# Convert range in format "a-b" to average(a, b)
def convert_range_to_average(range_string):

    if range_string is np.nan:
        return np.nan
    
    # Split "x-y" format
    range_list = str.split(range_string, '-')
    
    if len(range_list)==1:
        avg = range_list[0].replace('<', '').replace('>', '')
    
    elif len(range_list)==2:
        # Convert both "x" and "y" to ints before averaging
        avg = np.mean([int(range_list[0]), int(range_list[1])])
    
    else:
        raise error

    # Return average
    return int(avg)

# %%
# ----- CREATE 'CONVERTER' DICTIONARY -----
# also create dictionary of 'participant' values that couldn't be converted

# Gather array of unique 'participants' values
participants_unique = df.participants.dropna().unique()

# Create empty dictionaries to hold lookups
converter = {}

# Create dictionary to convert messy strings to ints
#print("COULDN'T CONVERT THE FOLLOWING VALUES:\n")
for participant in participants_unique:

    # Else remove commonly unnecessary characters
    participant_clean = str.lower(participant)\
                           .replace(',', '')\
                           .replace('about', '')\
                           .replace('around', '')\
                           .replace('over', '')\
                           .replace('people', '')\
                           .replace('some', '')\
                           .replace('estimated', '')\
                           .replace('protester', '')\
                           .replace('construction worker', '')\
                           .replace('member', '')\
                           .replace('citizen', '')\
                           .replace('parent', '')\
                           .replace('local', '')\
                           .replace('demonstrator', '')\
                           .replace('teacher', '')\
                           .replace('activist', '')\
                           .replace('supporter', '')\
                           .replace('villager', '')\
                           .replace('campaign', '')\
                           .replace('campaigner', '')\
                           .replace('driver', '')\
                           .replace('resident', '')\
                           .replace('participant', '')\
                           .replace(' of ', '')\
                           .replace('_', '')\
                           .replace(' to ', '-')\
                           .replace('>', '')\
                           .replace('<', '')\
                           .replace('+', '')\
                           .replace('almost','')\
                           .replace('more than','')\
                           .replace('less than', '')\
                           .replace('nearly', '')\
                           .replace('up to', '')\
                           .replace('at least', '')\
                           .replace('s', '')
    # Try converting clean value
    try:

        # Append to converter dictionary if successful
        converter[participant] = int(participant_clean)

    # Else convert values of format "x-y"
    except:
        try:

            converter[participant] = convert_range_to_average(participant_clean)

        # Else create dict to manually clean
        except:
            #print("Couldn't convert: {}  /  {}".format(participant, participant_clean))
            pass

# %%
# Identify the rows that weren't able to be converted using the dict above. 
# Estimate whether or not it is practical top use "participants_category"
# to average values within a range and use that value within participants_clean

temp = df[['id', 'participants', 'participants_category']].copy()
temp['participants_clean'] = df['participants'].map(converter)#.astype('Int64')

nas = temp.loc[temp['participants_clean'].isna()]
print('Remaining rows:', nas.shape[0])
print('Examples include:')


nas.sort_values(by='participants').head(100)
# Out:
# Remaining rows: 1291
# Examples include:
#                id                                       participants  \
# 1410   1012017014                               "Rocked by protests"
# 11615  6601992002                                                  .
# 1633   1302005002                                                  .
# 11631  6602002005                                                  .
# 15100  8501999009                                                  .
# 12975  7321990014                                                  .
# 15087  8501998019                                                  .
# 6651   3641990010                                          1 million
# 11442  6452017003                                        100 wounded
# 11588  6512017001                                        12 arrested
# 1469   1102016001                                          16 killed
# 887     932019002                                       164 arrested
# 1392   1012016006                                        20 arrested
# 6880   3652017014                                       200 arrested
# 515     702017004                                       230 families
# 2033   1402016002                              25 protesters injured
# 5260   3252016003                                     28 LGBT groups
# 12686  7102017005                                        30 arrested
# 1396   1012016010                                       300 arrested
# 12432  7052019003                                      4000 arrested
# 7584   3732018002                                        50 arrested
# 14935  8202016008                           57 former estate workers
# 14718  8002018001                            97 public organisations
# 6909   3661998002                                        > 50 < 100
# 13301  7322018002                                      A few hundred
# 8385   4502017005                                      A few hundred
# 14087  7712017001                                      A few hundred
# 1416   1012017020                               A few hundred people
# 1414   1012017018          A general strike that paralysed Venezuela
# 14719  8002018002  About 100 activists, including 39 suspects who...
# 12674  7102016018                                    About 100 taxis
# 1417   1012017021                         About a hundred protesters
# 13748  7702016002                       As many as 25,000 protesters
# 13346  7402012002                            Between 11000 and 45000
# 13547  7502017009                                 Civilians; a crowd
# 13540  7502017002                                             Crowds
# 13544  7502017006                                             Crowds
# 1400   1012017004                                      Demonstrators
# 7079   3691993003                                             Dozens
# 4841   2901991001                                             Dozens
# 12943  7132016003                                             Dozens
# 12662  7102016006           Estimated number of protesters at 10,000
# 14942  8202016015                             Estimated to be 15,500
# 1409   1012017013               HUNDREDS OF thousands of Venezuelans
# 1402   1012017006                                      Huge protests
# 13751  7702017003                                           Hundreds
# 14932  8202016005                                           Hundreds
# 13299  7322017003                                           Hundreds
# 13537  7502016006                                           Hundreds
# 13750  7702017002                                           Hundreds
# 15176  8502018001                                           Hundreds
# 9093   5002017001                                           Hundreds
# 12307  7032016001                                           Hundreds
# 3656   2102017002                                           Hundreds
# 10211  5602017002                                           Hundreds
# 10442  5652017006                                           Hundreds
# 8785   4752018012                                           Hundreds
# 8783   4752018010                                           Hundreds
# 8782   4752018009                                           Hundreds
# 7677   4202017003                                           Hundreds
# 8778   4752018005                                           Hundreds
# 8770   4752017031                                           Hundreds
# 8763   4752017024                                           Hundreds
# 8761   4752017022                                           Hundreds
# 8760   4752017021                                           Hundreds
# 14176  7752016004                                           Hundreds
# 15167  8502016002                                           Hundreds
# 8772   4752017033                                           Hundreds
# 14180  7752018002                                           Hundreds
# 1418   1012017022                            Hundreds of Venezuelans
# 13541  7502017003                       Hundreds of college students
# 12660  7102016004                                 Hundreds of people
# 13546  7502017008                                 Hundreds of people
# 13550  7502017012                              Hundreds of residents
# 1405   1012017009                     Hundreds of student protesters
# 1391   1012016005                              Hundreds of thousands
# 1394   1012016008                              Hundreds of thousands
# 1403   1012017007                              Hundreds of thousands
# 12671  7102016015                              Hundreds of villagers
# 12661  7102016005                                Hundreds of workers
# 1413   1012017017                                 Hundreds of youths
# 14715  8002017003  In northern Chiang Mai province, 200 kamnans a...
# 1401   1012017005                               Large demonstrations
# 12681  7102016025  March organiser and legal-sector lawmaker Denn...
# 14714  8002017002                                Mass demonstrations
# 1408   1012017012                                      Mass protests
# 1412   1012017016                                           Millions
# 13757  7702017009                                           Millions
# 14717  8002017005                          More than 200 campaigners
# 1411   1012017015                     More than seven million people
# 1415   1012017019  Protesters on whom the government security for...
# 13549  7502017011                              Protests across India
# 14089  7712017003                                    Several hundred
# 12667  7102016011                      Several hundred demonstrators
# 2049   1402016018                                   Several thousand
# 1407   1012017011                                   Several thousand
# 5487   3432016002                                   Several thousand
# 14713  8002017001                                   Several thousand
# 1398   1012017002                        Several thousand protesters
# 6737   3651998001                                  Tens of thousands
#
#       participants_category  participants_clean
# 1410                100-999                 NaN
# 11615                   NaN                 NaN
# 1633                    NaN                 NaN
# 11631                   NaN                 NaN
# 15100                   NaN                 NaN
# 12975                   NaN                 NaN
# 15087                   NaN                 NaN
# 6651                 >10000                 NaN
# 11442             2000-4999                 NaN
# 11588                 50-99                 NaN
# 1469                  50-99                 NaN
# 887                 100-999                 NaN
# 1392                  50-99                 NaN
# 6880                100-999                 NaN
# 515                 100-999                 NaN
# 2033                100-999                 NaN
# 5260                  50-99                 NaN
# 12686                 50-99                 NaN
# 1396              2000-4999                 NaN
# 12432            5000-10000                 NaN
# 7584                100-999                 NaN
# 14935                 50-99                 NaN
# 14718               100-999                 NaN
# 6909                  50-99                 NaN
# 13301               100-999                 NaN
# 8385                100-999                 NaN
# 14087               100-999                 NaN
# 1416                100-999                 NaN
# 1414                 >10000                 NaN
# 14719               100-999                 NaN
# 12674               100-999                 NaN
# 1417                100-999                 NaN
# 13748                >10000                 NaN
# 13346                   NaN                 NaN
# 13547                 50-99                 NaN
# 13540                 50-99                 NaN
# 13544               100-999                 NaN
# 1400                100-999                 NaN
# 7079                  50-99                 NaN
# 4841                100-999                 NaN
# 12943                 50-99                 NaN
# 12662            5000-10000                 NaN
# 14942                >10000                 NaN
# 1409                 >10000                 NaN
# 1402                100-999                 NaN
# 13751               100-999                 NaN
# 14932               100-999                 NaN
# 13299               100-999                 NaN
# 13537               100-999                 NaN
# 13750               100-999                 NaN
# 15176               100-999                 NaN
# 9093                100-999                 NaN
# 12307               100-999                 NaN
# 3656                100-999                 NaN
# 10211               100-999                 NaN
# 10442               100-999                 NaN
# 8785                100-999                 NaN
# 8783                100-999                 NaN
# 8782                100-999                 NaN
# 7677                100-999                 NaN
# 8778                100-999                 NaN
# 8770                100-999                 NaN
# 8763                100-999                 NaN
# 8761                100-999                 NaN
# 8760                100-999                 NaN
# 14176               100-999                 NaN
# 15167               100-999                 NaN
# 8772                100-999                 NaN
# 14180               100-999                 NaN
# 1418                100-999                 NaN
# 13541               100-999                 NaN
# 12660               100-999                 NaN
# 13546               100-999                 NaN
# 13550               100-999                 NaN
# 1405                100-999                 NaN
# 1391                 >10000                 NaN
# 1394                 >10000                 NaN
# 1403                 >10000                 NaN
# 12671               100-999                 NaN
# 12661               100-999                 NaN
# 1413                100-999                 NaN
# 14715                 50-99                 NaN
# 1401                100-999                 NaN
# 12681             1000-1999                 NaN
# 14714                 50-99                 NaN
# 1408              1000-1999                 NaN
# 1412                 >10000                 NaN
# 13757                >10000                 NaN
# 14717               100-999                 NaN
# 1411                 >10000                 NaN
# 1415                 >10000                 NaN
# 13549               100-999                 NaN
# 14089               100-999                 NaN
# 12667               100-999                 NaN
# 2049             5000-10000                 NaN
# 1407              2000-4999                 NaN
# 5487             5000-10000                 NaN
# 14713             2000-4999                 NaN
# 1398              2000-4999                 NaN
# 6737                 >10000                 NaN

# %%
# Apply dictionary to convert original participant counts
counts_converted = df['participants'].map(converter)#.astype('Int64')

# Create a series to hold the averages converted from the range column
range_as_average = df['participants_category'].apply(convert_range_to_average)

# Choose the count value unless it is NaN, in which case use avg value
chose_non_nan = lambda avg, count: avg if math.isnan(float(count)) else count

df['participants_clean'] = list(map(chose_non_nan, range_as_average, counts_converted))
print('Total remaining NaN values:', df['participants_clean'].isna().sum())
# Out:
# Total remaining NaN values: 14

# %%
counts_converted
# Out:
# 0        1000.0
# 1        1000.0
# 2         500.0
# 3         100.0
# 4         950.0
#           ...
# 15234     100.0
# 15235    1000.0
# 15236      50.0
# 15237      50.0
# 15238     100.0
# Name: participants, Length: 15239, dtype: float64

# %%
df.loc[23]
# Out:
# id                                                               202005001
# year                                                                  2005
# region                                                       North America
# protest                                                                  1
# protestnumber                                                            1
# startday                                                               3.0
# startmonth                                                             3.0
# startyear                                                           2005.0
# endday                                                                 3.0
# endmonth                                                               4.0
# endyear                                                             2005.0
# protesterviolence                                                      1.0
# location                                                            Quebec
# participants_category                                                  NaN
# participants                                                        170000
# protesteridentity                                         college students
# protesterdemand1                               political behavior, process
# protesterdemand2                                                       NaN
# protesterdemand3                                                       NaN
# protesterdemand4                                                       NaN
# stateresponse1                                                     arrests
# stateresponse2                                                         NaN
# stateresponse3                                                         NaN
# stateresponse4                                                         NaN
# stateresponse5                                                         NaN
# stateresponse6                                                         NaN
# stateresponse7                                                         NaN
# sources                  1. quebec is shedding image as hotbed of polit...
# notes                    the scene on fashionable rue st. denis looked ...
# scode_final                                                            CAN
# countryname_final                                                   Canada
# start_datetime                                         2005-03-03 00:00:00
# end_datetime                                           2005-04-03 00:00:00
# duration_days                                                           31
# participants_clean                                                170000.0
# Name: 23, dtype: object

# %% [markdown]
# #### YAY the above worked to fill in missing Participant values from Participant Categories values

# %%
# Provide conversion from string formats to list formats
dict_str_to_list = {
    '50-99': [50, 99],
    '100-999': [100, 999],
    '2000-4999': [2000, 4999],
    '1000-1999': [1000, 1999],
    '5000-9999': [5000, 9999],
    '10000+': [10000, int(10e12)]}

dict_str_to_list
# Out:
# {'50-99': [50, 99],
#  '100-999': [100, 999],
#  '2000-4999': [2000, 4999],
#  '1000-1999': [1000, 1999],
#  '5000-9999': [5000, 9999],
#  '10000+': [10000, 10000000000000]}

# %%
def pick_bucket(x):
    for key in dict_str_to_list:
        lim_low = dict_str_to_list[key][0]
        lim_hi  = dict_str_to_list[key][1]
        
        if (x >= lim_low) and (x <= lim_hi):
            return key
    return np.nan

df['participants_category_manufactured'] = list(map(pick_bucket, df['participants_clean']))

df['participants_category_manufactured']
# Out:
# 0        1000-1999
# 1        1000-1999
# 2          100-999
# 3          100-999
# 4          100-999
#            ...
# 15234      100-999
# 15235    1000-1999
# 15236        50-99
# 15237        50-99
# 15238      100-999
# Name: participants_category_manufactured, Length: 15239, dtype: object

# %% [markdown]
# #### Now, check if the above categories match the Categories column in df as a QC

# %%
df.loc[23]
# Out:
# id                                                                            202005001
# year                                                                               2005
# region                                                                    North America
# protest                                                                               1
# protestnumber                                                                         1
# startday                                                                            3.0
# startmonth                                                                          3.0
# startyear                                                                        2005.0
# endday                                                                              3.0
# endmonth                                                                            4.0
# endyear                                                                          2005.0
# protesterviolence                                                                   1.0
# location                                                                         Quebec
# participants_category                                                               NaN
# participants                                                                     170000
# protesteridentity                                                      college students
# protesterdemand1                                            political behavior, process
# protesterdemand2                                                                    NaN
# protesterdemand3                                                                    NaN
# protesterdemand4                                                                    NaN
# stateresponse1                                                                  arrests
# stateresponse2                                                                      NaN
# stateresponse3                                                                      NaN
# stateresponse4                                                                      NaN
# stateresponse5                                                                      NaN
# stateresponse6                                                                      NaN
# stateresponse7                                                                      NaN
# sources                               1. quebec is shedding image as hotbed of polit...
# notes                                 the scene on fashionable rue st. denis looked ...
# scode_final                                                                         CAN
# countryname_final                                                                Canada
# start_datetime                                                      2005-03-03 00:00:00
# end_datetime                                                        2005-04-03 00:00:00
# duration_days                                                                        31
# participants_clean                                                             170000.0
# participants_category_manufactured                                               10000+
# Name: 23, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15239 entries, 0 to 15238
# Data columns (total 36 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  15239 non-null  int64
#  1   year                                15239 non-null  int64
#  2   region                              15239 non-null  object
#  3   protest                             15239 non-null  int64
#  4   protestnumber                       15239 non-null  int64
#  5   startday                            15239 non-null  float64
#  6   startmonth                          15239 non-null  float64
#  7   startyear                           15239 non-null  float64
#  8   endday                              15239 non-null  float64
#  9   endmonth                            15239 non-null  float64
#  10  endyear                             15239 non-null  float64
#  11  protesterviolence                   15239 non-null  float64
#  12  location                            15239 non-null  object
#  13  participants_category               9887 non-null   object
#  14  participants                        15227 non-null  object
#  15  protesteridentity                   14684 non-null  object
#  16  protesterdemand1                    15238 non-null  object
#  17  protesterdemand2                    2977 non-null   object
#  18  protesterdemand3                    383 non-null    object
#  19  protesterdemand4                    779 non-null    object
#  20  stateresponse1                      15208 non-null  object
#  21  stateresponse2                      2888 non-null   object
#  22  stateresponse3                      930 non-null    object
#  23  stateresponse4                      244 non-null    object
#  24  stateresponse5                      797 non-null    object
#  25  stateresponse6                      16 non-null     object
#  26  stateresponse7                      857 non-null    object
#  27  sources                             15235 non-null  object
#  28  notes                               15193 non-null  object
#  29  scode_final                         15239 non-null  object
#  30  countryname_final                   15239 non-null  object
#  31  start_datetime                      15239 non-null  datetime64[ns]
#  32  end_datetime                        15239 non-null  datetime64[ns]
#  33  duration_days                       15239 non-null  int64
#  34  participants_clean                  15225 non-null  float64
#  35  participants_category_manufactured  15208 non-null  object
# dtypes: datetime64[ns](2), float64(8), int64(5), object(21)
# memory usage: 4.2+ MB

# %%
df_participants = df[['participants_category', 'participants', 'participants_clean', 'participants_category_manufactured']]
df_participants
# Out:
#       participants_category participants  participants_clean  \
# 0                       NaN        1000s              1000.0
# 1                       NaN         1000              1000.0
# 2                       NaN          500               500.0
# 3                       NaN         100s               100.0
# 4                       NaN          950               950.0
# ...                     ...          ...                 ...
# 15234               100-999         100+               100.0
# 15235             1000-1999   About 1000              1000.0
# 15236                 50-99          50+                50.0
# 15237                 50-99          50+                50.0
# 15238               100-999    About 100               100.0
#
#       participants_category_manufactured
# 0                              1000-1999
# 1                              1000-1999
# 2                                100-999
# 3                                100-999
# 4                                100-999
# ...                                  ...
# 15234                            100-999
# 15235                          1000-1999
# 15236                              50-99
# 15237                              50-99
# 15238                            100-999
#
# [15239 rows x 4 columns]

# %%
df_participants.loc[(df_participants.participants_category != df_participants.participants_category_manufactured) & (~df_participants.participants_category.isna())].sort_values(by='participants').participants.value_counts().head(50)
# Out:
# 1000s                    894
# thousands                194
# tens of thousands        191
# 10000s                   159
# 10000                    139
# 5000                     120
# 20000                     85
# >50                       70
# > 50                      60
# 50+                       60
# 30000                     53
# 15000                     53
# Thousands                 49
# Tens of thousands         46
# 100000                    46
# 50000                     40
# 6000                      39
# 7000                      38
# 10000+                    36
# hundreds of thousands     33
# 100000s                   29
# several thousand          29
# 8000                      29
# >10000                    27
# 25000                     26
# 40000                     25
# 5000+                     22
# 200000                    21
# >5000                     18
# 80000                     16
# 60000                     16
# 150000                    12
# 35000                     12
# 100000+                   12
# > 10000                   11
# 250000                    11
# 20000+                    11
# 1000000                   11
# 300000                    10
# 12000                      9
# >30000                     9
# > 100000                   8
# 18000                      8
# >20000                     7
# 400000                     7
# >100000                    7
# 500000                     7
# >50000                     7
# 70000                      7
# 350000                     6
# Name: participants, dtype: int64

# %%
df_participants.loc[(df_participants.participants_category != df_participants.participants_category_manufactured) & 
                    (~df_participants.participants_category.isna()) & 
                    (df_participants.participants_category != '>10000')]\
                    .sort_values(by='participants', ascending=True)\
                    .value_counts()
# Out:
# participants_category  participants                              participants_clean  participants_category_manufactured
# 2000-4999              1000s                                     1000.0              1000-1999                             879
# 5000-10000             thousands                                 7500.0              5000-9999                             137
#                        5000                                      5000.0              5000-9999                             120
#                        10000                                     10000.0             10000+                                 91
# 100-999                >50                                       50.0                50-99                                  69
#                        50+                                       50.0                50-99                                  57
#                        > 50                                      50.0                50-99                                  41
# 5000-10000             Thousands                                 7500.0              5000-9999                              41
#                        6000                                      6000.0              5000-9999                              39
#                        7000                                      7000.0              5000-9999                              37
#                        8000                                      8000.0              5000-9999                              29
#                        several thousand                          7500.0              5000-9999                              27
#                        5000+                                     5000.0              5000-9999                              22
#                        >5000                                     5000.0              5000-9999                              18
#                        1000s                                     1000.0              1000-1999                              12
# 1000-1999              > 50                                      50.0                50-99                                  12
# 5000-10000             > 50                                      50.0                50-99                                   5
#                        6000+                                     6000.0              5000-9999                               4
#                        >7000                                     7000.0              5000-9999                               4
#                        > 5000                                    5000.0              5000-9999                               3
# 100-999                <1000                                     1000.0              1000-1999                               3
# 5000-10000             9000+                                     9000.0              5000-9999                               3
#                        >8000                                     8000.0              5000-9999                               2
#                        5500                                      5500.0              5000-9999                               2
#                        Thousands                                 7500.0              5000-9999                               2
#                        7500                                      7500.0              5000-9999                               2
#                        <10000                                    10000.0             10000+                                  2
# 2000-4999              <5000                                     5000.0              5000-9999                               2
#                        1000+                                     1000.0              1000-1999                               2
# 5000-10000             7000+                                     7000.0              5000-9999                               2
# 1000-1999              50+                                       50.0                50-99                                   2
# 5000-10000             >5,000                                    5000.0              5000-9999                               2
#                        Several thousand                          7500.0              5000-9999                               2
# 2000-4999              1000S                                     1000.0              1000-1999                               2
# 5000-10000             >6000                                     6000.0              5000-9999                               2
#                        couple thousands                          7500.0              5000-9999                               1
#                        Estimated number of protesters at 10,000  7500.0              5000-9999                               1
#                        nearly 10000                              10000.0             10000+                                  1
#                        > 3000                                    3000.0              2000-4999                               1
#                        several thousand                          7500.0              5000-9999                               1
#                        > 9000                                    9000.0              5000-9999                               1
#                        >5100                                     5100.0              5000-9999                               1
#                        about 8000                                8000.0              5000-9999                               1
#                        >50                                       50.0                50-99                                   1
#                        Estimated 6,000 drivers                   6000.0              5000-9999                               1
#                        Some 5,000 members                        5000.0              5000-9999                               1
#                        >9000                                     9000.0              5000-9999                               1
#                        9000                                      9000.0              5000-9999                               1
#                        About 5,000 people                        5000.0              5000-9999                               1
#                        About 6,000 people                        6000.0              5000-9999                               1
#                        About 7,000                               7000.0              5000-9999                               1
#                        Around 5,000                              5000.0              5000-9999                               1
# 1000-1999              100-1500+                                 800.0               100-999                                 1
# 5000-10000             6600                                      6600.0              5000-9999                               1
#                        8000-9000                                 8500.0              5000-9999                               1
#                        7000-9000                                 8000.0              5000-9999                               1
# 1000-1999              3000                                      3000.0              2000-4999                               1
#                        700 - >1000                               850.0               100-999                                 1
#                        <2000                                     2000.0              2000-4999                               1
#                        > 200                                     200.0               100-999                                 1
#                        > 800                                     800.0               100-999                                 1
#                        >50-1000                                  525.0               100-999                                 1
# 2000-4999              1000                                      1000.0              1000-1999                               1
# 100-999                > 50                                      50.0                50-99                                   1
# 2000-4999              100s                                      100.0               100-999                                 1
#                        <6700                                     6700.0              5000-9999                               1
#                        > 1500                                    1500.0              1000-1999                               1
#                        > 50                                      50.0                50-99                                   1
# 50-99                  <100                                      100.0               100-999                                 1
#                        about 100                                 100.0               100-999                                 1
# 5000-10000             10000+                                    10000.0             10000+                                  1
#                        3000-10000                                6500.0              5000-9999                               1
#                        4000 arrested                             7500.0              5000-9999                               1
#                        4000-12000                                8000.0              5000-9999                               1
#                        5000-10000                                7500.0              5000-9999                               1
#                        5600+                                     5600.0              5000-9999                               1
#                        5750                                      5750.0              5000-9999                               1
#                        6000 to 8000                              7000.0              5000-9999                               1
# 100-999                90+                                       90.0                50-99                                   1
# 5000-10000             6000-8000                                 7000.0              5000-9999                               1
#                        6500                                      6500.0              5000-9999                               1
# 1000-1999              100s-1000s                                550.0               100-999                                 1
# 5000-10000             7000-15000                                11000.0             10000+                                  1
#                        6000-7000                                 6500.0              5000-9999                               1
# dtype: int64

# %%
print(df.participants_clean.value_counts())
print('NA values:',df.participants_clean.isna().sum())
# Out:
# 50.0       3172
# 100.0      2608
# 1000.0     2316
# 10000.0    1106
# 200.0       452
#            ...
# 950.0         1
# 87.0          1
# 12500.0       1
# 175.0         1
# 525.0         1
# Name: participants_clean, Length: 318, dtype: int64
# NA values: 14

# %%
# THIS SHOWS ALL PROTEXTS THAT HAVE EITHER COUNT OR CATEGORY AS MISSING
na_counts = df.loc[(df.participants_clean.isna()) |
                   (df.participants_category_manufactured.isna())]

print('Shape:', na_counts.participants_category.shape)
display(na_counts)
# Out:
# Shape: (31,)
#                id  year           region  protest  protestnumber  startday  \
# 21      202000004  2000    North America        1              4      16.0
# 585     902005006  2005  Central America        1              6      16.0
# 770     921997001  1997  Central America        1              1      15.0
# 781     922001001  2001  Central America        1              1       1.0
# 783     922003001  2003  Central America        1              1      20.0
# 794     922006004  2006  Central America        1              4       5.0
# 816     931994004  1994  Central America        1              4      23.0
# 1633   1302005002  2005    South America        1              2      13.0
# 11383  6452008002  2008             MENA        1              2      27.0
# 11419  6452013004  2013             MENA        1              4      26.0
# 11470  6511990002  1990             MENA        1              2      29.0
# 11615  6601992002  1992             MENA        1              2      22.0
# 11631  6602002005  2002             MENA        1              5      16.0
# 11793  6702012001  2012             MENA        1              1       9.0
# 12145  7022012004  2012             Asia        1              4       6.0
# 12204  7032011001  2011             Asia        1              1      11.0
# 12216  7032011013  2011             Asia        1             13      21.0
# 12222  7032011019  2011             Asia        1             19      21.0
# 12238  7032012001  2012             Asia        1              1      12.0
# 12252  7032012015  2012             Asia        1             15      23.0
# 12258  7032012021  2012             Asia        1             21      28.0
# 12269  7032012032  2012             Asia        1             32      17.0
# 12275  7032013005  2013             Asia        1              5       6.0
# 12303  7032013033  2013             Asia        1             33       6.0
# 12570  7102011006  2011             Asia        1              6      18.0
# 12975  7321990014  1990             Asia        1             14       8.0
# 13346  7402012002  2012             Asia        1              2      29.0
# 13954  7712011012  2011             Asia        1             12       5.0
# 13993  7712011051  2011             Asia        1             51      13.0
# 15087  8501998019  1998             Asia        1             19       1.0
# 15100  8501999009  1999             Asia        1              9      26.0
#
#        startmonth  startyear  endday  endmonth  endyear  protesterviolence  \
# 21            6.0     2000.0    16.0       6.0   2000.0                1.0
# 585           3.0     2005.0    16.0       3.0   2005.0                1.0
# 770           8.0     1997.0    15.0       8.0   1997.0                0.0
# 781           5.0     2001.0     1.0       5.0   2001.0                0.0
# 783           2.0     2003.0    20.0       2.0   2003.0                1.0
# 794           7.0     2006.0     5.0       7.0   2006.0                1.0
# 816           8.0     1994.0    30.0       8.0   1994.0                1.0
# 1633          4.0     2005.0    13.0       4.0   2005.0                0.0
# 11383         4.0     2008.0    27.0       4.0   2008.0                0.0
# 11419         1.0     2013.0    26.0       1.0   2013.0                1.0
# 11470        11.0     1990.0    29.0      11.0   1990.0                1.0
# 11615         8.0     1992.0    25.0       8.0   1992.0                0.0
# 11631         4.0     2002.0    16.0       4.0   2002.0                0.0
# 11793         3.0     2012.0     9.0       3.0   2012.0                0.0
# 12145         9.0     2012.0     6.0       9.0   2012.0                0.0
# 12204         1.0     2011.0    11.0       1.0   2011.0                0.0
# 12216         4.0     2011.0    21.0       4.0   2011.0                0.0
# 12222         6.0     2011.0    28.0       6.0   2011.0                0.0
# 12238         1.0     2012.0    12.0       1.0   2012.0                0.0
# 12252         3.0     2012.0    23.0       3.0   2012.0                0.0
# 12258         8.0     2012.0    28.0       8.0   2012.0                0.0
# 12269        10.0     2012.0    17.0      10.0   2012.0                0.0
# 12275         2.0     2013.0     6.0       2.0   2013.0                1.0
# 12303        12.0     2013.0     6.0      12.0   2013.0                0.0
# 12570         7.0     2011.0    18.0       7.0   2011.0                1.0
# 12975         6.0     1990.0     8.0       6.0   1990.0                1.0
# 13346         6.0     2012.0    29.0       6.0   2012.0                0.0
# 13954         3.0     2011.0     5.0       3.0   2011.0                0.0
# 13993        11.0     2011.0    13.0      11.0   2011.0                0.0
# 15087         9.0     1998.0     1.0       9.0   1998.0                1.0
# 15100         8.0     1999.0    26.0       8.0   1999.0                1.0
#
#                                                 location  \
# 21                                      Toronto, Ontario
# 585                                Santa Cruz del Quiche
# 770                                         San Salvador
# 781                                         San Salvador
# 783                                         San Salvador
# 794                                         San Salvador
# 816                                              Managua
# 1633                                               Quito
# 11383                                          Sadr City
# 11419  Falluja, Mosul, Nineveh, Salahuddin, Diyala an...
# 11470                                         Nile Delta
# 11615                                           National
# 11631                                             Beruit
# 11793                             King Khaled University
# 12145                                           Dushanbe
# 12204                                            Bishkek
# 12216                                            Bishkek
# 12222                                      Batken Region
# 12238                                            Bishkek
# 12252                                            Bishkek
# 12258                                            Bishkek
# 12269                                            Bishkek
# 12275                                       Dzhalal Abad
# 12303               Jeti Oguz District, Issyk Kul Region
# 12570                                   Khotan, Xinjiang
# 12975                                              Seoul
# 13346                                              Tokyo
# 13954                                       Grameen Bank
# 13993                                         Chittagong
# 15087                                               Aceh
# 15100                                               Dili
#
#       participants_category             participants  \
# 21                      NaN                      10s
# 585                     NaN                      NaN
# 770                     NaN                      NaN
# 781                     NaN                      NaN
# 783                     NaN                      NaN
# 794                     NaN                      NaN
# 816                     NaN                      NaN
# 1633                    NaN                        .
# 11383                   NaN                       40
# 11419                   NaN                      NaN
# 11470                   NaN                       29
# 11615                   NaN                        .
# 11631                   NaN                        .
# 11793                   NaN                      10s
# 12145                   NaN                      10s
# 12204                   NaN                      10s
# 12216                   NaN                      10s
# 12222                   NaN                      10s
# 12238                   NaN                      10s
# 12252                   NaN                      10s
# 12258                   NaN                      10s
# 12269                   NaN                      10s
# 12275                   NaN                      10s
# 12303                   NaN                      10s
# 12570                   NaN                      10s
# 12975                   NaN                        .
# 13346                   NaN  Between 11000 and 45000
# 13954                   NaN                      10s
# 13993                   NaN                      10s
# 15087                   NaN                        .
# 15100                   NaN                        .
#
#                                        protesteridentity  \
# 21                               anti poverty protesters
# 585                                                  NaN
# 770                                      bank depositors
# 781                            unions, former guerrillas
# 783                         striking health care workers
# 794                                             students
# 816                               transportation workers
# 1633                                             indians
# 11383                              members of parliament
# 11419                                             sunnis
# 11470                                 disgruntled voters
# 11615                                         christians
# 11631                                          hizbullah
# 11793                                    female students
# 12145                     shopkeepers from korvon market
# 12204                     members of patriotic movements
# 12216     united national movement government opposition
# 12222                         supporters of myrza asatov
# 12238            kyrgyz patriotic forces public movement
# 12252                                    the trade union
# 12258  the opposition movement for kyrgyzstan s salva...
# 12269           relatives and supporters of arrested mps
# 12275                     victims of june ethnic clashes
# 12303                                    local residents
# 12570                               uighurs ethnic group
# 12975                                           students
# 13346                                 protestors network
# 13954                             grameen bank employees
# 13993                                     chittagong bnp
# 15087                                             public
# 15100                       anti independence supporters
#
#                   protesterdemand1             protesterdemand2  \
# 21     political behavior, process                          NaN
# 585    political behavior, process                          NaN
# 770    political behavior, process                          NaN
# 781    political behavior, process                          NaN
# 783             labor wage dispute                          NaN
# 794    price increases, tax policy                          NaN
# 816    price increases, tax policy                          NaN
# 1633   political behavior, process                          NaN
# 11383  political behavior, process                          NaN
# 11419        removal of politician                          NaN
# 11470  political behavior, process                          NaN
# 11615  political behavior, process                          NaN
# 11631  political behavior, process                          NaN
# 11793          social restrictions                          NaN
# 12145  political behavior, process                          NaN
# 12204  political behavior, process                          NaN
# 12216  political behavior, process                          NaN
# 12222  political behavior, process                          NaN
# 12238  political behavior, process                          NaN
# 12252           labor wage dispute                          NaN
# 12258              land farm issue  political behavior, process
# 12269  political behavior, process                          NaN
# 12275  political behavior, process                          NaN
# 12303             police brutality                          NaN
# 12570  political behavior, process                          NaN
# 12975           labor wage dispute                          NaN
# 13346  political behavior, process                          NaN
# 13954  political behavior, process             police brutality
# 13993  price increases, tax policy                          NaN
# 15087          social restrictions                          NaN
# 15100  political behavior, process                          NaN
#
#       protesterdemand3 protesterdemand4   stateresponse1 stateresponse2  \
# 21                 NaN              NaN  crowd dispersal        arrests
# 585                NaN              NaN  crowd dispersal            NaN
# 770                NaN              NaN           ignore            NaN
# 781                NaN              NaN           ignore            NaN
# 783                NaN              NaN  crowd dispersal            NaN
# 794                NaN              NaN  crowd dispersal      shootings
# 816                NaN              NaN  crowd dispersal            NaN
# 1633               NaN              NaN  crowd dispersal            NaN
# 11383              NaN              NaN           ignore            NaN
# 11419              NaN              NaN        shootings       killings
# 11470              NaN              NaN        shootings            NaN
# 11615              NaN              NaN           ignore            NaN
# 11631              NaN              NaN           ignore            NaN
# 11793              NaN              NaN  crowd dispersal       beatings
# 12145              NaN              NaN     accomodation            NaN
# 12204              NaN              NaN           ignore            NaN
# 12216              NaN              NaN           ignore            NaN
# 12222              NaN              NaN          arrests            NaN
# 12238              NaN              NaN           ignore            NaN
# 12252              NaN              NaN           ignore            NaN
# 12258              NaN              NaN           ignore            NaN
# 12269              NaN              NaN           ignore            NaN
# 12275              NaN              NaN           ignore            NaN
# 12303              NaN              NaN           ignore            NaN
# 12570              NaN              NaN          arrests      shootings
# 12975              NaN              NaN              NaN            NaN
# 13346              NaN              NaN           ignore            NaN
# 13954              NaN              NaN  crowd dispersal            NaN
# 13993              NaN              NaN           ignore            NaN
# 15087              NaN              NaN         killings            NaN
# 15100              NaN              NaN           ignore            NaN
#
#       stateresponse3 stateresponse4 stateresponse5 stateresponse6  \
# 21               NaN            NaN            NaN            NaN
# 585              NaN            NaN            NaN            NaN
# 770              NaN            NaN            NaN            NaN
# 781              NaN            NaN            NaN            NaN
# 783              NaN            NaN            NaN            NaN
# 794         killings        arrests            NaN            NaN
# 816              NaN            NaN            NaN            NaN
# 1633             NaN            NaN            NaN            NaN
# 11383            NaN            NaN            NaN            NaN
# 11419            NaN            NaN            NaN            NaN
# 11470            NaN            NaN            NaN            NaN
# 11615            NaN            NaN            NaN            NaN
# 11631            NaN            NaN            NaN            NaN
# 11793            NaN            NaN            NaN            NaN
# 12145            NaN            NaN            NaN            NaN
# 12204            NaN            NaN            NaN            NaN
# 12216            NaN            NaN            NaN            NaN
# 12222            NaN            NaN            NaN            NaN
# 12238            NaN            NaN            NaN            NaN
# 12252            NaN            NaN            NaN            NaN
# 12258            NaN            NaN            NaN            NaN
# 12269            NaN            NaN            NaN            NaN
# 12275            NaN            NaN            NaN            NaN
# 12303            NaN            NaN            NaN            NaN
# 12570       killings            NaN            NaN            NaN
# 12975            NaN            NaN            NaN            NaN
# 13346            NaN            NaN            NaN            NaN
# 13954            NaN            NaN            NaN            NaN
# 13993            NaN            NaN            NaN            NaN
# 15087            NaN            NaN            NaN            NaN
# 15100            NaN            NaN            NaN            NaN
#
#       stateresponse7                                            sources  \
# 21               NaN  1. world briefing the new york times, june 16,...
# 585              NaN  world briefing americas: guatemala: protesters...
# 770              NaN  swindled salvadorans demonstrate the philadelp...
# 781              NaN  ap photos associated press international, may ...
# 783              NaN  protesters storm social security building in e...
# 794              NaN  in el salvador, confrontation between police, ...
# 816              NaN  nicaragua: transportation workers call nationa...
# 1633             NaN  bbc monitoring latin america, april 13, 2005, ...
# 11383            NaN  iraq struggle unfolds in peaceful protest and ...
# 11419            NaN  deadly turn in protests against iraqi leadersh...
# 11470            NaN  ny times, nov. 29, 1990 section a; page 12; co...
# 11615            NaN  ny times, august 22, 1992, section 1; page 2; ...
# 11631            NaN  jerusalem post, april 16, 2002, p2. powell war...
# 11793            NaN  woman dies after campus demonstration; religio...
# 12145            NaN  1. shopkeepers protesting after market fire ne...
# 12204            NaN  1. kyrgyz patriots call for national tv channe...
# 12216            NaN  1. kyrgyz opposition demands reform from gover...
# 12222            NaN  1. kyrgyz protesters block road to tajikistan ...
# 12238            NaN  1. kyrgyz protesters against plans to allow fo...
# 12252            NaN  1. kyrgyz trade union members rally against ne...
# 12258            NaN  1. protesters disrupt kyrgyzstan s first minin...
# 12269            NaN  1. supporters of arrested kyrgyz mps hold rall...
# 12275            NaN  1. kyrgyz protesters demand punishment of judg...
# 12303            NaN  1. protesters in kyrgyzstan s north blockade r...
# 12570            NaN  1. china says 18 died in police station attack...
# 12975            NaN  st. petersburg times, june 8, 1990, national; ...
# 13346            NaN  protest rally against noda, oi restarts intens...
# 13954            NaN  the new nation bangladesh ;gb employees protes...
# 13993            NaN  the new nation bangladesh ;bnp s programme the...
# 15087            NaN  sydney morning herald, september 2, 1998, news...
# 15100            NaN  ny times, august 27, 1999, section a; page 12;...
#
#                                                    notes scode_final  \
# 21     anti poverty protesters fought with the police...         CAN
# 585    eighth day of protests over trade agreement wi...         GUA
# 770    protesters demand government refund losses fro...         SAL
# 781    unions and former guerrillas marched in protes...         SAL
# 783    striking health workers stormed el salvador s ...         SAL
# 794    students protested increased prices in public ...         SAL
# 816    transportation workers strike, protesting fuel...         NIC
# 1633                    occupying the education ministry         ECU
# 11383  the latest episode in the struggle between the...         IRQ
# 11419  at least seven protesters and two soldiers wer...         IRQ
# 11470  the police reported that 29 people were injure...         EGY
# 11615  christian areas of lebanon were paralyzed toda...         LEB
# 11631  hizbullah has stepped up raids on israel since...         LEB
# 11793  one woman died as a result of the attack on pr...         SAU
# 12145  the shopkeepers protested to demand government...         TAJ
# 12204  1. protest centered on the demand for the publ...         KYR
# 12216  a united national movement which claims to hav...         KYR
# 12222  the organizers of a road protest in lyaylyak d...         KYR
# 12238  protestors were against allowing foreign compa...         KYR
# 12252  representatives of the trade union are holding...         KYR
# 12258  a group of protestors stormed the sale of lice...         KYR
# 12269  relatives and supporters of the three mps accu...         KYR
# 12275  those who suffered in the june events staged a...         KYR
# 12303  supporters of arrested kyrgyz opposition mp ah...         KYR
# 12570  the chinese government disputes that this was ...         CHN
# 12975  anti government students threw gasoline bombs ...         ROK
# 13346  the protest outside the prime ministercos offi...         JPN
# 13954  grameen bank gb employees on saturday staged d...         BNG
# 13993  the main opposition bnp hasdecided to hold a t...         BNG
# 15087  indonesian security forces opened fire on riot...         INS
# 15100  opponents of independence for east timor ran w...         INS
#
#       countryname_final start_datetime end_datetime  duration_days  \
# 21               Canada     2000-06-16   2000-06-16              0
# 585           Guatemala     2005-03-16   2005-03-16              0
# 770         El Salvador     1997-08-15   1997-08-15              0
# 781         El Salvador     2001-05-01   2001-05-01              0
# 783         El Salvador     2003-02-20   2003-02-20              0
# 794         El Salvador     2006-07-05   2006-07-05              0
# 816           Nicaragua     1994-08-23   1994-08-30              7
# 1633            Ecuador     2005-04-13   2005-04-13              0
# 11383              Iraq     2008-04-27   2008-04-27              0
# 11419              Iraq     2013-01-26   2013-01-26              0
# 11470             Egypt     1990-11-29   1990-11-29              0
# 11615           Lebanon     1992-08-22   1992-08-25              3
# 11631           Lebanon     2002-04-16   2002-04-16              0
# 11793      Saudi Arabia     2012-03-09   2012-03-09              0
# 12145        Tajikistan     2012-09-06   2012-09-06              0
# 12204        Kyrgyzstan     2011-01-11   2011-01-11              0
# 12216        Kyrgyzstan     2011-04-21   2011-04-21              0
# 12222        Kyrgyzstan     2011-06-21   2011-06-28              7
# 12238        Kyrgyzstan     2012-01-12   2012-01-12              0
# 12252        Kyrgyzstan     2012-03-23   2012-03-23              0
# 12258        Kyrgyzstan     2012-08-28   2012-08-28              0
# 12269        Kyrgyzstan     2012-10-17   2012-10-17              0
# 12275        Kyrgyzstan     2013-02-06   2013-02-06              0
# 12303        Kyrgyzstan     2013-12-06   2013-12-06              0
# 12570             China     2011-07-18   2011-07-18              0
# 12975       Korea South     1990-06-08   1990-06-08              0
# 13346             Japan     2012-06-29   2012-06-29              0
# 13954        Bangladesh     2011-03-05   2011-03-05              0
# 13993        Bangladesh     2011-11-13   2011-11-13              0
# 15087         Indonesia     1998-09-01   1998-09-01              0
# 15100         Indonesia     1999-08-26   1999-08-26              0
#
#        participants_clean participants_category_manufactured
# 21                   10.0                                NaN
# 585                   NaN                                NaN
# 770                   NaN                                NaN
# 781                   NaN                                NaN
# 783                   NaN                                NaN
# 794                   NaN                                NaN
# 816                   NaN                                NaN
# 1633                  NaN                                NaN
# 11383                40.0                                NaN
# 11419                 NaN                                NaN
# 11470                29.0                                NaN
# 11615                 NaN                                NaN
# 11631                 NaN                                NaN
# 11793                10.0                                NaN
# 12145                10.0                                NaN
# 12204                10.0                                NaN
# 12216                10.0                                NaN
# 12222                10.0                                NaN
# 12238                10.0                                NaN
# 12252                10.0                                NaN
# 12258                10.0                                NaN
# 12269                10.0                                NaN
# 12275                10.0                                NaN
# 12303                10.0                                NaN
# 12570                10.0                                NaN
# 12975                 NaN                                NaN
# 13346                 NaN                                NaN
# 13954                10.0                                NaN
# 13993                10.0                                NaN
# 15087                 NaN                                NaN
# 15100                 NaN                                NaN

# %%
# NOTE THAT THE DATA MANUAL SAYS ONLY PROTESTS WITH 50+ PEOPLE SHOULD BE INCLUDED 
# HERE, WE SEE THAT THERE IS A HANDFUL WITH FEWER THAN 50
# DROP THOSE ROWS AS OUTLIERS AS THEY ARE INCONSISTENT WITH THE DATA DEFINITIONS

print('Before setting to NaN:')
display(df.loc[df.participants_clean < 50])

df.loc[df.participants_clean < 50, 'participants_clean'] = np.nan
# Out:
# Before setting to NaN:
#                id  year         region  protest  protestnumber  startday  \
# 21      202000004  2000  North America        1              4      16.0
# 11383  6452008002  2008           MENA        1              2      27.0
# 11470  6511990002  1990           MENA        1              2      29.0
# 11793  6702012001  2012           MENA        1              1       9.0
# 12145  7022012004  2012           Asia        1              4       6.0
# 12204  7032011001  2011           Asia        1              1      11.0
# 12216  7032011013  2011           Asia        1             13      21.0
# 12222  7032011019  2011           Asia        1             19      21.0
# 12238  7032012001  2012           Asia        1              1      12.0
# 12252  7032012015  2012           Asia        1             15      23.0
# 12258  7032012021  2012           Asia        1             21      28.0
# 12269  7032012032  2012           Asia        1             32      17.0
# 12275  7032013005  2013           Asia        1              5       6.0
# 12303  7032013033  2013           Asia        1             33       6.0
# 12570  7102011006  2011           Asia        1              6      18.0
# 13954  7712011012  2011           Asia        1             12       5.0
# 13993  7712011051  2011           Asia        1             51      13.0
#
#        startmonth  startyear  endday  endmonth  endyear  protesterviolence  \
# 21            6.0     2000.0    16.0       6.0   2000.0                1.0
# 11383         4.0     2008.0    27.0       4.0   2008.0                0.0
# 11470        11.0     1990.0    29.0      11.0   1990.0                1.0
# 11793         3.0     2012.0     9.0       3.0   2012.0                0.0
# 12145         9.0     2012.0     6.0       9.0   2012.0                0.0
# 12204         1.0     2011.0    11.0       1.0   2011.0                0.0
# 12216         4.0     2011.0    21.0       4.0   2011.0                0.0
# 12222         6.0     2011.0    28.0       6.0   2011.0                0.0
# 12238         1.0     2012.0    12.0       1.0   2012.0                0.0
# 12252         3.0     2012.0    23.0       3.0   2012.0                0.0
# 12258         8.0     2012.0    28.0       8.0   2012.0                0.0
# 12269        10.0     2012.0    17.0      10.0   2012.0                0.0
# 12275         2.0     2013.0     6.0       2.0   2013.0                1.0
# 12303        12.0     2013.0     6.0      12.0   2013.0                0.0
# 12570         7.0     2011.0    18.0       7.0   2011.0                1.0
# 13954         3.0     2011.0     5.0       3.0   2011.0                0.0
# 13993        11.0     2011.0    13.0      11.0   2011.0                0.0
#
#                                    location participants_category  \
# 21                         Toronto, Ontario                   NaN
# 11383                             Sadr City                   NaN
# 11470                            Nile Delta                   NaN
# 11793                King Khaled University                   NaN
# 12145                              Dushanbe                   NaN
# 12204                               Bishkek                   NaN
# 12216                               Bishkek                   NaN
# 12222                         Batken Region                   NaN
# 12238                               Bishkek                   NaN
# 12252                               Bishkek                   NaN
# 12258                               Bishkek                   NaN
# 12269                               Bishkek                   NaN
# 12275                          Dzhalal Abad                   NaN
# 12303  Jeti Oguz District, Issyk Kul Region                   NaN
# 12570                      Khotan, Xinjiang                   NaN
# 13954                          Grameen Bank                   NaN
# 13993                            Chittagong                   NaN
#
#       participants                                  protesteridentity  \
# 21             10s                            anti poverty protesters
# 11383           40                              members of parliament
# 11470           29                                 disgruntled voters
# 11793          10s                                    female students
# 12145          10s                     shopkeepers from korvon market
# 12204          10s                     members of patriotic movements
# 12216          10s     united national movement government opposition
# 12222          10s                         supporters of myrza asatov
# 12238          10s            kyrgyz patriotic forces public movement
# 12252          10s                                    the trade union
# 12258          10s  the opposition movement for kyrgyzstan s salva...
# 12269          10s           relatives and supporters of arrested mps
# 12275          10s                     victims of june ethnic clashes
# 12303          10s                                    local residents
# 12570          10s                               uighurs ethnic group
# 13954          10s                             grameen bank employees
# 13993          10s                                     chittagong bnp
#
#                   protesterdemand1             protesterdemand2  \
# 21     political behavior, process                          NaN
# 11383  political behavior, process                          NaN
# 11470  political behavior, process                          NaN
# 11793          social restrictions                          NaN
# 12145  political behavior, process                          NaN
# 12204  political behavior, process                          NaN
# 12216  political behavior, process                          NaN
# 12222  political behavior, process                          NaN
# 12238  political behavior, process                          NaN
# 12252           labor wage dispute                          NaN
# 12258              land farm issue  political behavior, process
# 12269  political behavior, process                          NaN
# 12275  political behavior, process                          NaN
# 12303             police brutality                          NaN
# 12570  political behavior, process                          NaN
# 13954  political behavior, process             police brutality
# 13993  price increases, tax policy                          NaN
#
#       protesterdemand3 protesterdemand4   stateresponse1 stateresponse2  \
# 21                 NaN              NaN  crowd dispersal        arrests
# 11383              NaN              NaN           ignore            NaN
# 11470              NaN              NaN        shootings            NaN
# 11793              NaN              NaN  crowd dispersal       beatings
# 12145              NaN              NaN     accomodation            NaN
# 12204              NaN              NaN           ignore            NaN
# 12216              NaN              NaN           ignore            NaN
# 12222              NaN              NaN          arrests            NaN
# 12238              NaN              NaN           ignore            NaN
# 12252              NaN              NaN           ignore            NaN
# 12258              NaN              NaN           ignore            NaN
# 12269              NaN              NaN           ignore            NaN
# 12275              NaN              NaN           ignore            NaN
# 12303              NaN              NaN           ignore            NaN
# 12570              NaN              NaN          arrests      shootings
# 13954              NaN              NaN  crowd dispersal            NaN
# 13993              NaN              NaN           ignore            NaN
#
#       stateresponse3 stateresponse4 stateresponse5 stateresponse6  \
# 21               NaN            NaN            NaN            NaN
# 11383            NaN            NaN            NaN            NaN
# 11470            NaN            NaN            NaN            NaN
# 11793            NaN            NaN            NaN            NaN
# 12145            NaN            NaN            NaN            NaN
# 12204            NaN            NaN            NaN            NaN
# 12216            NaN            NaN            NaN            NaN
# 12222            NaN            NaN            NaN            NaN
# 12238            NaN            NaN            NaN            NaN
# 12252            NaN            NaN            NaN            NaN
# 12258            NaN            NaN            NaN            NaN
# 12269            NaN            NaN            NaN            NaN
# 12275            NaN            NaN            NaN            NaN
# 12303            NaN            NaN            NaN            NaN
# 12570       killings            NaN            NaN            NaN
# 13954            NaN            NaN            NaN            NaN
# 13993            NaN            NaN            NaN            NaN
#
#       stateresponse7                                            sources  \
# 21               NaN  1. world briefing the new york times, june 16,...
# 11383            NaN  iraq struggle unfolds in peaceful protest and ...
# 11470            NaN  ny times, nov. 29, 1990 section a; page 12; co...
# 11793            NaN  woman dies after campus demonstration; religio...
# 12145            NaN  1. shopkeepers protesting after market fire ne...
# 12204            NaN  1. kyrgyz patriots call for national tv channe...
# 12216            NaN  1. kyrgyz opposition demands reform from gover...
# 12222            NaN  1. kyrgyz protesters block road to tajikistan ...
# 12238            NaN  1. kyrgyz protesters against plans to allow fo...
# 12252            NaN  1. kyrgyz trade union members rally against ne...
# 12258            NaN  1. protesters disrupt kyrgyzstan s first minin...
# 12269            NaN  1. supporters of arrested kyrgyz mps hold rall...
# 12275            NaN  1. kyrgyz protesters demand punishment of judg...
# 12303            NaN  1. protesters in kyrgyzstan s north blockade r...
# 12570            NaN  1. china says 18 died in police station attack...
# 13954            NaN  the new nation bangladesh ;gb employees protes...
# 13993            NaN  the new nation bangladesh ;bnp s programme the...
#
#                                                    notes scode_final  \
# 21     anti poverty protesters fought with the police...         CAN
# 11383  the latest episode in the struggle between the...         IRQ
# 11470  the police reported that 29 people were injure...         EGY
# 11793  one woman died as a result of the attack on pr...         SAU
# 12145  the shopkeepers protested to demand government...         TAJ
# 12204  1. protest centered on the demand for the publ...         KYR
# 12216  a united national movement which claims to hav...         KYR
# 12222  the organizers of a road protest in lyaylyak d...         KYR
# 12238  protestors were against allowing foreign compa...         KYR
# 12252  representatives of the trade union are holding...         KYR
# 12258  a group of protestors stormed the sale of lice...         KYR
# 12269  relatives and supporters of the three mps accu...         KYR
# 12275  those who suffered in the june events staged a...         KYR
# 12303  supporters of arrested kyrgyz opposition mp ah...         KYR
# 12570  the chinese government disputes that this was ...         CHN
# 13954  grameen bank gb employees on saturday staged d...         BNG
# 13993  the main opposition bnp hasdecided to hold a t...         BNG
#
#       countryname_final start_datetime end_datetime  duration_days  \
# 21               Canada     2000-06-16   2000-06-16              0
# 11383              Iraq     2008-04-27   2008-04-27              0
# 11470             Egypt     1990-11-29   1990-11-29              0
# 11793      Saudi Arabia     2012-03-09   2012-03-09              0
# 12145        Tajikistan     2012-09-06   2012-09-06              0
# 12204        Kyrgyzstan     2011-01-11   2011-01-11              0
# 12216        Kyrgyzstan     2011-04-21   2011-04-21              0
# 12222        Kyrgyzstan     2011-06-21   2011-06-28              7
# 12238        Kyrgyzstan     2012-01-12   2012-01-12              0
# 12252        Kyrgyzstan     2012-03-23   2012-03-23              0
# 12258        Kyrgyzstan     2012-08-28   2012-08-28              0
# 12269        Kyrgyzstan     2012-10-17   2012-10-17              0
# 12275        Kyrgyzstan     2013-02-06   2013-02-06              0
# 12303        Kyrgyzstan     2013-12-06   2013-12-06              0
# 12570             China     2011-07-18   2011-07-18              0
# 13954        Bangladesh     2011-03-05   2011-03-05              0
# 13993        Bangladesh     2011-11-13   2011-11-13              0
#
#        participants_clean participants_category_manufactured
# 21                   10.0                                NaN
# 11383                40.0                                NaN
# 11470                29.0                                NaN
# 11793                10.0                                NaN
# 12145                10.0                                NaN
# 12204                10.0                                NaN
# 12216                10.0                                NaN
# 12222                10.0                                NaN
# 12238                10.0                                NaN
# 12252                10.0                                NaN
# 12258                10.0                                NaN
# 12269                10.0                                NaN
# 12275                10.0                                NaN
# 12303                10.0                                NaN
# 12570                10.0                                NaN
# 13954                10.0                                NaN
# 13993                10.0                                NaN

# %%
df.loc[23]
# Out:
# id                                                                            202005001
# year                                                                               2005
# region                                                                    North America
# protest                                                                               1
# protestnumber                                                                         1
# startday                                                                            3.0
# startmonth                                                                          3.0
# startyear                                                                        2005.0
# endday                                                                              3.0
# endmonth                                                                            4.0
# endyear                                                                          2005.0
# protesterviolence                                                                   1.0
# location                                                                         Quebec
# participants_category                                                               NaN
# participants                                                                     170000
# protesteridentity                                                      college students
# protesterdemand1                                            political behavior, process
# protesterdemand2                                                                    NaN
# protesterdemand3                                                                    NaN
# protesterdemand4                                                                    NaN
# stateresponse1                                                                  arrests
# stateresponse2                                                                      NaN
# stateresponse3                                                                      NaN
# stateresponse4                                                                      NaN
# stateresponse5                                                                      NaN
# stateresponse6                                                                      NaN
# stateresponse7                                                                      NaN
# sources                               1. quebec is shedding image as hotbed of polit...
# notes                                 the scene on fashionable rue st. denis looked ...
# scode_final                                                                         CAN
# countryname_final                                                                Canada
# start_datetime                                                      2005-03-03 00:00:00
# end_datetime                                                        2005-04-03 00:00:00
# duration_days                                                                        31
# participants_clean                                                             170000.0
# participants_category_manufactured                                               10000+
# Name: 23, dtype: object

# %%
plt.figure()
df['participants_clean'].dropna().sort_values().hist(bins=25);
plt.title('Participant Turnout Hist')


plt.figure()
df['participants_clean'].dropna().sort_values().hist(bins=4000)
plt.xlim([0, 20000])
plt.title('Participant Turnout Hist (Zoomed In)');

# %% [markdown]
# # Move to Protester Identities and Demands

# %% [markdown]
# #### Protester Identity

# %%
# Replace unknowns with unknown for consistency
print(df.protesteridentity.value_counts().head(50))

df.protesteridentity.replace('unspecified', UNKNOWN, inplace=True)
df.protesteridentity.replace('people', UNKNOWN, inplace=True)
df['protesteridentity'] = df['protesteridentity'].fillna(UNKNOWN)
# Out:
# protesters                                                                               1541
# students                                                                                  646
# workers                                                                                   273
# unspecified                                                                               224
# farmers                                                                                   219
# residents                                                                                 171
# opposition supporters                                                                     165
# university students                                                                       144
# demonstrators                                                                             137
# opposition                                                                                133
# women                                                                                     115
# teachers                                                                                   99
# ladies in white                                                                            90
# people                                                                                     83
# activists                                                                                  67
# youths                                                                                     58
# taxi drivers                                                                               57
# journalists                                                                                54
# soldiers                                                                                   51
# pegida patriotic europeans against the islamization of the west                            51
# protestors                                                                                 48
# stuttgart 21                                                                               48
# prisoners                                                                                  47
# labor unions                                                                               45
# pro democracy activists; civil human rights front                                          45
# villagers                                                                                  44
# fishermen                                                                                  42
# pegida                                                                                     41
# locals                                                                                     40
# indians                                                                                    39
# muslims                                                                                    39
# miners                                                                                     39
# pro democracy activists; hirak                                                             38
# anti government protesters                                                                 36
# peruvians                                                                                  36
# ethnic albanians                                                                           35
# opposition supporters demanding the resignation of president hery rajaonarimampianina      35
# kurds                                                                                      35
# awami league                                                                               34
# local residents                                                                            34
# bangladesh nationalist party                                                               33
# chaves opponents                                                                           33
# anti corruption protesters                                                                 32
# pensioners                                                                                 32
# youth                                                                                      32
# pro democracy                                                                              31
# civil servants                                                                             30
# traders                                                                                    30
# anti government demonstrators                                                              30
# venezuelans                                                                                29
# Name: protesteridentity, dtype: int64

# %% [markdown]
# # Protester Demands

# %%
# Columns to be used for this section
demand_cols = ['protesterdemand1', 'protesterdemand2', 'protesterdemand3', 'protesterdemand4']

for col in demand_cols:    
    # Print list of demands in each relevant column
    print(df[col].value_counts())
    print('-----')
# Out:
# political behavior, process    9680
# labor wage dispute             1710
# price increases, tax policy    1087
# removal of politician          1011
# police brutality                825
# land farm issue                 467
# social restrictions             458
# Name: protesterdemand1, dtype: int64
# -----
# political behavior, process    1004
# removal of politician           768
# labor wage dispute              438
# police brutality                241
# price increases, tax policy     214
# social restrictions             212
# land farm issue                 100
# Name: protesterdemand2, dtype: int64
# -----
# price increases, tax policy    111
# removal of politician           94
# political behavior, process     63
# labor wage dispute              61
# police brutality                28
# social restrictions             14
# land farm issue                 12
# Name: protesterdemand3, dtype: int64
# -----
# .                              744
# removal of politician           18
# police brutality                 7
# political behavior, process      3
# land farm issue                  3
# labor wage dispute               2
# price increases, tax policy      2
# Name: protesterdemand4, dtype: int64
# -----

# %%
# Create list of unique demands
demands = np.concatenate([df.protesterdemand1.dropna().unique(), 
                          df.protesterdemand2.dropna().unique(),
                          df.protesterdemand3.dropna().unique(), 
                          df.protesterdemand4.dropna().unique()])
# Verify there are only 7 demands as indicated by data manual
set(demands)
# Out:
# {'.',
#  'labor wage dispute',
#  'land farm issue',
#  'police brutality',
#  'political behavior, process',
#  'price increases, tax policy',
#  'removal of politician',
#  'social restrictions'}

# %%
# Replace '.' with np.nan
for demand_col in demand_cols:
    df[demand_col].replace('.', np.nan, inplace=True)

# %%
# --- ONE HOT ENCODE EACH OF THESE DEMANDS
ohe = OneHotEncoder(sparse=False)


for demand_col in demand_cols:
    if demand_col == demand_cols[0]: #first iteration
        fit = ohe.fit_transform(df[demand_col].values.reshape(-1, 1))
        demand_array = np.array(fit)     
        print('Protester demand count:', np.sum(demand_array))
    else:
        fit = ohe.transform(df[demand_col].values.reshape(-1, 1))
        demand_array = np.logical_or(demand_array, fit)
        print('Protester demand count:', np.sum(demand_array))
        


# Clean column names
remove_commas = lambda x: str.replace(x, ', ', '/')
remove_spaces = lambda x: str.replace(x, ' ', '-')
col_names = ohe.get_feature_names(['demand'])
col_names = list(map(remove_spaces, map(remove_commas, col_names)))

# Store as dataframe 
demand_df = pd.DataFrame(demand_array, dtype='int', columns=col_names)
demand_df.drop('demand_nan', axis=1, inplace=True)

print('\nFinal shape:', demand_df.shape)
print('\nColumn names:', demand_df.columns)
print('\nRequests by type:\n{}'.format((demand_df.sum().sort_values(ascending=False))))
# Out:
# Protester demand count: 15239.0
# Protester demand count: 30476
# Protester demand count: 33453
# Protester demand count: 33835
#
# Final shape: (15239, 7)
#
# Column names: Index(['demand_labor-wage-dispute', 'demand_land-farm-issue',
#        'demand_police-brutality', 'demand_political-behavior/process',
#        'demand_price-increases/tax-policy', 'demand_removal-of-politician',
#        'demand_social-restrictions'],
#       dtype='object')
#
# Requests by type:
# demand_political-behavior/process    10750
# demand_labor-wage-dispute             2211
# demand_removal-of-politician          1889
# demand_price-increases/tax-policy     1414
# demand_police-brutality               1101
# demand_social-restrictions             684
# demand_land-farm-issue                 582
# dtype: int64

# %% [markdown]
# # State responses

# %%
# column names containing state response data
response_cols = ['stateresponse1', 'stateresponse2', 'stateresponse3', 'stateresponse4', 
             'stateresponse5', 'stateresponse6', 'stateresponse7']

# Replace '.' with np.nan
for col in response_cols:
    df[col].replace('.', np.nan, inplace=True)

# %%
# Verify there are only 7 responses as indicated by data manual
# Create list of unique demands

demands = np.array([])
for col in response_cols:
    demands = np.concatenate([demands, df[col]])
print(set(demands))
# We see that there are 7 demands, plus placeholder '.' and 'nan' values to drop later
# Out:
# {nan, 'ignore', 'crowd dispersal', 'arrests', 'beatings', 'killings', 'accomodation', 'shootings'}

# %%
# --- ONE HOT ENCODE EACH OF THESE RESPONSES

ohe = OneHotEncoder(sparse=False)

for col in response_cols:
    if col == response_cols[0]: # first iteration
        fit = ohe.fit_transform(df[col].values.reshape(-1, 1))
        response_array = np.array(fit)     
        print('State response count:', np.sum(response_array))
        print('\nColumn_names:', ohe.get_feature_names(['response']))
    else:
        fit = ohe.transform(df[col].values.reshape(-1, 1))
        response_array = np.logical_or(response_array, fit)
        print('State response count:', np.sum(response_array))
        
print('\nPre-cleaning column names:', ohe.get_feature_names(['response']))
        
        
# # Clean column names
remove_spaces = lambda x: str.replace(x, ' ', '-')
col_names = ohe.get_feature_names(['response'])
col_names = list(map(remove_spaces, col_names))
print('\nPost-cleaning column names:', col_names)

# Store as dataframe 
response_df = pd.DataFrame(response_array, dtype='int', columns=col_names)
response_df.drop('response_nan', axis=1, inplace=True)

print('\nFinal shape:', response_df.shape)
print('\nColumn names:', response_df.columns)
# Out:
# State response count: 15239.0
#
# Column_names: ['response_accomodation' 'response_arrests' 'response_beatings'
#  'response_crowd dispersal' 'response_ignore' 'response_killings'
#  'response_shootings' 'response_nan']
# State response count: 30448
# State response count: 33321
# State response count: 34236
# State response count: 34470
# State response count: 34517
# State response count: 34534
#
# Pre-cleaning column names: ['response_accomodation' 'response_arrests' 'response_beatings'
#  'response_crowd dispersal' 'response_ignore' 'response_killings'
#  'response_shootings' 'response_nan']
#
# Post-cleaning column names: ['response_accomodation', 'response_arrests', 'response_beatings', 'response_crowd-dispersal', 'response_ignore', 'response_killings', 'response_shootings', 'response_nan']
#
# Final shape: (15239, 7)
#
# Column names: Index(['response_accomodation', 'response_arrests', 'response_beatings',
#        'response_crowd-dispersal', 'response_ignore', 'response_killings',
#        'response_shootings'],
#       dtype='object')

# %% [markdown]
# #### Identify next column to investigate:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15239 entries, 0 to 15238
# Data columns (total 36 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  15239 non-null  int64
#  1   year                                15239 non-null  int64
#  2   region                              15239 non-null  object
#  3   protest                             15239 non-null  int64
#  4   protestnumber                       15239 non-null  int64
#  5   startday                            15239 non-null  float64
#  6   startmonth                          15239 non-null  float64
#  7   startyear                           15239 non-null  float64
#  8   endday                              15239 non-null  float64
#  9   endmonth                            15239 non-null  float64
#  10  endyear                             15239 non-null  float64
#  11  protesterviolence                   15239 non-null  float64
#  12  location                            15239 non-null  object
#  13  participants_category               9887 non-null   object
#  14  participants                        15227 non-null  object
#  15  protesteridentity                   15239 non-null  object
#  16  protesterdemand1                    15238 non-null  object
#  17  protesterdemand2                    2977 non-null   object
#  18  protesterdemand3                    383 non-null    object
#  19  protesterdemand4                    35 non-null     object
#  20  stateresponse1                      15208 non-null  object
#  21  stateresponse2                      2888 non-null   object
#  22  stateresponse3                      930 non-null    object
#  23  stateresponse4                      244 non-null    object
#  24  stateresponse5                      53 non-null     object
#  25  stateresponse6                      16 non-null     object
#  26  stateresponse7                      7 non-null      object
#  27  sources                             15235 non-null  object
#  28  notes                               15193 non-null  object
#  29  scode_final                         15239 non-null  object
#  30  countryname_final                   15239 non-null  object
#  31  start_datetime                      15239 non-null  datetime64[ns]
#  32  end_datetime                        15239 non-null  datetime64[ns]
#  33  duration_days                       15239 non-null  int64
#  34  participants_clean                  15208 non-null  float64
#  35  participants_category_manufactured  15208 non-null  object
# dtypes: datetime64[ns](2), float64(8), int64(5), object(21)
# memory usage: 4.2+ MB

# %%
df.loc[23]
# Out:
# id                                                                            202005001
# year                                                                               2005
# region                                                                    North America
# protest                                                                               1
# protestnumber                                                                         1
# startday                                                                            3.0
# startmonth                                                                          3.0
# startyear                                                                        2005.0
# endday                                                                              3.0
# endmonth                                                                            4.0
# endyear                                                                          2005.0
# protesterviolence                                                                   1.0
# location                                                                         Quebec
# participants_category                                                               NaN
# participants                                                                     170000
# protesteridentity                                                      college students
# protesterdemand1                                            political behavior, process
# protesterdemand2                                                                    NaN
# protesterdemand3                                                                    NaN
# protesterdemand4                                                                    NaN
# stateresponse1                                                                  arrests
# stateresponse2                                                                      NaN
# stateresponse3                                                                      NaN
# stateresponse4                                                                      NaN
# stateresponse5                                                                      NaN
# stateresponse6                                                                      NaN
# stateresponse7                                                                      NaN
# sources                               1. quebec is shedding image as hotbed of polit...
# notes                                 the scene on fashionable rue st. denis looked ...
# scode_final                                                                         CAN
# countryname_final                                                                Canada
# start_datetime                                                      2005-03-03 00:00:00
# end_datetime                                                        2005-04-03 00:00:00
# duration_days                                                                        31
# participants_clean                                                             170000.0
# participants_category_manufactured                                               10000+
# Name: 23, dtype: object

# %% [markdown]
# ### Investigate "sources" and "notes" columns

# %%
df.sources.value_counts()
# Out:
# germany s car capital reels as court allows ban on cars the new york times, february 28, 2018 wednesday, section a; column 0; foreign desk; pg. 1, 1583 words, by katrin bennhold ;                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             48
# discontent over migrants takes a toll on east german city the new york times, december 2, 2015 wednesday, section ; column 0; foreign desk; letter from europe; pg. , 680 words, by alison smale angela merkel faces protests on anniversary of german reunification; german chancellor angela merkel s visit to dresden to mark the 26th anniversary of reunification drew protests from far right nationalists who oppose her policy of welcoming refugees. germany cracks down on far right groups with arrests and a trial the new york times, april 20, 2016 wednesday, section a; column 0; foreign desk; pg. 10, 841 words, by alison smale and melissa eddy. follow alison smale on twitter asmalenyt, and melissa eddy meddynyt. the christian science monitor, october 3, 2016 monday, world, 427 words, eva botkin kowacki staff writer;                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             45
# mr. trump s cuban opportunity. the washington post, january 11, 2017 wednesday regional edition, editorial copy; pg. a18, 551 words ;                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           37
# discontent over migrants takes a toll on east german city the new york times, december 2, 2015 wednesday, section ; column 0; foreign desk; letter from europe; pg. , 680 words, by alison smale;                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               37
# why these catholics plan to protest at pope s cuba visit; a group of catholic protesters were arrested in havana less than a week before a visit from pope francis to cuba. the protesters say the catholic church should do more for their political cause. the christian science monitor, september 14, 2015 monday, world, 537 words, lucy schouten staff;                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   37
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ..
# opposition alliance holds 2,000 strong rally in armenian capital bbc summary of world broadcasts, january 26, 1995, thursday, part 1 former ussr; caucasus; armenia; su 2211 f, 182 words;                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       1
# agence france presse, february 22, 2006 wednesday, ecuador oil exports in turmoil as protests continue ; the globe and mail canada , february 24, 2006 friday, report on business: international; business ticker: international:; pg. b5, ecuado;                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               1
# violence hits nicaragua as bus, taxi drivers strike the associated press, september 20, 1993, monday, am cycle, international news, 266 words two killed in transport strike as nicaragua crisis deepens the associated press, september 22, 1993, wednesday, am cycle, international news, 560 words, by filadelfo aleman, associated press writer president to fly home to nicaragua amid deepening crisis the associated press, september 22, 1993, wednesday, pm cycle, international news, 542 words, by filadelfo aleman, associated press writer transportion worker s strike paralyzes nicaragua the associated press, september 22, 1993, wednesday, am cycle, international news, 654 words, by filadelfo aleman, associated press writer two die as nicaraguan strikers clash with police the new york times, september 22, 1993, wednesday, late edition final, section a; page 3; column 2; foreign desk, 282 words, ap unemployed and disgruntled joining armed transport strikers the associated press, september 23, 1993, thursday, am cycle, international news, 475 words, by bill cormier, associated press writer barricade bonfires blaze as transportation strike paralyzes nicaragua the associated press, september 23, 1993, thursday, pm cycle, international news, 619 words, by bill cormier, associated press writer five day nationwide strike ends the associated press, september 24, 1993, friday, pm cycle, international news, 443 words, by bill cormier, associated press writer nicaragua repeals new car tax after strike the new york times, september 25, 1993, saturday, late edition final, section 1; page 2; column 1; foreign desk, 479 words, special to the new york times;     1
# asylum seeking families protest on children s day the irish times, november 21, 2014 friday, ireland; pg. 9, 355 words, tim o brien;                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             1
# 1 farmers furious at halloumi law. cyprus mail, may 25, 2012 friday; 2 sheep and goat farmers keep their flocks for now. cyprus mail, august 28, 2012 tuesday;                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   1
# Name: sources, Length: 14122, dtype: int64

# %%
df.notes.value_counts()
# Out:
# general strike                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  116
# just the number of arrest and or injuries                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        53
# but stuttgart, nestled in a basin framed by vineyards and forested hills, also has a long tradition of hiking clubs and solar panels on its rooftops. the city has a green mayor, who drives an electric car, and has been governed by a coalition led by the greens since 2011. it also has a vibrant local environmental movement, which has been protesting a multiyear, multibillion euro project in the heart of the city to move the main train station underground. outraged at the sprawling and polluting building site, known as stuttgart 21, residents have been demonstrating every monday for seven years. this week, on the eve of the diesel ruling, as air pollution measurements reached twice the level permitted under european standards, the 406th protest took place. braving subzero temperatures, mr. resch, the man who filed the driving ban lawsuit, addressed a small but noisy crowd. coded as weekly protests on mondays for entire period.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       48
# coded as weekly protests going back to october of 2014. enough information to code one protest a week with 1,000s of individuals. 2 12 2015 more than one year later, they are still here, the thousands of people who rally every monday under the banner of the pegida movement to vent their rage against muslims, migrants and especially the government of chancellor angela merkel. no further mentions of pegida demonstrations during the year. though there is also no sign that the monday protests stopped. 26 4 2016 dresden, where weekly demonstrations against immigrants have been held since late 2014. 3 10 2016 celebrations marking 26 years since germany s reunification filled the streets of dresden monday, but the mood wasn t all jovial. when german chancellor angela merkel arrived and greeted the people who had gathered, some right wing protestors jeered and shouted traitor and merkel must go, while holding placards bearing the same slogan. at the center of the criticism levied against her and other politicians is merkel s open door refugee policy. dresden, where the celebrations of german unity day took place, is a hotbed of anti migrant sentiment. the anti islam group patriotic europeans against the islamization of the west, known by its german acronym as pegida, is based there. the grassroots movement has held weekly rallies in the city, attracting about 20,000 supporters at their peak in early 2015.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     45
# more than one year later, they are still here, the thousands of people who rally every monday under the banner of the pegida movement to vent their rage against muslims, migrants and especially the government of chancellor angela merkel.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    41
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# protests occurred in north of the capital, in guatemala city, and at atlantic and pacific ports. teacher strike continues. it began january 13th.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 1
# hundreds of unarmed army reservists in madagascar on friday barricaded parliament saying they were taking 160 lawmakers hostage to demand payment for having backed president marc ravalomanana during the country s political crisis in 2002. the peaceful protest which began friday morning, when between 500 and 1,200 reservists used laden bicycles to block access roads to the national assembly building in the capital, antananarivo, ended without serious incident in the early afternoon after a meeting with two of the assembly s deputy speakers. despite that the protesters said they were taking the lawmakers hostage, they were not armed and were peaceful. no violence actually took place.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                1
# in pretoria, the conservative party, which opposes the dismantling of apartheid, gathered several thousand white supporters for a march to the union buildings, where mr. de klerk s offices are situated, to deliver a petition contending that he had no mandate to dismantle white minority rule. they demanded that he call a new election for white voters. the conservative party contends that mr. de klerk has betrayed whites, and particularly afrikaners, by meeting with the african national congress, which was banned for 30 years. if apartheid cannot be maintained, the conservatives want the country partitioned into separate homelands for whites and blacks.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               1
# ??the founders of an albanian university that has been banned by macedonian authorities as unconstitutional went on trial for incitement here wednesday. a 10,000 strong crowd of supporters gathered in this northwestern town as university rector fadilj sulejmani and his colleague miljaim fejziu entered the courthouse ??the demonstration in tetovo s central square wednesday in the presence of macedonian albanian political leaders lasted about an hour and was peaceful, though some 1,000 people also protested in front of the court, forcing it to suspend hearings for an hour. ??                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# 1 simmering tensions between protesters and the authorities over lebanon s continuing trash crisis erupted into violence on wednesday as the police used force on demonstrators rallying outside the seat of government in beirut...riot police beat back...protesters with batons, pushing them to blom bank...footage of police beating women protestors...video posted on facebook by activists from the antigovernment you stink movement showed one young protester, identified as bilal allaw, being rushed away on a stretcher after police officers with batons charged at dozens of protesters...according to alexis lai of beirut s daily star, the protesters first scuffled with the police earlier in the day when one of the movement s founders, assaad thebian, was briefly detained. after mr. thebian was released, he called on supporters of the movement to protest in riad al solh square, outside prime minister per tammam salam s office...showed protesters being pelted with water by the police as they tried to remove barbed wire blocking the street leading to the government buildings...the protesters later regrouped, refusing to disperse until four more activists taken into custody were released...the detained protesters were eventually set free, according to nadine mazloum of lbc, but the activists promised to return to the square on saturday to protest police brutality... ; 2 at least 30 people were hurt, according to the red cross. dozens of people were injured on saturday, when the police also used rubber bullets... ; 3 dozens of demonstrators and officers were wounded during similar clashes the previous evening, prompting prime minister tammam salam to issue conciliatory remarks on sunday afternoon...the protest organizer, a group calling itself you stink, has promised to press on with the rallies until the government resigns. it s not about the trash anymore. our demands are more we want this corrupt government to resign, said tarek, a protester. he gave only his first name, citing concerns about his safety.      1
# Name: notes, Length: 13921, dtype: int64

# %% [markdown]
# ##### As can be seen above, the 'source' and 'notes' columns don't contain standardized text. It is best to fill na's such that rows aren't dropped just because these columns aren't filled in

# %%
df['notes'] = df['notes'].fillna(UNKNOWN)
df['sources'] = df['sources'].fillna(UNKNOWN)

# %% [markdown]
# # Put it all together

# %%
# Take a look at everything that is an option
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15239 entries, 0 to 15238
# Data columns (total 36 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  15239 non-null  int64
#  1   year                                15239 non-null  int64
#  2   region                              15239 non-null  object
#  3   protest                             15239 non-null  int64
#  4   protestnumber                       15239 non-null  int64
#  5   startday                            15239 non-null  float64
#  6   startmonth                          15239 non-null  float64
#  7   startyear                           15239 non-null  float64
#  8   endday                              15239 non-null  float64
#  9   endmonth                            15239 non-null  float64
#  10  endyear                             15239 non-null  float64
#  11  protesterviolence                   15239 non-null  float64
#  12  location                            15239 non-null  object
#  13  participants_category               9887 non-null   object
#  14  participants                        15227 non-null  object
#  15  protesteridentity                   15239 non-null  object
#  16  protesterdemand1                    15238 non-null  object
#  17  protesterdemand2                    2977 non-null   object
#  18  protesterdemand3                    383 non-null    object
#  19  protesterdemand4                    35 non-null     object
#  20  stateresponse1                      15208 non-null  object
#  21  stateresponse2                      2888 non-null   object
#  22  stateresponse3                      930 non-null    object
#  23  stateresponse4                      244 non-null    object
#  24  stateresponse5                      53 non-null     object
#  25  stateresponse6                      16 non-null     object
#  26  stateresponse7                      7 non-null      object
#  27  sources                             15239 non-null  object
#  28  notes                               15239 non-null  object
#  29  scode_final                         15239 non-null  object
#  30  countryname_final                   15239 non-null  object
#  31  start_datetime                      15239 non-null  datetime64[ns]
#  32  end_datetime                        15239 non-null  datetime64[ns]
#  33  duration_days                       15239 non-null  int64
#  34  participants_clean                  15208 non-null  float64
#  35  participants_category_manufactured  15208 non-null  object
# dtypes: datetime64[ns](2), float64(8), int64(5), object(21)
# memory usage: 4.2+ MB

# %%
df.loc[df['year'] != df['startyear']]
# Out:
# Empty DataFrame
# Columns: [id, year, region, protest, protestnumber, startday, startmonth, startyear, endday, endmonth, endyear, protesterviolence, location, participants_category, participants, protesteridentity, protesterdemand1, protesterdemand2, protesterdemand3, protesterdemand4, stateresponse1, stateresponse2, stateresponse3, stateresponse4, stateresponse5, stateresponse6, stateresponse7, sources, notes, scode_final, countryname_final, start_datetime, end_datetime, duration_days, participants_clean, participants_category_manufactured]
# Index: []

# %%
include_cols = ['id', 'countryname_final', 'scode_final', 'region', 'protestnumber', 'protesterviolence', 'protesteridentity',
                'startyear', 'startmonth', 'startday', 'duration_days',
                'participants_clean', 'participants_category', 'participants_category_manufactured', 'notes']

df[include_cols]
# Out:
#                id countryname_final scode_final         region  protestnumber  \
# 0       201990001            Canada         CAN  North America              1
# 1       201990002            Canada         CAN  North America              2
# 2       201990003            Canada         CAN  North America              3
# 3       201990004            Canada         CAN  North America              4
# 4       201990005            Canada         CAN  North America              5
# ...           ...               ...         ...            ...            ...
# 15234  9102014001  Papua New Guinea         PNG        Oceania              1
# 15235  9102016001  Papua New Guinea         PNG        Oceania              1
# 15236  9102017001  Papua New Guinea         PNG        Oceania              1
# 15237  9102017002  Papua New Guinea         PNG        Oceania              2
# 15238  9102017003  Papua New Guinea         PNG        Oceania              3
#
#        protesterviolence                                  protesteridentity  \
# 0                    0.0                                            unknown
# 1                    0.0                                            unknown
# 2                    0.0                         separatist parti quebecois
# 3                    1.0                                     mohawk indians
# 4                    1.0                                    local residents
# ...                  ...                                                ...
# 15234                1.0                                     asylum seekers
# 15235                1.0                                university students
# 15236                0.0  protesters opposed to renewing the licence of ...
# 15237                1.0  protesters opposed to counting irregularities ...
# 15238                0.0                                             locals
#
#        startyear  startmonth  startday  duration_days  participants_clean  \
# 0         1990.0         1.0      15.0              0              1000.0
# 1         1990.0         6.0      25.0              0              1000.0
# 2         1990.0         7.0       1.0              0               500.0
# 3         1990.0         7.0      12.0             56               100.0
# 4         1990.0         8.0      14.0              1               950.0
# ...          ...         ...       ...            ...                 ...
# 15234     2014.0         2.0      16.0              2               100.0
# 15235     2016.0         5.0      15.0             25              1000.0
# 15236     2017.0         6.0      15.0              0                50.0
# 15237     2017.0         7.0      15.0              0                50.0
# 15238     2017.0        10.0      31.0              0               100.0
#
#       participants_category participants_category_manufactured  \
# 0                       NaN                          1000-1999
# 1                       NaN                          1000-1999
# 2                       NaN                            100-999
# 3                       NaN                            100-999
# 4                       NaN                            100-999
# ...                     ...                                ...
# 15234               100-999                            100-999
# 15235             1000-1999                          1000-1999
# 15236                 50-99                              50-99
# 15237                 50-99                              50-99
# 15238               100-999                            100-999
#
#                                                    notes
# 0      canada s railway passenger system was finally ...
# 1      protestors were only identified as young peopl...
# 2      the queen, after calling on canadians to remai...
# 3      canada s federal government has agreed to acqu...
# 4      protests were directed against the state due t...
# ...                                                  ...
# 15234  ? a government inquiry will be launched as ser...
# 15235  police in papua new guinea fired gunshots wedn...
# 15236  the bougainville government has enacted an ind...
# 15237  peter o neill has been reappointed as prime mi...
# 15238  refugees on manus island were braced for poten...
#
# [15239 rows x 15 columns]

# %% [markdown]
# ### Combine clean dataframe with protester demands and government responses

# %%
df_clean = pd.concat([df[include_cols], demand_df, response_df], axis=1)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15239 entries, 0 to 15238
# Data columns (total 29 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  15239 non-null  int64
#  1   countryname_final                   15239 non-null  object
#  2   scode_final                         15239 non-null  object
#  3   region                              15239 non-null  object
#  4   protestnumber                       15239 non-null  int64
#  5   protesterviolence                   15239 non-null  float64
#  6   protesteridentity                   15239 non-null  object
#  7   startyear                           15239 non-null  float64
#  8   startmonth                          15239 non-null  float64
#  9   startday                            15239 non-null  float64
#  10  duration_days                       15239 non-null  int64
#  11  participants_clean                  15208 non-null  float64
#  12  participants_category               9887 non-null   object
#  13  participants_category_manufactured  15208 non-null  object
#  14  notes                               15239 non-null  object
#  15  demand_labor-wage-dispute           15239 non-null  int32
#  16  demand_land-farm-issue              15239 non-null  int32
#  17  demand_police-brutality             15239 non-null  int32
#  18  demand_political-behavior/process   15239 non-null  int32
#  19  demand_price-increases/tax-policy   15239 non-null  int32
#  20  demand_removal-of-politician        15239 non-null  int32
#  21  demand_social-restrictions          15239 non-null  int32
#  22  response_accomodation               15239 non-null  int32
#  23  response_arrests                    15239 non-null  int32
#  24  response_beatings                   15239 non-null  int32
#  25  response_crowd-dispersal            15239 non-null  int32
#  26  response_ignore                     15239 non-null  int32
#  27  response_killings                   15239 non-null  int32
#  28  response_shootings                  15239 non-null  int32
# dtypes: float64(5), int32(14), int64(3), object(7)
# memory usage: 2.6+ MB

# %% [markdown]
# ### Fill na values where valuable, drop rows with remaining nas

# %%
df_clean['participants_category'] = df_clean['participants_category'].fillna(UNKNOWN)

# %% [markdown]
# ##### Below, we see that there are 31 rows with null values. In all cases, it is in the 'participants' category. It is worth dropping these rows entirely since the participant count at a protest is an invaluable field in this analysis.

# %%
df_clean.loc[df_clean.isna().any(axis=1)].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31 entries, 21 to 15100
# Data columns (total 29 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  31 non-null     int64
#  1   countryname_final                   31 non-null     object
#  2   scode_final                         31 non-null     object
#  3   region                              31 non-null     object
#  4   protestnumber                       31 non-null     int64
#  5   protesterviolence                   31 non-null     float64
#  6   protesteridentity                   31 non-null     object
#  7   startyear                           31 non-null     float64
#  8   startmonth                          31 non-null     float64
#  9   startday                            31 non-null     float64
#  10  duration_days                       31 non-null     int64
#  11  participants_clean                  0 non-null      float64
#  12  participants_category               31 non-null     object
#  13  participants_category_manufactured  0 non-null      object
#  14  notes                               31 non-null     object
#  15  demand_labor-wage-dispute           31 non-null     int32
#  16  demand_land-farm-issue              31 non-null     int32
#  17  demand_police-brutality             31 non-null     int32
#  18  demand_political-behavior/process   31 non-null     int32
#  19  demand_price-increases/tax-policy   31 non-null     int32
#  20  demand_removal-of-politician        31 non-null     int32
#  21  demand_social-restrictions          31 non-null     int32
#  22  response_accomodation               31 non-null     int32
#  23  response_arrests                    31 non-null     int32
#  24  response_beatings                   31 non-null     int32
#  25  response_crowd-dispersal            31 non-null     int32
#  26  response_ignore                     31 non-null     int32
#  27  response_killings                   31 non-null     int32
#  28  response_shootings                  31 non-null     int32
# dtypes: float64(5), int32(14), int64(3), object(7)
# memory usage: 5.6+ KB

# %%
# DROP ROWS WITH MISSING VALUES
df_clean.dropna(inplace=True)

# %%
# Verify that the desired columns are included

clean_cols = list(df_clean.columns)

for x_val in list(df.columns):
    incl = 'include:' if x_val in clean_cols else '*EXCLUDE*:'
    print(incl, x_val)
# Out:
# include: id
# *EXCLUDE*: year
# include: region
# *EXCLUDE*: protest
# include: protestnumber
# include: startday
# include: startmonth
# include: startyear
# *EXCLUDE*: endday
# *EXCLUDE*: endmonth
# *EXCLUDE*: endyear
# include: protesterviolence
# *EXCLUDE*: location
# include: participants_category
# *EXCLUDE*: participants
# include: protesteridentity
# *EXCLUDE*: protesterdemand1
# *EXCLUDE*: protesterdemand2
# *EXCLUDE*: protesterdemand3
# *EXCLUDE*: protesterdemand4
# *EXCLUDE*: stateresponse1
# *EXCLUDE*: stateresponse2
# *EXCLUDE*: stateresponse3
# *EXCLUDE*: stateresponse4
# *EXCLUDE*: stateresponse5
# *EXCLUDE*: stateresponse6
# *EXCLUDE*: stateresponse7
# *EXCLUDE*: sources
# include: notes
# include: scode_final
# include: countryname_final
# *EXCLUDE*: start_datetime
# *EXCLUDE*: end_datetime
# include: duration_days
# include: participants_clean
# include: participants_category_manufactured

# %% [markdown]
# ### Final, nit-picky cleanup

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15208 entries, 0 to 15238
# Data columns (total 29 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  15208 non-null  int64
#  1   countryname_final                   15208 non-null  object
#  2   scode_final                         15208 non-null  object
#  3   region                              15208 non-null  object
#  4   protestnumber                       15208 non-null  int64
#  5   protesterviolence                   15208 non-null  float64
#  6   protesteridentity                   15208 non-null  object
#  7   startyear                           15208 non-null  float64
#  8   startmonth                          15208 non-null  float64
#  9   startday                            15208 non-null  float64
#  10  duration_days                       15208 non-null  int64
#  11  participants_clean                  15208 non-null  float64
#  12  participants_category               15208 non-null  object
#  13  participants_category_manufactured  15208 non-null  object
#  14  notes                               15208 non-null  object
#  15  demand_labor-wage-dispute           15208 non-null  int32
#  16  demand_land-farm-issue              15208 non-null  int32
#  17  demand_police-brutality             15208 non-null  int32
#  18  demand_political-behavior/process   15208 non-null  int32
#  19  demand_price-increases/tax-policy   15208 non-null  int32
#  20  demand_removal-of-politician        15208 non-null  int32
#  21  demand_social-restrictions          15208 non-null  int32
#  22  response_accomodation               15208 non-null  int32
#  23  response_arrests                    15208 non-null  int32
#  24  response_beatings                   15208 non-null  int32
#  25  response_crowd-dispersal            15208 non-null  int32
#  26  response_ignore                     15208 non-null  int32
#  27  response_killings                   15208 non-null  int32
#  28  response_shootings                  15208 non-null  int32
# dtypes: float64(5), int32(14), int64(3), object(7)
# memory usage: 2.7+ MB

# %%
# Convert relevant columns from float to int
convert_to_int = ['protesterviolence', 'startyear', 'startmonth', 'startday', 'participants_clean']

for col in convert_to_int:
    df_clean[col] = df_clean[col].astype('int')

df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15208 entries, 0 to 15238
# Data columns (total 29 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  15208 non-null  int64
#  1   countryname_final                   15208 non-null  object
#  2   scode_final                         15208 non-null  object
#  3   region                              15208 non-null  object
#  4   protestnumber                       15208 non-null  int64
#  5   protesterviolence                   15208 non-null  int32
#  6   protesteridentity                   15208 non-null  object
#  7   startyear                           15208 non-null  int32
#  8   startmonth                          15208 non-null  int32
#  9   startday                            15208 non-null  int32
#  10  duration_days                       15208 non-null  int64
#  11  participants_clean                  15208 non-null  int32
#  12  participants_category               15208 non-null  object
#  13  participants_category_manufactured  15208 non-null  object
#  14  notes                               15208 non-null  object
#  15  demand_labor-wage-dispute           15208 non-null  int32
#  16  demand_land-farm-issue              15208 non-null  int32
#  17  demand_police-brutality             15208 non-null  int32
#  18  demand_political-behavior/process   15208 non-null  int32
#  19  demand_price-increases/tax-policy   15208 non-null  int32
#  20  demand_removal-of-politician        15208 non-null  int32
#  21  demand_social-restrictions          15208 non-null  int32
#  22  response_accomodation               15208 non-null  int32
#  23  response_arrests                    15208 non-null  int32
#  24  response_beatings                   15208 non-null  int32
#  25  response_crowd-dispersal            15208 non-null  int32
#  26  response_ignore                     15208 non-null  int32
#  27  response_killings                   15208 non-null  int32
#  28  response_shootings                  15208 non-null  int32
# dtypes: int32(19), int64(3), object(7)
# memory usage: 2.4+ MB

# %%
df_clean.rename(columns={'participants_clean': 'participants', 
                         'participants_category': 'participants_category_original',
                         'id': 'protest_id', 
                         'ccode_fina': 'ccode',
                         'countryname_final': 'country'}, inplace=True)
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15208 entries, 0 to 15238
# Data columns (total 29 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   protest_id                          15208 non-null  int64
#  1   country                             15208 non-null  object
#  2   scode_final                         15208 non-null  object
#  3   region                              15208 non-null  object
#  4   protestnumber                       15208 non-null  int64
#  5   protesterviolence                   15208 non-null  int32
#  6   protesteridentity                   15208 non-null  object
#  7   startyear                           15208 non-null  int32
#  8   startmonth                          15208 non-null  int32
#  9   startday                            15208 non-null  int32
#  10  duration_days                       15208 non-null  int64
#  11  participants                        15208 non-null  int32
#  12  participants_category_original      15208 non-null  object
#  13  participants_category_manufactured  15208 non-null  object
#  14  notes                               15208 non-null  object
#  15  demand_labor-wage-dispute           15208 non-null  int32
#  16  demand_land-farm-issue              15208 non-null  int32
#  17  demand_police-brutality             15208 non-null  int32
#  18  demand_political-behavior/process   15208 non-null  int32
#  19  demand_price-increases/tax-policy   15208 non-null  int32
#  20  demand_removal-of-politician        15208 non-null  int32
#  21  demand_social-restrictions          15208 non-null  int32
#  22  response_accomodation               15208 non-null  int32
#  23  response_arrests                    15208 non-null  int32
#  24  response_beatings                   15208 non-null  int32
#  25  response_crowd-dispersal            15208 non-null  int32
#  26  response_ignore                     15208 non-null  int32
#  27  response_killings                   15208 non-null  int32
#  28  response_shootings                  15208 non-null  int32
# dtypes: int32(19), int64(3), object(7)
# memory usage: 2.4+ MB

# %% [markdown]
# ##### Final EDA of Response columns

# %%
df_response_OG = df[['stateresponse1', 'stateresponse2', 'stateresponse3', 'stateresponse4', 'stateresponse5', 'stateresponse6', 'stateresponse7']].copy()

temp = pd.concat([response_df, df_response_OG], axis=1)
temp.loc[(temp.stateresponse1=='accomodation') & (temp.stateresponse2.isna())]
# Out:
#        response_accomodation  response_arrests  response_beatings  \
# 3                          1                 0                  0
# 19                         1                 0                  0
# 39                         1                 0                  0
# 45                         1                 0                  0
# 46                         1                 0                  0
# ...                      ...               ...                ...
# 15229                      1                 0                  0
# 15230                      1                 0                  0
# 15231                      1                 0                  0
# 15232                      1                 0                  0
# 15236                      1                 0                  0
#
#        response_crowd-dispersal  response_ignore  response_killings  \
# 3                             0                0                  0
# 19                            0                0                  0
# 39                            0                0                  0
# 45                            0                0                  0
# 46                            0                0                  0
# ...                         ...              ...                ...
# 15229                         0                0                  0
# 15230                         0                0                  0
# 15231                         0                0                  0
# 15232                         0                0                  0
# 15236                         0                0                  0
#
#        response_shootings stateresponse1 stateresponse2 stateresponse3  \
# 3                       0   accomodation            NaN            NaN
# 19                      0   accomodation            NaN            NaN
# 39                      0   accomodation            NaN            NaN
# 45                      0   accomodation            NaN            NaN
# 46                      0   accomodation            NaN            NaN
# ...                   ...            ...            ...            ...
# 15229                   0   accomodation            NaN            NaN
# 15230                   0   accomodation            NaN            NaN
# 15231                   0   accomodation            NaN            NaN
# 15232                   0   accomodation            NaN            NaN
# 15236                   0   accomodation            NaN            NaN
#
#       stateresponse4 stateresponse5 stateresponse6 stateresponse7
# 3                NaN            NaN            NaN            NaN
# 19               NaN            NaN            NaN            NaN
# 39               NaN            NaN            NaN            NaN
# 45               NaN            NaN            NaN            NaN
# 46               NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 15229            NaN            NaN            NaN            NaN
# 15230            NaN            NaN            NaN            NaN
# 15231            NaN            NaN            NaN            NaN
# 15232            NaN            NaN            NaN            NaN
# 15236            NaN            NaN            NaN            NaN
#
# [885 rows x 14 columns]

# %% [markdown]
# # Export as SQL

# %%
engine = create_engine('sqlite:///../data/processed/protests.db')

with engine.begin() as connection:
    df_clean.to_sql(name='protests', con=engine, if_exists='replace', index=False)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15208 entries, 0 to 15238
# Data columns (total 29 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   protest_id                          15208 non-null  int64
#  1   country                             15208 non-null  object
#  2   scode_final                         15208 non-null  object
#  3   region                              15208 non-null  object
#  4   protestnumber                       15208 non-null  int64
#  5   protesterviolence                   15208 non-null  int32
#  6   protesteridentity                   15208 non-null  object
#  7   startyear                           15208 non-null  int32
#  8   startmonth                          15208 non-null  int32
#  9   startday                            15208 non-null  int32
#  10  duration_days                       15208 non-null  int64
#  11  participants                        15208 non-null  int32
#  12  participants_category_original      15208 non-null  object
#  13  participants_category_manufactured  15208 non-null  object
#  14  notes                               15208 non-null  object
#  15  demand_labor-wage-dispute           15208 non-null  int32
#  16  demand_land-farm-issue              15208 non-null  int32
#  17  demand_police-brutality             15208 non-null  int32
#  18  demand_political-behavior/process   15208 non-null  int32
#  19  demand_price-increases/tax-policy   15208 non-null  int32
#  20  demand_removal-of-politician        15208 non-null  int32
#  21  demand_social-restrictions          15208 non-null  int32
#  22  response_accomodation               15208 non-null  int32
#  23  response_arrests                    15208 non-null  int32
#  24  response_beatings                   15208 non-null  int32
#  25  response_crowd-dispersal            15208 non-null  int32
#  26  response_ignore                     15208 non-null  int32
#  27  response_killings                   15208 non-null  int32
#  28  response_shootings                  15208 non-null  int32
# dtypes: int32(19), int64(3), object(7)
# memory usage: 2.4+ MB

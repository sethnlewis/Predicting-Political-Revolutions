# %%
import pandas as pd
pd.options.display.max_rows = 300
pd.options.display.max_columns = 300

# %%
df = pd.read_csv('../data/raw/ACLED/2018-07-30-2021-08-04.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 710319 entries, 0 to 710318
# Data columns (total 31 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   data_id           710319 non-null  int64
#  1   iso               710319 non-null  int64
#  2   event_id_cnty     710319 non-null  object
#  3   event_id_no_cnty  710319 non-null  int64
#  4   event_date        710319 non-null  object
#  5   year              710319 non-null  int64
#  6   time_precision    710319 non-null  int64
#  7   event_type        710319 non-null  object
#  8   sub_event_type    710319 non-null  object
#  9   actor1            710319 non-null  object
#  10  assoc_actor_1     293971 non-null  object
#  11  inter1            710319 non-null  int64
#  12  actor2            327592 non-null  object
#  13  assoc_actor_2     88621 non-null   object
#  14  inter2            710319 non-null  int64
#  15  interaction       710319 non-null  int64
# ...

# %%
df
# Out:
#         data_id  iso event_id_cnty  event_id_no_cnty    event_date  year  \
# 0       8412416  104      MMR20668             20668  30 July 2021  2021
# 1       8413696  356      IND97818             97818  30 July 2021  2021
# 2       8404481  760      SYR93246             93246  30 July 2021  2021
# 3       8412673  804      UKR46633             46633  30 July 2021  2021
# 4       8402690   76      BRA44615             44615  30 July 2021  2021
# ...         ...  ...           ...               ...           ...   ...
# 710314  7440382   76      BRA34257             34257  30 July 2018  2018
# 710315  5484030  356      IND33869             33869  30 July 2018  2018
# 710316  5885694  368      IRQ13694             13694  30 July 2018  2018
# 710317  5951742  356      IND33878             33878  30 July 2018  2018
# 710318  5484031  356      IND33876             33876  30 July 2018  2018
#
#         time_precision                  event_type  \
# ...

# %%
df.event_type.value_counts()
# Out:
# Protests                      341230
# Battles                       125253
# Explosions/Remote violence     87925
# Violence against civilians     75012
# Riots                          46961
# Strategic developments         33938
# Name: event_type, dtype: int64

# %%
df.year.value_counts()
# Out:
# 2020    251711
# 2019    215961
# 2021    160629
# 2018     82018
# Name: year, dtype: int64

# %%
df.loc[df.event_id_no_cnty==1]
# Out:
#         data_id  iso event_id_cnty  event_id_no_cnty        event_date  year  \
# 114292  7731810  652          BLM1                 1     05 March 2021  2021
# 210058  7495304  438          LIE1                 1   22 October 2020  2020
# 294596  7473778  292          GIB1                 1      29 June 2020  2020
# 304892  7200338  408          PRK1                 1      16 June 2020  2020
# 306103  7593655  840          USA1                 1      15 June 2020  2020
# 337919  7492776  304          GRL1                 1       05 May 2020  2020
# 343281  7718547  670          VCT1                 1     26 April 2020  2020
# 350896  7064158  850          VIR1                 1     10 April 2020  2020
# 351409  7058563  238          FLK1                 1     09 April 2020  2020
# 352173  7841096  180          DRC1                 1     07 April 2020  2020
# 357374  7001482  500          MSR1                 1     26 March 2020  2020
# ...

# %%
df.event_id_no_cnty.value_counts()
# Out:
# 1        98
# 2        95
# 3        91
# 4        89
# 7        86
#          ..
# 93575     1
# 97566     1
# 95519     1
# 95895     1
# 95414     1
# Name: event_id_no_cnty, Length: 97604, dtype: int64

# %%
df.loc[df.country == 'United States'][:100]
# Out:
#       data_id  iso event_id_cnty  event_id_no_cnty    event_date  year  \
# 103   8418110  840      USA32841             32841  30 July 2021  2021
# 108   8418114  840      USA32857             32857  30 July 2021  2021
# 111   8418118  840      USA32951             32951  30 July 2021  2021
# 121   8418128  840      USA32967             32967  30 July 2021  2021
# 125   8418130  840      USA32998             32998  30 July 2021  2021
# 141   8418146  840      USA32866             32866  30 July 2021  2021
# 165   8418159  840      USA32970             32970  30 July 2021  2021
# 188   8418177  840      USA32949             32949  30 July 2021  2021
# 191   8418180  840      USA32858             32858  30 July 2021  2021
# 204   8418192  840      USA32870             32870  30 July 2021  2021
# 246   8418216  840      USA32840             32840  30 July 2021  2021
# 276   8418238  840      USA33006             33006  30 July 2021  2021
# ...
